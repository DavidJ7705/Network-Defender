# %% [markdown]
# # PPO CartPole

# %%
import gymnasium as gym
from pathlib import Path
from gymnasium.wrappers import RecordVideo
from datetime import datetime
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
docs_path = Path("../../documentation/cartpole/ppo-cartpole") 

run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"
monitor_dir = run_path / "monitor"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)
monitor_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "ppo_cartpole"
monitor_file = str(monitor_dir) #/ "monitor_log.csv"

# %% [markdown]
# ## Training Model

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array") 
env = Monitor(env, monitor_file)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)
model.save(str(model_file))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.8     |
# |    ep_rew_mean     | 19.8     |
# | time/              |          |
# |    fps             | 6408     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.7        |
# |    ep_rew_mean          | 24.7        |
# | time/                   |             |
# |    fps                  | 4458        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008392536 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.0126     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.65        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 45.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 34.2       |
# |    ep_rew_mean          | 34.2       |
# | time/                   |            |
# |    fps                  | 3966       |
# |    iterations           | 3          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01077316 |
# |    clip_fraction        | 0.0814     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.663     |
# |    explained_variance   | 0.106      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.3       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0196    |
# |    value_loss           | 34.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46          |
# |    ep_rew_mean          | 46          |
# | time/                   |             |
# |    fps                  | 3830        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008202678 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 52          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.6        |
# |    ep_rew_mean          | 61.6        |
# | time/                   |             |
# |    fps                  | 3764        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005888373 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 66.4        |
# -----------------------------------------

# %%
# Reset environment
observation, info = env.reset(seed=42)
print(f"Total Timesteps:{model.num_timesteps}")
print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Total Timesteps:10240
# Action space: Discrete(2)
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Starting observation: [ 0.0273956  -0.00611216  0.03585979  0.0197368 ]
# maxiumum number of steps per episode: 500

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["cart position", "cart velocity", "pole angle", "pole angular velocity"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(action)

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}")

    for label, observe in zip(labels,observation):
        print(f"{label}: {observe}")

    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 1
# cart position: 0.02727336250245571
# cart velocity: 0.18847766518592834
# pole angle: 0.036254528909921646
# pole angular velocity: -0.26141977310180664
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 0
# cart position: 0.0310429148375988
# cart velocity: -0.007142550311982632
# pole angle: 0.03102613240480423
# pole angular velocity: 0.04247424006462097
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 1
# cart position: 0.03090006485581398
# cart velocity: 0.1875210702419281
# pole angle: 0.0318756178021431
# pole angular velocity: -0.24026045203208923
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 0
# cart position: 0.03465048596262932
# cart velocity: -0.0080413818359375
# pole angle: 0.027070408686995506
# pole angular velocity: 0.062304068356752396
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 1
# cart position: 0.03448965772986412
# cart velocity: 0.18668219447135925
# pole angle: 0.028316490352153778
# pole angular velocity: -0.22171655297279358
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 0
# cart position: 0.038223300129175186
# cart velocity: -0.008832814171910286
# pole angle: 0.02388215810060501
# pole angular velocity: 0.07976232469081879
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 7:
# Action taken: 1
# cart position: 0.03804664686322212
# cart velocity: 0.1859387904405594
# pole angle: 0.02547740563750267
# pole angular velocity: -0.20529106259346008
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 8:
# Action taken: 0
# cart position: 0.041765421628952026
# cart velocity: -0.009538063779473305
# pole angle: 0.02137158438563347
# pole angular velocity: 0.09531859308481216
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 9:
# Action taken: 1
# cart position: 0.04157466068863869
# cart velocity: 0.18527115881443024
# pole angle: 0.023277955129742622
# pole angular velocity: -0.19054575264453888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 10:
# Action taken: 0
# cart position: 0.045280084013938904
# cart velocity: -0.010175937786698341
# pole angle: 0.01946704089641571
# pole angular velocity: 0.1093885749578476
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 11:
# Action taken: 1
# cart position: 0.04507656395435333
# cart velocity: 0.18466173112392426
# pole angle: 0.02165481261909008
# pole angular velocity: -0.17708958685398102
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 12:
# Action taken: 0
# cart position: 0.04876979812979698
# cart velocity: -0.010763324797153473
# pole angle: 0.018113020807504654
# pole angular velocity: 0.12234526872634888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 13:
# Action taken: 1
# cart position: 0.04855453222990036
# cart velocity: 0.18409450352191925
# pole angle: 0.020559925585985184
# pole angular velocity: -0.16456858813762665
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 14:
# Action taken: 0
# cart position: 0.05223642289638519
# cart velocity: -0.011315638199448586
# pole angle: 0.017268553376197815
# pole angular velocity: 0.13452886044979095
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 15:
# Action taken: 1
# cart position: 0.05201010778546333
# cart velocity: 0.1835547536611557
# pole angle: 0.019959131255745888
# pole angular velocity: -0.1526564508676529
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 16:
# Action taken: 0
# cart position: 0.05568120628595352
# cart velocity: -0.011847210116684437
# pole angle: 0.016906002536416054
# pole angular velocity: 0.1462557315826416
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 17:
# Action taken: 1
# cart position: 0.05544425919651985
# cart velocity: 0.18302860856056213
# pole angle: 0.019831117242574692
# pole angular velocity: -0.14104610681533813
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 18:
# Action taken: 0
# cart position: 0.059104833751916885
# cart velocity: -0.01237166952341795
# pole angle: 0.017010195180773735
# pole angular velocity: 0.15782664716243744
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 19:
# Action taken: 1
# cart position: 0.058857399970293045
# cart velocity: 0.18250267207622528
# pole angle: 0.020166728645563126
# pole angular velocity: -0.12944181263446808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 20:
# Action taken: 0
# cart position: 0.06250745058059692
# cart velocity: -0.012902283109724522
# pole angle: 0.017577892169356346
# pole angular velocity: 0.1695346236228943
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 21:
# Action taken: 1
# cart position: 0.062249407172203064
# cart velocity: 0.181963711977005
# pole angle: 0.020968584343791008
# pole angular velocity: -0.11755158007144928
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 22:
# Action taken: 0
# cart position: 0.06588868051767349
# cart velocity: -0.013452299870550632
# pole angle: 0.018617553636431694
# pole angular velocity: 0.18167231976985931
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 23:
# Action taken: 1
# cart position: 0.06561963260173798
# cart velocity: 0.18139836192131042
# pole angle: 0.02225099876523018
# pole angular velocity: -0.10507979243993759
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 24:
# Action taken: 0
# cart position: 0.06924760341644287
# cart velocity: -0.014035270549356937
# pole angle: 0.02014940418303013
# pole angular velocity: 0.19453935325145721
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 25:
# Action taken: 1
# cart position: 0.06896689534187317
# cart velocity: 0.18079274892807007
# pole angle: 0.024040190503001213
# pole angular velocity: -0.09171982109546661
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 26:
# Action taken: 0
# cart position: 0.07258275151252747
# cart velocity: -0.014665385708212852
# pole angle: 0.022205794230103493
# pole angular velocity: 0.20844979584217072
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 27:
# Action taken: 1
# cart position: 0.07228944450616837
# cart velocity: 0.18013212084770203
# pole angle: 0.02637479081749916
# pole angular velocity: -0.07714646309614182
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 28:
# Action taken: 0
# cart position: 0.07589208334684372
# cart velocity: -0.015357806347310543
# pole angle: 0.0248318612575531
# pole angular velocity: 0.22373972833156586
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 29:
# Action taken: 1
# cart position: 0.07558493316173553
# cart velocity: 0.17940059304237366
# pole angle: 0.029306655749678612
# pole angular velocity: -0.06100798398256302
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 30:
# Action taken: 0
# cart position: 0.07917293906211853
# cart velocity: -0.01612902618944645
# pole angle: 0.028086496517062187
# pole angular velocity: 0.24077542126178741
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 31:
# Action taken: 1
# cart position: 0.07885035872459412
# cart velocity: 0.17858068645000458
# pole angle: 0.032902006059885025
# pole angular velocity: -0.04291761294007301
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 32:
# Action taken: 0
# cart position: 0.08242197334766388
# cart velocity: -0.016997240483760834
# pole angle: 0.03204365074634552
# pole angular velocity: 0.25996196269989014
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 33:
# Action taken: 1
# cart position: 0.08208203315734863
# cart velocity: 0.177652969956398
# pole angle: 0.037242889404296875
# pole angular velocity: -0.02244425192475319
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 34:
# Action taken: 1
# cart position: 0.08563508838415146
# cart velocity: 0.37222155928611755
# pole angle: 0.03679400682449341
# pole angular velocity: -0.30314791202545166
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 35:
# Action taken: 0
# cart position: 0.09307952225208282
# cart velocity: 0.17659509181976318
# pole angle: 0.030731048434972763
# pole angular velocity: 0.0009082172182388604
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 36:
# Action taken: 1
# cart position: 0.09661142528057098
# cart velocity: 0.37126314640045166
# pole angle: 0.030749212950468063
# pole angular velocity: -0.28192248940467834
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 37:
# Action taken: 0
# cart position: 0.10403668880462646
# cart velocity: 0.17571638524532318
# pole angle: 0.02511076256632805
# pole angular velocity: 0.020297832787036896
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 38:
# Action taken: 1
# cart position: 0.10755101591348648
# cart velocity: 0.3704693913459778
# pole angle: 0.02551671862602234
# pole angular velocity: -0.2643577754497528
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 39:
# Action taken: 0
# cart position: 0.11496040225028992
# cart velocity: 0.17499269545078278
# pole angle: 0.020229563117027283
# pole angular velocity: 0.03626289591193199
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 40:
# Action taken: 1
# cart position: 0.11846025288105011
# cart velocity: 0.3698188066482544
# pole angle: 0.02095482125878334
# pole angular velocity: -0.24996937811374664
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 41:
# Action taken: 0
# cart position: 0.12585663795471191
# cart velocity: 0.17440396547317505
# pole angle: 0.015955433249473572
# pole angular velocity: 0.04924878478050232
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 42:
# Action taken: 1
# cart position: 0.12934471666812897
# cart velocity: 0.36929354071617126
# pole angle: 0.016940409317612648
# pole angular velocity: -0.23835766315460205
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 43:
# Action taken: 0
# cart position: 0.13673058152198792
# cart velocity: 0.1739337295293808
# pole angle: 0.012173255905508995
# pole angular velocity: 0.059620246291160583
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 44:
# Action taken: 1
# cart position: 0.14020925760269165
# cart velocity: 0.3688790500164032
# pole angle: 0.013365660794079304
# pole angular velocity: -0.2291972041130066
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 45:
# Action taken: 0
# cart position: 0.14758683741092682
# cart velocity: 0.17356866598129272
# pole angle: 0.008781717158854008
# pole angular velocity: 0.06767157465219498
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 46:
# Action taken: 1
# cart position: 0.15105821192264557
# cart velocity: 0.36856362223625183
# pole angle: 0.010135148651897907
# pole angular velocity: -0.2222277969121933
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 47:
# Action taken: 0
# cart position: 0.15842948853969574
# cart velocity: 0.17329828441143036
# pole angle: 0.0056905923411250114
# pole angular velocity: 0.07363485544919968
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 48:
# Action taken: 1
# cart position: 0.16189545392990112
# cart velocity: 0.3683381974697113
# pole angle: 0.0071632894687354565
# pole angular velocity: -0.21724724769592285
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 49:
# Action taken: 0
# cart position: 0.16926221549510956
# cart velocity: 0.1731145828962326
# pole angle: 0.0028183446265757084
# pole angular velocity: 0.07768665254116058
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 50:
# Action taken: 1
# cart position: 0.17272450029850006
# cart velocity: 0.3681960105895996
# pole angle: 0.004372077994048595
# pole angular velocity: -0.2141057401895523
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 51:
# Action taken: 0
# cart position: 0.18008843064308167
# cart velocity: 0.17301182448863983
# pole angle: 8.996292308438569e-05
# pole angular velocity: 0.07995311915874481
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 52:
# Action taken: 1
# cart position: 0.18354865908622742
# cart velocity: 0.36813250184059143
# pole angle: 0.0016890253173187375
# pole angular velocity: -0.21270142495632172
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 53:
# Action taken: 0
# cart position: 0.19091130793094635
# cart velocity: 0.17298643290996552
# pole angle: -0.0025650030001997948
# pole angular velocity: 0.08051382750272751
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 54:
# Action taken: 1
# cart position: 0.1943710446357727
# cart velocity: 0.36814504861831665
# pole angle: -0.0009547265945002437
# pole angular velocity: -0.21297726035118103
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 55:
# Action taken: 0
# cart position: 0.20173394680023193
# cart velocity: 0.17303676903247833
# pole angle: -0.005214272066950798
# pole angular velocity: 0.07940434664487839
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 56:
# Action taken: 1
# cart position: 0.20519468188285828
# cart velocity: 0.3682330846786499
# pole angle: -0.00362618500366807
# pole angular velocity: -0.21491912007331848
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 57:
# Action taken: 0
# cart position: 0.21255934238433838
# cart velocity: 0.17316316068172455
# pole angle: -0.00792456790804863
# pole angular velocity: 0.07661774009466171
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 58:
# Action taken: 1
# cart position: 0.21602259576320648
# cart velocity: 0.3683978021144867
# pole angle: -0.006392212584614754
# pole angular velocity: -0.21855483949184418
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 59:
# Action taken: 0
# cart position: 0.22339056432247162
# cart velocity: 0.17336781322956085
# pole angle: -0.010763309895992279
# pole angular velocity: 0.07210487127304077
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 60:
# Action taken: 1
# cart position: 0.22685791552066803
# cart velocity: 0.3686424195766449
# pole angle: -0.009321211837232113
# pole angular velocity: -0.22395439445972443
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 61:
# Action taken: 0
# cart position: 0.23423075675964355
# cart velocity: 0.17365491390228271
# pole angle: -0.013800300657749176
# pole angular velocity: 0.06577374041080475
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 62:
# Action taken: 1
# cart position: 0.2377038598060608
# cart velocity: 0.36897197365760803
# pole angle: -0.01248482521623373
# pole angular velocity: -0.23123112320899963
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 63:
# Action taken: 0
# cart position: 0.2450833022594452
# cart velocity: 0.1740306317806244
# pole angle: -0.017109448090195656
# pole angular velocity: 0.05748767405748367
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 64:
# Action taken: 1
# cart position: 0.24856391549110413
# cart velocity: 0.3693936765193939
# pole angle: -0.015959694981575012
# pole angular velocity: -0.240543931722641
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 65:
# Action taken: 0
# cart position: 0.25595179200172424
# cart velocity: 0.17450329661369324
# pole angle: -0.020770572125911713
# pole angular velocity: 0.047062452882528305
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 66:
# Action taken: 0
# cart position: 0.2594418525695801
# cart velocity: -0.020314758643507957
# pole angle: -0.019829323515295982
# pole angular velocity: 0.3331203758716583
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 67:
# Action taken: 1
# cart position: 0.25903555750846863
# cart velocity: 0.175083726644516
# pole angle: -0.013166915625333786
# pole angular velocity: 0.034250836819410324
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 68:
# Action taken: 0
# cart position: 0.26253724098205566
# cart velocity: -0.019846951588988304
# pole angle: -0.012481899000704288
# pole angular velocity: 0.3227505385875702
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 69:
# Action taken: 1
# cart position: 0.26214030385017395
# cart velocity: 0.17545048892498016
# pole angle: -0.006026888266205788
# pole angular velocity: 0.026157619431614876
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 70:
# Action taken: 0
# cart position: 0.26564928889274597
# cart velocity: -0.01958450861275196
# pole angle: -0.005503735970705748
# pole angular velocity: 0.31693291664123535
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 71:
# Action taken: 1
# cart position: 0.2652575969696045
# cart velocity: 0.17561540007591248
# pole angle: 0.0008349224226549268
# pole angular velocity: 0.022519398480653763
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 72:
# Action taken: 0
# cart position: 0.26876991987228394
# cart velocity: -0.019518515095114708
# pole angle: 0.0012853103689849377
# pole angular velocity: 0.31546562910079956
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 73:
# Action taken: 1
# cart position: 0.2683795392513275
# cart velocity: 0.17558510601520538
# pole angle: 0.007594623137265444
# pole angular velocity: 0.023188330233097076
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 74:
# Action taken: 0
# cart position: 0.2718912661075592
# cart velocity: -0.019644932821393013
# pole angle: 0.008058389648795128
# pole angular velocity: 0.31825774908065796
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 75:
# Action taken: 1
# cart position: 0.27149835228919983
# cart velocity: 0.17536132037639618
# pole angle: 0.014423544518649578
# pole angular velocity: 0.028126990422606468
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 76:
# Action taken: 1
# cart position: 0.275005578994751
# cart velocity: 0.37027350068092346
# pole angle: 0.014986083842813969
# pole angular velocity: -0.259970486164093
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 77:
# Action taken: 0
# cart position: 0.28241103887557983
# cart velocity: 0.17494085431098938
# pole angle: 0.009786674752831459
# pole angular velocity: 0.03740133345127106
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 78:
# Action taken: 1
# cart position: 0.28590986132621765
# cart velocity: 0.36992108821868896
# pole angle: 0.010534701868891716
# pole angular velocity: -0.25217780470848083
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 79:
# Action taken: 0
# cart position: 0.293308287858963
# cart velocity: 0.17465031147003174
# pole angle: 0.005491145420819521
# pole angular velocity: 0.04380926489830017
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 80:
# Action taken: 1
# cart position: 0.29680129885673523
# cart velocity: 0.3696931004524231
# pole angle: 0.006367330439388752
# pole angular velocity: -0.24713611602783203
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 81:
# Action taken: 0
# cart position: 0.3041951656341553
# cart velocity: 0.17448079586029053
# pole angle: 0.0014246084028854966
# pole angular velocity: 0.04754839837551117
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 82:
# Action taken: 1
# cart position: 0.3076847791671753
# cart velocity: 0.36958229541778564
# pole angle: 0.002375576412305236
# pole angular velocity: -0.24468471109867096
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 83:
# Action taken: 0
# cart position: 0.31507641077041626
# cart velocity: 0.17442648112773895
# pole angle: -0.002518117893487215
# pole angular velocity: 0.04874658212065697
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 84:
# Action taken: 1
# cart position: 0.3185649514198303
# cart velocity: 0.36958444118499756
# pole angle: -0.0015431861393153667
# pole angular velocity: -0.24472977221012115
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 85:
# Action taken: 0
# cart position: 0.32595664262771606
# cart velocity: 0.17448458075523376
# pole angle: -0.0064377812668681145
# pole angular velocity: 0.04746600240468979
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 86:
# Action taken: 0
# cart position: 0.32944631576538086
# cart velocity: -0.020544471219182014
# pole angle: -0.005488461349159479
# pole angular velocity: 0.3381108045578003
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 87:
# Action taken: 1
# cart position: 0.3290354311466217
# cart velocity: 0.17465515434741974
# pole angle: 0.0012737549841403961
# pole angular velocity: 0.043702200055122375
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 88:
# Action taken: 0
# cart position: 0.3325285315513611
# cart velocity: -0.0204850435256958
# pole angle: 0.002147798892110586
# pole angular velocity: 0.33678674697875977
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 89:
# Action taken: 1
# cart position: 0.33211883902549744
# cart velocity: 0.17460627853870392
# pole angle: 0.008883533999323845
# pole angular velocity: 0.0447818823158741
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 90:
# Action taken: 1
# cart position: 0.335610955953598
# cart velocity: 0.36959972977638245
# pole angle: 0.009779171086847782
# pole angular velocity: -0.24508501589298248
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 91:
# Action taken: 0
# cart position: 0.34300297498703003
# cart velocity: 0.17433947324752808
# pole angle: 0.004877470899373293
# pole angular velocity: 0.05066638067364693
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 92:
# Action taken: 1
# cart position: 0.3464897572994232
# cart velocity: 0.36939114332199097
# pole angle: 0.0058907982893288136
# pole angular velocity: -0.2404736876487732
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 93:
# Action taken: 0
# cart position: 0.35387757420539856
# cart velocity: 0.17418554425239563
# pole angle: 0.0010813247645273805
# pole angular velocity: 0.05406152829527855
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 94:
# Action taken: 1
# cart position: 0.3573612868785858
# cart velocity: 0.3692919611930847
# pole angle: 0.0021625554654747248
# pole angular velocity: -0.2382800430059433
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 95:
# Action taken: 0
# cart position: 0.36474713683128357
# cart velocity: 0.17413920164108276
# pole angle: -0.002603045431897044
# pole angular velocity: 0.055084239691495895
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 96:
# Action taken: 0
# cart position: 0.3682298958301544
# cart velocity: -0.020945336669683456
# pole angle: -0.0015013605589047074
# pole angular velocity: 0.34694474935531616
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 97:
# Action taken: 1
# cart position: 0.367810994386673
# cart velocity: 0.1741979420185089
# pole angle: 0.005437534302473068
# pole angular velocity: 0.053788766264915466
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 98:
# Action taken: 1
# cart position: 0.37129494547843933
# cart velocity: 0.36924150586128235
# pole angle: 0.0065133096650242805
# pole angular velocity: -0.2371736317873001
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 99:
# Action taken: 0
# cart position: 0.3786797821521759
# cart velocity: 0.17402710020542145
# pole angle: 0.001769837224856019
# pole angular velocity: 0.05755665525794029
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 100:
# Action taken: 1
# cart position: 0.38216033577919006
# cart velocity: 0.369123637676239
# pole angle: 0.002920970320701599
# pole angular velocity: -0.23456734418869019
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 101:
# Action taken: 0
# cart position: 0.389542818069458
# cart velocity: 0.17396007478237152
# pole angle: -0.001770376693457365
# pole angular velocity: 0.05903550982475281
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 102:
# Action taken: 0
# cart position: 0.39302200078964233
# cart velocity: -0.02113644964993
# pole angle: -0.0005896664224565029
# pole angular velocity: 0.35115933418273926
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 103:
# Action taken: 1
# cart position: 0.39259928464889526
# cart velocity: 0.17399388551712036
# pole angle: 0.006433520466089249
# pole angular velocity: 0.05829053744673729
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 104:
# Action taken: 1
# cart position: 0.3960791528224945
# cart velocity: 0.36902299523353577
# pole angle: 0.007599330972880125
# pole angular velocity: -0.23235563933849335
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 105:
# Action taken: 0
# cart position: 0.4034596085548401
# cart velocity: 0.17379328608512878
# pole angle: 0.0029522182885557413
# pole angular velocity: 0.06271464377641678
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 106:
# Action taken: 1
# cart position: 0.4069354832172394
# cart velocity: 0.3688727915287018
# pole angle: 0.004206511192023754
# pole angular velocity: -0.2290353775024414
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 107:
# Action taken: 0
# cart position: 0.4143129289150238
# cart velocity: 0.17369098961353302
# pole angle: -0.0003741964465007186
# pole angular velocity: 0.0649714544415474
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 108:
# Action taken: 0
# cart position: 0.41778674721717834
# cart velocity: -0.021425601094961166
# pole angle: 0.0009252326563000679
# pole angular velocity: 0.35753628611564636
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 109:
# Action taken: 1
# cart position: 0.41735824942588806
# cart velocity: 0.17368318140506744
# pole angle: 0.008075959049165249
# pole angular velocity: 0.06514526158571243
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 110:
# Action taken: 1
# cart position: 0.42083191871643066
# cart velocity: 0.3686884343624115
# pole angle: 0.009378863498568535
# pole angular velocity: -0.2249787449836731
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 111:
# Action taken: 0
# cart position: 0.428205668926239
# cart velocity: 0.17343369126319885
# pole angle: 0.004879288841038942
# pole angular velocity: 0.07064781337976456
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 112:
# Action taken: 1
# cart position: 0.43167436122894287
# cart velocity: 0.36848536133766174
# pole angle: 0.006292244885116816
# pole angular velocity: -0.2204916924238205
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 113:
# Action taken: 0
# cart position: 0.4390440583229065
# cart velocity: 0.17327402532100677
# pole angle: 0.0018824111903086305
# pole angular velocity: 0.07416940480470657
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 114:
# Action taken: 1
# cart position: 0.4425095319747925
# cart velocity: 0.3683689534664154
# pole angle: 0.003365799318999052
# pole angular velocity: -0.2179190218448639
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 115:
# Action taken: 0
# cart position: 0.44987690448760986
# cart velocity: 0.17319904267787933
# pole angle: -0.0009925810154527426
# pole angular velocity: 0.07582372426986694
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 116:
# Action taken: 1
# cart position: 0.45334088802337646
# cart velocity: 0.36833521723747253
# pole angle: 0.0005238934536464512
# pole angular velocity: -0.21717220544815063
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 117:
# Action taken: 0
# cart position: 0.4607076048851013
# cart velocity: 0.17320576310157776
# pole angle: -0.003819550620391965
# pole angular velocity: 0.07567593455314636
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 118:
# Action taken: 0
# cart position: 0.46417170763015747
# cart velocity: -0.02186121977865696
# pole angle: -0.0023060317616909742
# pole angular velocity: 0.3671513497829437
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 119:
# Action taken: 1
# cart position: 0.4637344777584076
# cart velocity: 0.17329342663288116
# pole angle: 0.005036994814872742
# pole angular velocity: 0.07374218106269836
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 120:
# Action taken: 1
# cart position: 0.467200368642807
# cart velocity: 0.3683428168296814
# pole angle: 0.006511838641017675
# pole angular velocity: -0.21734730899333954
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 121:
# Action taken: 0
# cart position: 0.4745672047138214
# cart velocity: 0.17312836647033691
# pole angle: 0.0021648923866450787
# pole angular velocity: 0.07738259434700012
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 122:
# Action taken: 1
# cart position: 0.4780297875404358
# cart velocity: 0.3682192265987396
# pole angle: 0.0037125442177057266
# pole angular velocity: -0.21461650729179382
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 123:
# Action taken: 0
# cart position: 0.4853941798210144
# cart velocity: 0.1730443835258484
# pole angle: -0.0005797860212624073
# pole angular velocity: 0.07923520356416702
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 124:
# Action taken: 0
# cart position: 0.4888550639152527
# cart velocity: -0.02206924557685852
# pole angle: 0.0010049180127680302
# pole angular velocity: 0.371735155582428
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 125:
# Action taken: 1
# cart position: 0.48841366171836853
# cart velocity: 0.17303840816020966
# pole angle: 0.008439620956778526
# pole angular velocity: 0.07936924695968628
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 126:
# Action taken: 1
# cart position: 0.49187442660331726
# cart velocity: 0.3680383861064911
# pole angle: 0.010027006268501282
# pole angular velocity: -0.21063904464244843
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 127:
# Action taken: 0
# cart position: 0.49923521280288696
# cart velocity: 0.17277449369430542
# pole angle: 0.005814224947243929
# pole angular velocity: 0.08518993109464645
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 128:
# Action taken: 1
# cart position: 0.5026906728744507
# cart velocity: 0.3678126335144043
# pole angle: 0.00751802371814847
# pole angular velocity: -0.20565295219421387
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 129:
# Action taken: 0
# cart position: 0.5100469589233398
# cart velocity: 0.17258398234844208
# pole angle: 0.003404964692890644
# pole angular velocity: 0.0893920287489891
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 130:
# Action taken: 1
# cart position: 0.5134986042976379
# cart velocity: 0.367656946182251
# pole angle: 0.005192805081605911
# pole angular velocity: -0.20221468806266785
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 131:
# Action taken: 0
# cart position: 0.5208517909049988
# cart velocity: 0.1724611222743988
# pole angle: 0.0011485115392133594
# pole angular velocity: 0.09210179001092911
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 132:
# Action taken: 1
# cart position: 0.5243009924888611
# cart velocity: 0.3675665855407715
# pole angle: 0.0029905473347753286
# pole angular velocity: -0.2002185583114624
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 133:
# Action taken: 0
# cart position: 0.5316523313522339
# cart velocity: 0.1724020093679428
# pole angle: -0.0010138239013031125
# pole angular velocity: 0.09340624511241913
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 134:
# Action taken: 1
# cart position: 0.5351003408432007
# cart velocity: 0.3675384819507599
# pole angle: 0.0008543009171262383
# pole angular velocity: -0.1995963752269745
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 135:
# Action taken: 0
# cart position: 0.5424511432647705
# cart velocity: 0.17240430414676666
# pole angle: -0.003137626452371478
# pole angular velocity: 0.0933559238910675
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 136:
# Action taken: 0
# cart position: 0.5458992123603821
# cart velocity: -0.02267252840101719
# pole angle: -0.001270508044399321
# pole angular velocity: 0.3850472867488861
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 137:
# Action taken: 1
# cart position: 0.5454457402229309
# cart velocity: 0.172467440366745
# pole angle: 0.006430437788367271
# pole angular velocity: 0.09196404367685318
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 138:
# Action taken: 1
# cart position: 0.5488951206207275
# cart velocity: 0.36749663949012756
# pole angle: 0.008269717916846275
# pole angular velocity: -0.19868317246437073
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 139:
# Action taken: 0
# cart position: 0.5562450289726257
# cart velocity: 0.17225737869739532
# pole angle: 0.0042960550636053085
# pole angular velocity: 0.09659696370363235
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 140:
# Action taken: 1
# cart position: 0.5596901774406433
# cart velocity: 0.3673174977302551
# pole angle: 0.006227994337677956
# pole angular velocity: -0.19472748041152954
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 141:
# Action taken: 0
# cart position: 0.5670365691184998
# cart velocity: 0.1721070110797882
# pole angle: 0.0023334447760134935
# pole angular velocity: 0.099913589656353
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 142:
# Action taken: 1
# cart position: 0.5704786777496338
# cart velocity: 0.3671954572200775
# pole angle: 0.004331716801971197
# pole angular velocity: -0.19203223288059235
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 143:
# Action taken: 0
# cart position: 0.5778226256370544
# cart velocity: 0.17201179265975952
# pole angle: 0.0004910720163024962
# pole angular velocity: 0.10201402008533478
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 144:
# Action taken: 1
# cart position: 0.5812628269195557
# cart velocity: 0.3671267032623291
# pole angle: 0.0025313524529337883
# pole angular velocity: -0.19051393866539001
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 145:
# Action taken: 0
# cart position: 0.5886053442955017
# cart velocity: 0.17196863889694214
# pole angle: -0.0012789262691512704
# pole angular velocity: 0.10296645760536194
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 146:
# Action taken: 1
# cart position: 0.5920447111129761
# cart velocity: 0.36710888147354126
# pole angle: 0.0007804028573445976
# pole angular velocity: -0.1901196986436844
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 147:
# Action taken: 0
# cart position: 0.5993869304656982
# cart velocity: 0.171975776553154
# pole angle: -0.0030219911132007837
# pole angular velocity: 0.10280931740999222
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 148:
# Action taken: 0
# cart position: 0.6028264164924622
# cart velocity: -0.02310273051261902
# pole angle: -0.0009658047929406166
# pole angular velocity: 0.3945372700691223
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 149:
# Action taken: 1
# cart position: 0.6023643612861633
# cart velocity: 0.1720329076051712
# pole angle: 0.00692494073882699
# pole angular velocity: 0.10155001282691956
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 150:
# Action taken: 1
# cart position: 0.6058050394058228
# cart velocity: 0.36705493927001953
# pole angle: 0.008955941535532475
# pole angular velocity: -0.18894009292125702
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 151:
# Action taken: 0
# cart position: 0.6131461262702942
# cart velocity: 0.17180600762367249
# pole angle: 0.005177139304578304
# pole angular velocity: 0.1065545603632927
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 152:
# Action taken: 1
# cart position: 0.6165822744369507
# cart velocity: 0.36685338616371155
# pole angle: 0.007308230269700289
# pole angular velocity: -0.18449051678180695
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 153:
# Action taken: 0
# cart position: 0.6239193081855774
# cart velocity: 0.17162764072418213
# pole angle: 0.0036184201017022133
# pole angular velocity: 0.1104888916015625
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 154:
# Action taken: 1
# cart position: 0.6273518800735474
# cart velocity: 0.3666975498199463
# pole angle: 0.005828198045492172
# pole angular velocity: -0.18105025589466095
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 155:
# Action taken: 0
# cart position: 0.6346858143806458
# cart velocity: 0.17149269580841064
# pole angle: 0.00220719282515347
# pole angular velocity: 0.11346554756164551
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 156:
# Action taken: 1
# cart position: 0.6381157040596008
# cart velocity: 0.3665829300880432
# pole angle: 0.004476503934711218
# pole angular velocity: -0.17852020263671875
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 157:
# Action taken: 0
# cart position: 0.645447313785553
# cart velocity: 0.17139722406864166
# pole angle: 0.0009060997399501503
# pole angular velocity: 0.1155715361237526
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 158:
# Action taken: 1
# cart position: 0.6488752961158752
# cart velocity: 0.3665061891078949
# pole angle: 0.0032175304368138313
# pole angular velocity: -0.1768253892660141
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 159:
# Action taken: 0
# cart position: 0.656205415725708
# cart velocity: 0.17133831977844238
# pole angle: -0.0003189772251062095
# pole angular velocity: 0.11687082797288895
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 160:
# Action taken: 1
# cart position: 0.65963214635849
# cart velocity: 0.36646485328674316
# pole angle: 0.0020184393506497145
# pole angular velocity: -0.17591272294521332
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 161:
# Action taken: 0
# cart position: 0.6669614911079407
# cart velocity: 0.1713140606880188
# pole angle: -0.0014998151455074549
# pole angular velocity: 0.11740627139806747
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 162:
# Action taken: 0
# cart position: 0.6703877449035645
# cart velocity: -0.023786362260580063
# pole angle: 0.000848310359288007
# pole angular velocity: 0.4096156358718872
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 163:
# Action taken: 1
# cart position: 0.6699120402336121
# cart velocity: 0.17132355272769928
# pole angle: 0.009040622971951962
# pole angular velocity: 0.11720028519630432
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 164:
# Action taken: 1
# cart position: 0.6733384728431702
# cart velocity: 0.3663147985935211
# pole angle: 0.011384628713130951
# pole angular velocity: -0.17261675000190735
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 165:
# Action taken: 0
# cart position: 0.6806647777557373
# cart velocity: 0.17103178799152374
# pole angle: 0.00793229416012764
# pole angular velocity: 0.12363582104444504
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 166:
# Action taken: 1
# cart position: 0.6840854287147522
# cart velocity: 0.3660391867160797
# pole angle: 0.010405010543763638
# pole angular velocity: -0.16653403639793396
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 167:
# Action taken: 0
# cart position: 0.6914061903953552
# cart velocity: 0.17076987028121948
# pole angle: 0.007074330002069473
# pole angular velocity: 0.12941312789916992
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 168:
# Action taken: 1
# cart position: 0.6948215961456299
# cart velocity: 0.3657897710800171
# pole angle: 0.00966259278357029
# pole angular velocity: -0.16102956235408783
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 169:
# Action taken: 0
# cart position: 0.7021374106407166
# cart velocity: 0.17053082585334778
# pole angle: 0.0064420015551149845
# pole angular velocity: 0.1346859335899353
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 170:
# Action taken: 1
# cart position: 0.7055480480194092
# cart velocity: 0.3655599057674408
# pole angle: 0.009135720320045948
# pole angular velocity: -0.1559576839208603
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 171:
# Action taken: 0
# cart position: 0.7128592133522034
# cart velocity: 0.17030835151672363
# pole angle: 0.006016566418111324
# pole angular velocity: 0.13959328830242157
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 172:
# Action taken: 1
# cart position: 0.7162653803825378
# cart velocity: 0.3653436303138733
# pole angle: 0.008808432146906853
# pole angular velocity: -0.15118545293807983
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 173:
# Action taken: 0
# cart position: 0.7235722541809082
# cart velocity: 0.17009665071964264
# pole angle: 0.005784722976386547
# pole angular velocity: 0.14426326751708984
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 174:
# Action taken: 1
# cart position: 0.7269741892814636
# cart velocity: 0.3651352822780609
# pole angle: 0.008669988252222538
# pole angular velocity: -0.14658908545970917
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 175:
# Action taken: 0
# cart position: 0.7342768907546997
# cart velocity: 0.16989025473594666
# pole angle: 0.005738206673413515
# pole angular velocity: 0.14881640672683716
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 176:
# Action taken: 1
# cart position: 0.7376747131347656
# cart velocity: 0.36492955684661865
# pole angle: 0.008714534342288971
# pole angular velocity: -0.14205072820186615
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 177:
# Action taken: 0
# cart position: 0.7449733018875122
# cart velocity: 0.16968390345573425
# pole angle: 0.005873520392924547
# pole angular velocity: 0.15336869657039642
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 178:
# Action taken: 1
# cart position: 0.7483669519424438
# cart velocity: 0.36472126841545105
# pole angle: 0.008940894156694412
# ...
# pole angular velocity: 0.12471092492341995
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 226:
# Action taken: 1
# cart position: 1.05989408493042
# cart velocity: 0.7285293936729431
# pole angle: 0.08682812005281448
# pole angular velocity: -0.1402193307876587
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 227:
# Action taken: 0
# cart position: 1.0744646787643433
# cart velocity: 0.5322781205177307
# pole angle: 0.08402372896671295
# pole angular velocity: 0.1785440295934677
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 228:
# Action taken: 1
# cart position: 1.0851103067398071
# cart velocity: 0.7261034250259399
# pole angle: 0.08759461343288422
# pole angular velocity: -0.0864943116903305
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 229:
# Action taken: 0
# cart position: 1.0996323823928833
# cart velocity: 0.52984219789505
# pole angle: 0.08586472272872925
# pole angular velocity: 0.2324887365102768
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 230:
# Action taken: 1
# cart position: 1.1102291345596313
# cart velocity: 0.7236389517784119
# pole angle: 0.09051449596881866
# pole angular velocity: -0.03192228823900223
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 231:
# Action taken: 0
# cart position: 1.124701976776123
# cart velocity: 0.5273434519767761
# pole angle: 0.08987605571746826
# pole angular velocity: 0.28789061307907104
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 232:
# Action taken: 1
# cart position: 1.1352487802505493
# cart velocity: 0.7210764288902283
# pole angle: 0.095633864402771
# pole angular velocity: 0.02485203556716442
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 233:
# Action taken: 1
# cart position: 1.1496703624725342
# cart velocity: 0.9147060513496399
# pole angle: 0.09613090753555298
# pole angular velocity: -0.2361917495727539
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 234:
# Action taken: 0
# cart position: 1.1679644584655762
# cart velocity: 0.7183515429496765
# pole angle: 0.09140707552433014
# pole angular velocity: 0.08519919216632843
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 235:
# Action taken: 1
# cart position: 1.1823315620422363
# cart velocity: 0.9120523929595947
# pole angle: 0.093111053109169
# pole angular velocity: -0.17730289697647095
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 236:
# Action taken: 0
# cart position: 1.2005726099014282
# cart velocity: 0.715729832649231
# pole angle: 0.08956500142812729
# pole angular velocity: 0.14324045181274414
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 237:
# Action taken: 1
# cart position: 1.2148871421813965
# cart velocity: 0.909462571144104
# pole angle: 0.09242980927228928
# pole angular velocity: -0.11989688128232956
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 238:
# Action taken: 0
# cart position: 1.2330764532089233
# cart velocity: 0.7131462097167969
# pole angle: 0.09003186970949173
# pole angular velocity: 0.20045630633831024
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 239:
# Action taken: 1
# cart position: 1.2473393678665161
# cart velocity: 0.9068728685379028
# pole angle: 0.09404099732637405
# pole angular velocity: -0.06252314150333405
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 240:
# Action taken: 0
# cart position: 1.2654768228530884
# cart velocity: 0.7105371952056885
# pole angle: 0.09279052913188934
# pole angular velocity: 0.25828638672828674
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 241:
# Action taken: 1
# cart position: 1.279687523841858
# cart velocity: 0.9042204022407532
# pole angle: 0.09795626252889633
# pole angular velocity: -0.0037472788244485855
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 242:
# Action taken: 1
# cart position: 1.29777193069458
# cart velocity: 1.097810983657837
# pole angle: 0.09788131713867188
# pole angular velocity: -0.2639879882335663
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 243:
# Action taken: 0
# cart position: 1.319728136062622
# cart velocity: 0.9014381170272827
# pole angle: 0.09260155260562897
# pole angular velocity: 0.05789259821176529
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 244:
# Action taken: 1
# cart position: 1.337756872177124
# cart velocity: 1.095118761062622
# pole angle: 0.09375941008329391
# pole angular velocity: -0.20419763028621674
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 245:
# Action taken: 0
# cart position: 1.3596593141555786
# cart velocity: 0.8987897038459778
# pole angle: 0.08967545628547668
# pole angular velocity: 0.11652730405330658
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 246:
# Action taken: 1
# cart position: 1.37763512134552
# cart velocity: 1.092519998550415
# pole angle: 0.09200599789619446
# pole angular velocity: -0.14657115936279297
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 247:
# Action taken: 0
# cart position: 1.399485468864441
# cart velocity: 0.8962091207504272
# pole angle: 0.08907457441091537
# pole angular velocity: 0.1736612468957901
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 248:
# Action taken: 1
# cart position: 1.4174096584320068
# cart velocity: 1.0899507999420166
# pole angle: 0.09254780411720276
# pole angular velocity: -0.08964581042528152
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 249:
# Action taken: 0
# cart position: 1.439208745956421
# cart velocity: 0.8936325311660767
# pole angle: 0.09075488895177841
# pole angular velocity: 0.23074157536029816
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 250:
# Action taken: 1
# cart position: 1.4570813179016113
# cart velocity: 1.0873483419418335
# pole angle: 0.09536971896886826
# pole angular velocity: -0.03199099004268646
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 251:
# Action taken: 0
# cart position: 1.4788283109664917
# cart velocity: 0.8909972906112671
# pole angle: 0.09472990036010742
# pole angular velocity: 0.28919339179992676
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 252:
# Action taken: 1
# cart position: 1.4966483116149902
# cart velocity: 1.0846498012542725
# pole angle: 0.1005137637257576
# pole angular velocity: 0.027826040983200073
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 253:
# Action taken: 1
# cart position: 1.518341302871704
# cart velocity: 1.2781974077224731
# pole angle: 0.10107028484344482
# pole angular velocity: -0.23152872920036316
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 254:
# Action taken: 0
# cart position: 1.5439051389694214
# cart velocity: 1.081787347793579
# pole angle: 0.09643971174955368
# pole angular velocity: 0.09124689549207687
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 255:
# Action taken: 1
# cart position: 1.5655409097671509
# cart velocity: 1.2754042148590088
# pole angle: 0.0982646495103836
# pole angular velocity: -0.16951951384544373
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 256:
# Action taken: 0
# cart position: 1.591049075126648
# cart velocity: 1.0790231227874756
# pole angle: 0.09487425535917282
# pole angular velocity: 0.15247443318367004
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 257:
# Action taken: 1
# cart position: 1.6126295328140259
# cart velocity: 1.2726675271987915
# pole angle: 0.09792374819517136
# pole angular velocity: -0.10883476585149765
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 258:
# Action taken: 0
# cart position: 1.6380828619003296
# cart velocity: 1.0762887001037598
# pole angle: 0.09574705362319946
# pole angular velocity: 0.213065966963768
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 259:
# Action taken: 1
# cart position: 1.6596086025238037
# cart velocity: 1.2699205875396729
# pole angle: 0.10000836849212646
# pole angular velocity: -0.04794494807720184
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 260:
# Action taken: 0
# cart position: 1.6850069761276245
# cart velocity: 1.0735174417495728
# pole angle: 0.09904947131872177
# pole angular velocity: 0.2745412588119507
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 261:
# Action taken: 1
# cart position: 1.706477403640747
# cart velocity: 1.2670968770980835
# pole angle: 0.10454029589891434
# pole angular velocity: 0.014668229967355728
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 262:
# Action taken: 1
# cart position: 1.7318192720413208
# cart velocity: 1.4605762958526611
# pole angle: 0.10483366250991821
# pole angular velocity: -0.24328765273094177
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 263:
# Action taken: 0
# cart position: 1.7610307931900024
# cart velocity: 1.2641253471374512
# pole angle: 0.09996791183948517
# pole angular velocity: 0.08053572475910187
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 264:
# Action taken: 1
# cart position: 1.7863132953643799
# cart velocity: 1.457682728767395
# pole angle: 0.10157862305641174
# pole angular velocity: -0.17900913953781128
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 265:
# Action taken: 0
# cart position: 1.8154670000076294
# cart velocity: 1.2612649202346802
# pole angle: 0.09799844026565552
# pole angular velocity: 0.14391161501407623
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 266:
# Action taken: 1
# cart position: 1.8406922817230225
# cart velocity: 1.4548567533493042
# pole angle: 0.10087667405605316
# pole angular velocity: -0.11631745100021362
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 267:
# Action taken: 0
# cart position: 1.869789481163025
# cart velocity: 1.2584450244903564
# pole angle: 0.09855032712221146
# pole angular velocity: 0.20640994608402252
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 268:
# Action taken: 1
# cart position: 1.8949583768844604
# cart velocity: 1.4520297050476074
# pole angle: 0.10267852246761322
# pole angular velocity: -0.053631220012903214
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 269:
# Action taken: 1
# cart position: 1.9239989519119263
# cart velocity: 1.6455409526824951
# pole angle: 0.10160589963197708
# pole angular velocity: -0.3122348487377167
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 270:
# Action taken: 0
# cart position: 1.9569097757339478
# cart velocity: 1.449129343032837
# pole angle: 0.09536120295524597
# pole angular velocity: 0.01068386621773243
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 271:
# Action taken: 1
# cart position: 1.9858922958374023
# cart velocity: 1.6427634954452515
# pole angle: 0.09557487815618515
# pole angular velocity: -0.25045400857925415
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 272:
# Action taken: 0
# cart position: 2.018747568130493
# cart velocity: 1.446415901184082
# pole angle: 0.09056580066680908
# pole angular velocity: 0.07077953964471817
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 273:
# Action taken: 1
# cart position: 2.047675848007202
# cart velocity: 1.6401305198669434
# pole angle: 0.09198138862848282
# pole angular velocity: -0.19201169908046722
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 274:
# Action taken: 0
# cart position: 2.0804784297943115
# cart velocity: 1.4438214302062988
# pole angle: 0.08814115822315216
# pole angular velocity: 0.12821170687675476
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 275:
# Action taken: 1
# cart position: 2.1093549728393555
# cart velocity: 1.6375772953033447
# pole angle: 0.09070538729429245
# pole angular velocity: -0.13541407883167267
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 276:
# Action taken: 0
# cart position: 2.142106533050537
# cart velocity: 1.4412811994552612
# pole angle: 0.08799710869789124
# pole angular velocity: 0.18445062637329102
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 277:
# Action taken: 1
# cart position: 2.1709320545196533
# cart velocity: 1.6350409984588623
# pole angle: 0.09168612211942673
# pole angular velocity: -0.07922683656215668
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 278:
# Action taken: 0
# cart position: 2.2036328315734863
# cart velocity: 1.4387325048446655
# pole angle: 0.09010158479213715
# pole angular velocity: 0.2409171313047409
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 279:
# Action taken: 1
# cart position: 2.232407569885254
# cart velocity: 1.6324595212936401
# pole angle: 0.09491992741823196
# pole angular velocity: -0.02204069308936596
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 280:
# Action taken: 1
# cart position: 2.265056848526001
# cart velocity: 1.8261011838912964
# pole angle: 0.09447911381721497
# pole angular velocity: -0.2833309769630432
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 281:
# Action taken: 0
# cart position: 2.3015787601470947
# cart velocity: 1.6297675371170044
# pole angle: 0.08881249278783798
# pole angular velocity: 0.037591587752103806
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 282:
# Action taken: 1
# cart position: 2.334174156188965
# cart velocity: 1.823511004447937
# pole angle: 0.08956432342529297
# pole angular velocity: -0.2258017659187317
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 283:
# Action taken: 0
# cart position: 2.3706443309783936
# cart velocity: 1.6272307634353638
# pole angle: 0.08504828810691833
# pole angular velocity: 0.09373519569635391
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 284:
# Action taken: 1
# cart position: 2.403188943862915
# cart velocity: 1.8210372924804688
# pole angle: 0.08692299574613571
# pole angular velocity: -0.1709497570991516
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 284.0

# %% [markdown]
# ## Report Document

# %%
obs_explanation = """\
**Observation vector (4 values):**
1. **Cart Position (m)** — horizontal position on the track (≈ -4.8 to +4.8).
2. **Cart Velocity (m/s)** — how fast the cart moves (unbounded float in practice).
3. **Pole Angle (rad)** — tilt of the pole relative to vertical (≈ -0.4189 to +0.4189 rad ≈ ±24°).
4. **Pole Angular Velocity (rad/s)** — how fast the pole is rotating (unbounded float in practice).
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- **Pole tilt exceeds ±0.4189 rad (~±24°)** → `terminated = True`
- **Cart position leaves track bounds (≈ ±4.8 m)** → `terminated = True`
- **Time limit of 500 steps is reached** → `truncated = True`
"""

with open(report_file, "w",encoding="utf-8")as f:
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Performance Summary:\n")
    f.write(f"- Total Timesteps: {model.num_timesteps}\n")
    f.write(f"- Algorithm: {type(model).__name__}\n")
    f.write(f"- Observation: {observation.tolist()}\n")
    f.write(f"- Total reward: {total_reward}\n\n")

    f.write("## Graph Interpretation:\n")
    f.write("- Training curve shows how total episode rewards increased during training.\n")
    f.write("- Evaluation curve shows the mean performance of the trained model at fixed intervals.\n")
    f.write("- A smooth upward trend in both curves indicates stable learning.\n")
    f.write("- The final rewards approaching 500 suggest the agent solved the CartPole task.\n\n")

# %% [markdown]
# ## Plotting (Evaluation Curve + Training Curve)

# %%
def generate_evaluation_curve(model, graphs_dir, num_eval_episodes=20, eval_freq=200, total_timesteps=2000):
    """
    Evaluate the model at regular intervals and plot evaluation curve.
    Evaluation curve, not recording rewards during training, evaluating trained model at fixed intervals
    Each point on graph comes from evaluate_policy(), which tests model for several episodes & averages results
    Measures performance after certain amounts of training, NOT the actual learning process

    * TLDR: graphs shows the evaluarion reward at regular timesteps during training *
    """
    rewards = []
    timesteps = []

    env = gym.make("CartPole-v1")

    for step in range(eval_freq, total_timesteps + 1, eval_freq):
        # Evaluate policy
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=num_eval_episodes, deterministic=True) #this uses the model we just trained 
        rewards.append(mean_reward)
        timesteps.append(step)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(timesteps, rewards, marker="o", label="Mean Reward (Evaluation)", color="tab:orange")
    plt.xlabel("Timesteps")
    plt.ylabel("Mean Reward over Episodes")
    plt.title("evaluation Curve (PPO on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

    # Save figure
    graph_file = graphs_dir / "evaluation_curve.png"
    plt.savefig(graph_file, dpi=200, bbox_inches="tight")
    plt.close()
    env.close()

    print(f"evaluation curve saved to {graph_file}")


generate_evaluation_curve(model, graphs_dir)
# Out:
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# evaluation curve saved to ../../documentation/cartpole/ppo-cartpole/run_2025-10-10_14-53-57/graphs/evaluation_curve.png

# %%
def plot_training_curve(monitor_dir, graphs_dir):
    """
    Plot the training learning curve based on rewards logged during training.
    The learning curve visualizes how the agent’s performance evolves over time
    by showing the total episode rewards collected during training.

    Each point on the graph corresponds to the cumulative reward obtained in a
    single training episode, as recorded automatically by the Monitor wrapper.

    This curve reflects the agent’s actual *learning process* — showing how it
    improves, stabilizes, or fluctuates in performance while training.

    * TLDR: graph shows the agent’s reward per episode DURING training (true learning progress) *
  
    """
    monitor_dir = Path(monitor_dir)

    csv_files = list(monitor_dir.glob("*.csv"))
    if not csv_files:
        raise FileNotFoundError(f"No monitor CSV found in {monitor_dir}")
    log_file = csv_files[0]  

    print(f"Found monitor file: {log_file.name}")

    df = pd.read_csv(log_file, skiprows=1)
    plt.figure(figsize=(10, 6))
    plt.plot(df["r"], label="Reward per Episode", color="tab:blue", alpha=0.7)
    plt.xlabel("Episodes")
    plt.ylabel("Total Reward")
    plt.title("Training Learning Curve (PPO on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()
    out = Path(graphs_dir) / "training_learning_curve.png"
    plt.savefig(out, dpi=200, bbox_inches="tight")
    plt.close()
    print(f"Saved training learning curve → {out}")

plot_training_curve(monitor_file, graphs_dir)
# Out:
# Found monitor file: monitor.csv
# Saved training learning curve → ../../documentation/cartpole/ppo-cartpole/run_2025-10-10_14-53-57/graphs/training_learning_curve.png

# %%
def record_demo_videos(model_file, video_dir, num_episodes=5):
    """
    Record demo videos of the PPO agent before and after training.
    - 'Before training' shows a freshly initialized PPO agent with random behavior.
    - 'After training' shows the saved trained model's performance.
    """
    # --- Baseline (Before Training) ---
    print("\nRecording baseline PPO agent episodes...")
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    baseline_model = PPO("MlpPolicy", env, verbose=0)

    baseline_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="ppo_baseline_untrained"
    )

    for ep in range(num_episodes):
        obs, info = baseline_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = baseline_model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = baseline_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Baseline Episode {ep + 1}: reward = {total_reward}")
    baseline_env.close()

    # --- Trained model (After Training) ---
    print("\nRecording trained PPO agent episodes...")
    model = PPO.load(str(model_file))
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    trained_env = RecordVideo(
        env,
        video_folder=str(video_dir),
        episode_trigger=lambda e: True,
        name_prefix="ppo_cartpole_trained"
    )

    for ep in range(num_episodes):
        obs, info = trained_env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = trained_env.step(action)
            done = terminated or truncated
            total_reward += reward
        print(f"Trained Episode {ep + 1}: reward = {total_reward}")
    trained_env.close()

record_demo_videos(model_file, video_dir)
# Out:
# Recording baseline PPO agent episodes...
# Baseline Episode 1: reward = 83.0
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/documentation/cartpole/ppo-cartpole/run_2025-10-10_14-53-57/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Baseline Episode 2: reward = 46.0
# Baseline Episode 3: reward = 64.0
# Baseline Episode 4: reward = 68.0
# Baseline Episode 5: reward = 59.0
#
# Recording trained PPO agent episodes...
# Trained Episode 1: reward = 500.0
# Trained Episode 2: reward = 306.0
# Trained Episode 3: reward = 360.0
# Trained Episode 4: reward = 500.0
# Trained Episode 5: reward = 500.0
