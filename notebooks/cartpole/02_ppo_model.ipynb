# %%
import gymnasium as gym
from pathlib import Path
from gymnasium.wrappers import RecordVideo
from datetime import datetime
from stable_baselines3 import PPO

# %%
docs_path = Path("../../documentation/cartpole/ppo-cartpole") 

run_id = datetime.now().strftime("%Y-%m-%d>%H:%M:%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "ppo_cartpole"

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array") 
env = RecordVideo(
    env,
    video_folder=str(video_dir),
    episode_trigger=lambda e: True,
    name_prefix="cartpole_random_baseline" 
)
# Out:
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/documentation/cartpole/ppo-cartpole/run_2025-10-08>11:17:59/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=1000)

model.save(str(model_file))
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | 20.9     |
# | time/              |          |
# |    fps             | 276      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------

# %%
# Reset environment
observation, info = env.reset(seed=42)

print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Action space: Discrete(2)
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Starting observation: [ 0.0273956  -0.00611216  0.03585979  0.0197368 ]
# maxiumum number of steps per episode: 500

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["cart position", "cart velocity", "pole angle", "pole angular velocity"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(action)

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}")

    for label, observe in zip(labels,observation):
        print(f"{label}: {observe}")

    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 1
# cart position: 0.02727336250245571
# cart velocity: 0.18847766518592834
# pole angle: 0.036254528909921646
# pole angular velocity: -0.26141977310180664
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 0
# cart position: 0.0310429148375988
# cart velocity: -0.007142550311982632
# pole angle: 0.03102613240480423
# pole angular velocity: 0.04247424006462097
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 1
# cart position: 0.03090006485581398
# cart velocity: 0.1875210702419281
# pole angle: 0.0318756178021431
# pole angular velocity: -0.24026045203208923
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 0
# cart position: 0.03465048596262932
# cart velocity: -0.0080413818359375
# pole angle: 0.027070408686995506
# pole angular velocity: 0.062304068356752396
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 1
# cart position: 0.03448965772986412
# cart velocity: 0.18668219447135925
# pole angle: 0.028316490352153778
# pole angular velocity: -0.22171655297279358
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 0
# cart position: 0.038223300129175186
# cart velocity: -0.008832814171910286
# pole angle: 0.02388215810060501
# pole angular velocity: 0.07976232469081879
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 7:
# Action taken: 1
# cart position: 0.03804664686322212
# cart velocity: 0.1859387904405594
# pole angle: 0.02547740563750267
# pole angular velocity: -0.20529106259346008
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 8:
# Action taken: 0
# cart position: 0.041765421628952026
# cart velocity: -0.009538063779473305
# pole angle: 0.02137158438563347
# pole angular velocity: 0.09531859308481216
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 9:
# Action taken: 1
# cart position: 0.04157466068863869
# cart velocity: 0.18527115881443024
# pole angle: 0.023277955129742622
# pole angular velocity: -0.19054575264453888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 10:
# Action taken: 0
# cart position: 0.045280084013938904
# cart velocity: -0.010175937786698341
# pole angle: 0.01946704089641571
# pole angular velocity: 0.1093885749578476
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 11:
# Action taken: 1
# cart position: 0.04507656395435333
# cart velocity: 0.18466173112392426
# pole angle: 0.02165481261909008
# pole angular velocity: -0.17708958685398102
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 12:
# Action taken: 0
# cart position: 0.04876979812979698
# cart velocity: -0.010763324797153473
# pole angle: 0.018113020807504654
# pole angular velocity: 0.12234526872634888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 13:
# Action taken: 1
# cart position: 0.04855453222990036
# cart velocity: 0.18409450352191925
# pole angle: 0.020559925585985184
# pole angular velocity: -0.16456858813762665
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 14:
# Action taken: 0
# cart position: 0.05223642289638519
# cart velocity: -0.011315638199448586
# pole angle: 0.017268553376197815
# pole angular velocity: 0.13452886044979095
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 15:
# Action taken: 1
# cart position: 0.05201010778546333
# cart velocity: 0.1835547536611557
# pole angle: 0.019959131255745888
# pole angular velocity: -0.1526564508676529
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 16:
# Action taken: 0
# cart position: 0.05568120628595352
# cart velocity: -0.011847210116684437
# pole angle: 0.016906002536416054
# pole angular velocity: 0.1462557315826416
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 17:
# Action taken: 1
# cart position: 0.05544425919651985
# cart velocity: 0.18302860856056213
# pole angle: 0.019831117242574692
# pole angular velocity: -0.14104610681533813
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 18:
# Action taken: 0
# cart position: 0.059104833751916885
# cart velocity: -0.01237166952341795
# pole angle: 0.017010195180773735
# pole angular velocity: 0.15782664716243744
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 19:
# Action taken: 1
# cart position: 0.058857399970293045
# cart velocity: 0.18250267207622528
# pole angle: 0.020166728645563126
# pole angular velocity: -0.12944181263446808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 20:
# Action taken: 0
# cart position: 0.06250745058059692
# cart velocity: -0.012902283109724522
# pole angle: 0.017577892169356346
# pole angular velocity: 0.1695346236228943
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 21:
# Action taken: 1
# cart position: 0.062249407172203064
# cart velocity: 0.181963711977005
# pole angle: 0.020968584343791008
# pole angular velocity: -0.11755158007144928
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 22:
# Action taken: 0
# cart position: 0.06588868051767349
# cart velocity: -0.013452299870550632
# pole angle: 0.018617553636431694
# pole angular velocity: 0.18167231976985931
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 23:
# Action taken: 1
# cart position: 0.06561963260173798
# cart velocity: 0.18139836192131042
# pole angle: 0.02225099876523018
# pole angular velocity: -0.10507979243993759
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 24:
# Action taken: 0
# cart position: 0.06924760341644287
# cart velocity: -0.014035270549356937
# pole angle: 0.02014940418303013
# pole angular velocity: 0.19453935325145721
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 25:
# Action taken: 1
# cart position: 0.06896689534187317
# cart velocity: 0.18079274892807007
# pole angle: 0.024040190503001213
# pole angular velocity: -0.09171982109546661
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 26:
# Action taken: 0
# cart position: 0.07258275151252747
# cart velocity: -0.014665385708212852
# pole angle: 0.022205794230103493
# pole angular velocity: 0.20844979584217072
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 27:
# Action taken: 1
# cart position: 0.07228944450616837
# cart velocity: 0.18013212084770203
# pole angle: 0.02637479081749916
# pole angular velocity: -0.07714646309614182
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 28:
# Action taken: 0
# cart position: 0.07589208334684372
# cart velocity: -0.015357806347310543
# pole angle: 0.0248318612575531
# pole angular velocity: 0.22373972833156586
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 29:
# Action taken: 1
# cart position: 0.07558493316173553
# cart velocity: 0.17940059304237366
# pole angle: 0.029306655749678612
# pole angular velocity: -0.06100798398256302
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 30:
# Action taken: 0
# cart position: 0.07917293906211853
# cart velocity: -0.01612902618944645
# pole angle: 0.028086496517062187
# pole angular velocity: 0.24077542126178741
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 31:
# Action taken: 1
# cart position: 0.07885035872459412
# cart velocity: 0.17858068645000458
# pole angle: 0.032902006059885025
# pole angular velocity: -0.04291761294007301
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 32:
# Action taken: 0
# cart position: 0.08242197334766388
# cart velocity: -0.016997240483760834
# pole angle: 0.03204365074634552
# pole angular velocity: 0.25996196269989014
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 33:
# Action taken: 1
# cart position: 0.08208203315734863
# cart velocity: 0.177652969956398
# pole angle: 0.037242889404296875
# pole angular velocity: -0.02244425192475319
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 34:
# Action taken: 0
# cart position: 0.08563508838415146
# cart velocity: -0.01798274554312229
# pole angle: 0.03679400682449341
# pole angular velocity: 0.28175270557403564
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 35:
# Action taken: 1
# cart position: 0.08527543395757675
# cart velocity: 0.17659558355808258
# pole angle: 0.042429059743881226
# pole angular velocity: 0.0008977456018328667
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 36:
# Action taken: 0
# cart position: 0.08880734443664551
# cart velocity: -0.019108368083834648
# pole angle: 0.04244701564311981
# pole angular velocity: 0.30665987730026245
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 37:
# Action taken: 1
# cart position: 0.0884251818060875
# cart velocity: 0.17538383603096008
# pole angle: 0.04858021065592766
# pole angular velocity: 0.02766004018485546
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 38:
# Action taken: 0
# cart position: 0.09193285554647446
# cart velocity: -0.020399918779730797
# pole angle: 0.049133412539958954
# pole angular velocity: 0.3352661430835724
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 39:
# Action taken: 1
# cart position: 0.09152485430240631
# cart velocity: 0.17398959398269653
# pole angle: 0.05583873763680458
# pole angular velocity: 0.05847317725419998
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 40:
# Action taken: 1
# cart position: 0.09500464797019958
# cart velocity: 0.36826831102371216
# pole angle: 0.05700819939374924
# pole angular velocity: -0.2160826325416565
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 41:
# Action taken: 0
# cart position: 0.1023700162768364
# cart velocity: 0.17237967252731323
# pole angle: 0.05268654599785805
# pole angular velocity: 0.09402430802583694
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 42:
# Action taken: 1
# cart position: 0.10581760853528976
# cart velocity: 0.3667084574699402
# pole angle: 0.05456703156232834
# pole angular velocity: -0.18158167600631714
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 43:
# Action taken: 0
# cart position: 0.11315178126096725
# cart velocity: 0.17084985971450806
# pole angle: 0.050935398787260056
# pole angular velocity: 0.12780366837978363
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 44:
# Action taken: 1
# cart position: 0.11656877398490906
# cart velocity: 0.3652065396308899
# pole angle: 0.05349147319793701
# pole angular velocity: -0.1483847051858902
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 45:
# Action taken: 0
# cart position: 0.12387290596961975
# cart velocity: 0.16936101019382477
# pole angle: 0.0505237802863121
# pole angular velocity: 0.16068238019943237
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 46:
# Action taken: 1
# cart position: 0.12726013362407684
# cart velocity: 0.36372461915016174
# pole angle: 0.05373742803931236
# pole angular velocity: -0.11564331501722336
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 47:
# Action taken: 0
# cart position: 0.13453461229801178
# cart velocity: 0.1678755134344101
# pole angle: 0.05142455920577049
# pole angular velocity: 0.1934974640607834
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 48:
# Action taken: 1
# cart position: 0.13789212703704834
# cart velocity: 0.36222556233406067
# pole angle: 0.05529450997710228
# pole angular velocity: -0.08253006637096405
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 49:
# Action taken: 0
# cart position: 0.14513663947582245
# cart velocity: 0.16635636985301971
# pole angle: 0.053643908351659775
# pole angular velocity: 0.22707299888134003
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 50:
# Action taken: 1
# cart position: 0.14846377074718475
# cart velocity: 0.360672265291214
# pole angle: 0.05818536877632141
# pole angular velocity: -0.04821784794330597
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 51:
# Action taken: 0
# cart position: 0.1556772142648697
# cart velocity: 0.1647663563489914
# pole angle: 0.05722101032733917
# pole angular velocity: 0.26224058866500854
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 52:
# Action taken: 1
# cart position: 0.15897254645824432
# cart velocity: 0.35902681946754456
# pole angle: 0.06246582418680191
# pole angular velocity: -0.011859381571412086
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 53:
# Action taken: 0
# cart position: 0.16615307331085205
# cart velocity: 0.16306722164154053
# pole angle: 0.06222863495349884
# pole angular velocity: 0.2998597323894501
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 54:
# Action taken: 1
# cart position: 0.16941441595554352
# cart velocity: 0.35724952816963196
# pole angle: 0.06822583079338074
# pole angular velocity: 0.02743345871567726
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 55:
# Action taken: 0
# cart position: 0.17655940353870392
# cart velocity: 0.16121886670589447
# pole angle: 0.0687744989991188
# pole angular velocity: 0.3408381938934326
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 56:
# Action taken: 1
# cart position: 0.17978379130363464
# cart velocity: 0.35529831051826477
# pole angle: 0.07559126615524292
# pole angular velocity: 0.07061099261045456
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 57:
# Action taken: 0
# cart position: 0.18688975274562836
# cart velocity: 0.15917861461639404
# pole angle: 0.07700348645448685
# pole angular velocity: 0.3861531615257263
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 58:
# Action taken: 1
# cart position: 0.19007332623004913
# cart velocity: 0.3531278073787689
# pole angle: 0.08472654223442078
# pole angular velocity: 0.11870814114809036
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 59:
# Action taken: 1
# cart position: 0.19713588058948517
# cart velocity: 0.54694002866745
# pole angle: 0.08710070699453354
# pole angular velocity: -0.14608758687973022
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 60:
# Action taken: 0
# cart position: 0.208074688911438
# cart velocity: 0.3506857454776764
# pole angle: 0.08417895436286926
# pole angular velocity: 0.17275317013263702
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 61:
# Action taken: 1
# cart position: 0.2150883972644806
# cart velocity: 0.5445083379745483
# pole angle: 0.08763401955366135
# pole angular velocity: -0.09223184734582901
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 62:
# Action taken: 0
# cart position: 0.2259785681962967
# cart velocity: 0.3482467234134674
# pole angle: 0.08578938245773315
# pole angular velocity: 0.22676227986812592
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 63:
# Action taken: 1
# cart position: 0.23294350504875183
# cart velocity: 0.5420445203781128
# pole angle: 0.09032462537288666
# pole angular velocity: -0.03767421469092369
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 64:
# Action taken: 0
# cart position: 0.24378439784049988
# cart velocity: 0.34575122594833374
# pole angle: 0.08957114815711975
# pole angular velocity: 0.2820848226547241
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 65:
# Action taken: 1
# cart position: 0.25069940090179443
# cart velocity: 0.5394889712333679
# pole angle: 0.09521283954381943
# pole angular velocity: 0.018941912800073624
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 66:
# Action taken: 0
# cart position: 0.2614891827106476
# cart velocity: 0.3431396484375
# pole angle: 0.09559167921543121
# pole angular velocity: 0.34008219838142395
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 67:
# Action taken: 1
# cart position: 0.2683520019054413
# cart velocity: 0.5367807149887085
# pole angle: 0.10239332169294357
# pole angular velocity: 0.07900786399841309
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 68:
# Action taken: 0
# cart position: 0.2790876030921936
# cart velocity: 0.34035131335258484
# pole angle: 0.10397347807884216
# pole angular velocity: 0.40215978026390076
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 69:
# Action taken: 1
# cart position: 0.28589463233947754
# cart velocity: 0.5338567495346069
# pole angle: 0.11201667785644531
# pole angular velocity: 0.14398233592510223
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 70:
# Action taken: 1
# cart position: 0.2965717613697052
# cart velocity: 0.727211058139801
# pole angle: 0.11489631980657578
# pole angular velocity: -0.11136740446090698
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 71:
# Action taken: 0
# cart position: 0.31111598014831543
# cart velocity: 0.5306462049484253
# pole angle: 0.112668976187706
# pole angular velocity: 0.21524108946323395
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 72:
# Action taken: 1
# cart position: 0.32172891497612
# cart velocity: 0.7239922285079956
# pole angle: 0.11697379499673843
# pole angular velocity: -0.039884429425001144
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 73:
# Action taken: 0
# cart position: 0.3362087607383728
# cart velocity: 0.5274040699005127
# pole angle: 0.11617610603570938
# pole angular velocity: 0.2872946262359619
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 74:
# Action taken: 1
# cart position: 0.34675684571266174
# cart velocity: 0.7206941246986389
# pole angle: 0.12192200124263763
# pole angular velocity: 0.03339291736483574
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 75:
# Action taken: 0
# cart position: 0.3611707091331482
# cart velocity: 0.5240538716316223
# pole angle: 0.12258985638618469
# pole angular velocity: 0.3619200587272644
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 76:
# Action taken: 1
# cart position: 0.3716517984867096
# cart velocity: 0.7172395586967468
# pole angle: 0.12982825934886932
# pole angular velocity: 0.1102675050497055
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 77:
# Action taken: 0
# cart position: 0.38599658012390137
# cart velocity: 0.5205193161964417
# pole angle: 0.13203361630439758
# pole angular velocity: 0.4409268796443939
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 78:
# Action taken: 1
# cart position: 0.39640697836875916
# cart velocity: 0.713549792766571
# pole angle: 0.140852153301239
# pole angular velocity: 0.19260646402835846
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 79:
# Action taken: 1
# cart position: 0.410677969455719
# cart velocity: 0.9064053297042847
# pole angle: 0.14470428228378296
# pole angular velocity: -0.052538204938173294
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 80:
# Action taken: 0
# cart position: 0.4288060665130615
# cart velocity: 0.7095368504524231
# pole angle: 0.1436535120010376
# pole angular velocity: 0.28207290172576904
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 81:
# Action taken: 1
# cart position: 0.4429967999458313
# cart velocity: 0.9023488163948059
# pole angle: 0.14929497241973877
# pole angular velocity: 0.03792306408286095
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 82:
# Action taken: 0
# cart position: 0.4610437750816345
# cart velocity: 0.7054364085197449
# pole angle: 0.15005342662334442
# pole angular velocity: 0.3737359046936035
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 83:
# Action taken: 1
# cart position: 0.47515252232551575
# cart velocity: 0.8981437683105469
# pole angle: 0.15752814710140228
# pole angular velocity: 0.13187332451343536
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 84:
# Action taken: 0
# cart position: 0.4931153953075409
# cart velocity: 0.7011572122573853
# pole angle: 0.16016562283039093
# pole angular velocity: 0.46981653571128845
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 85:
# Action taken: 1
# cart position: 0.5071385502815247
# cart velocity: 0.8936972618103027
# pole angle: 0.1695619523525238
# pole angular velocity: 0.23159059882164001
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 86:
# Action taken: 1
# cart position: 0.5250124931335449
# cart velocity: 1.086041808128357
# pole angle: 0.17419375479221344
# pole angular velocity: -0.0031759068369865417
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 87:
# Action taken: 0
# cart position: 0.5467333197593689
# cart velocity: 0.8889052271842957
# pole angle: 0.17413024604320526
# pole angular velocity: 0.3390083611011505
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 88:
# Action taken: 1
# cart position: 0.5645114183425903
# cart velocity: 1.0811772346496582
# pole angle: 0.1809104084968567
# pole angular velocity: 0.10589779168367386
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 89:
# Action taken: 0
# cart position: 0.5861349701881409
# cart velocity: 0.8839859962463379
# pole angle: 0.18302837014198303
# pole angular velocity: 0.44975540041923523
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 90:
# Action taken: 1
# cart position: 0.6038146615028381
# cart velocity: 1.0761115550994873
# pole angle: 0.19202347099781036
# pole angular velocity: 0.21989114582538605
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 91:
# Action taken: 0
# cart position: 0.6253368854522705
# cart velocity: 0.8788376450538635
# pole angle: 0.1964212954044342
# pole angular velocity: 0.5664717555046082
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 92:
# Action taken: 1
# cart position: 0.6429136395454407
# cart velocity: 1.070740818977356
# pole angle: 0.20775073766708374
# pole angular velocity: 0.34152936935424805
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 93:
# Action taken: 1
# cart position: 0.6643284559249878
# cart velocity: 1.2623951435089111
# pole angle: 0.21458131074905396
# pole angular velocity: 0.12086973339319229
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 93.0

# %%
obs_explanation = """\
**Observation vector (4 values):**
1. **Cart Position (m)** — horizontal position on the track (≈ -4.8 to +4.8).
2. **Cart Velocity (m/s)** — how fast the cart moves (unbounded float in practice).
3. **Pole Angle (rad)** — tilt of the pole relative to vertical (≈ -0.4189 to +0.4189 rad ≈ ±24°).
4. **Pole Angular Velocity (rad/s)** — how fast the pole is rotating (unbounded float in practice).
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- **Pole tilt exceeds ±0.4189 rad (~±24°)** → `terminated = True`
- **Cart position leaves track bounds (≈ ±4.8 m)** → `terminated = True`
- **Time limit of 500 steps is reached** → `truncated = True`
"""

with open(report_file, "w")as f:
    f.write("# SCRUM-15: Researching Cartpole test write\n\n")
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Example Run\n")
    f.write(f"- Starting observation: {observation.tolist()}\n")
    f.write(f"- Total reward: {total_reward}\n")

# %%
import matplotlib.pyplot as plt
import numpy as np
from stable_baselines3.common.evaluation import evaluate_policy

def generate_evaluation_curve(model, env, graphs_dir, num_eval_episodes=20, eval_freq=200, total_timesteps=2000):
    """
    Evaluate the model at regular intervals and plot evaluation curve.
    Evaluation curve, not recording rewards during training, evaluating trained model at fixed intervals
    Each point on graph comes from evaluate_policy(), which tests model for several episodes & averages results
    Measures performance after certain amounts of training, NOT the actual learning process

    * TLDR: graphs shows the evaluarion reward at regular timesteps during training *
    """
    rewards = []
    timesteps = []

    for step in range(eval_freq, total_timesteps + 1, eval_freq):
        # Evaluate policy
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=num_eval_episodes, deterministic=True)
        rewards.append(mean_reward)
        timesteps.append(step)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(timesteps, rewards, marker="o", label="Mean Reward")
    plt.xlabel("Timesteps")
    plt.ylabel("Mean Reward over Episodes")
    plt.title("evaluation Curve (PPO on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

    # Save figure
    graph_file = graphs_dir / "evaluation_curve.png"
    plt.savefig(graph_file, dpi=200, bbox_inches="tight")
    plt.close()

    print(f"evaluation curve saved to {graph_file}")


generate_evaluation_curve(model, env, graphs_dir, num_eval_episodes=10, eval_freq=200, total_timesteps=1000)
# Out:
# evaluation curve saved to ../../documentation/cartpole/ppo-cartpole/run_2025-10-08>11:17:59/graphs/evaluation_curve.png
