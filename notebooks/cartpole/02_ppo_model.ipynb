# %% [markdown]
# # PPO CartPole

# %%
import gymnasium as gym
from pathlib import Path
from gymnasium.wrappers import RecordVideo
from datetime import datetime
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
docs_path = Path("../../documentation/cartpole/ppo-cartpole") 

run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"
monitor_dir = run_path / "monitor"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)
monitor_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "ppo_cartpole"
monitor_file = str(monitor_dir) #/ "monitor_log.csv"

# %% [markdown]
# ## Training Model

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array") 
env = Monitor(env, monitor_file)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)
model.save(str(model_file))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | 22.4     |
# | time/              |          |
# |    fps             | 6151     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.9        |
# |    ep_rew_mean          | 25.9        |
# | time/                   |             |
# |    fps                  | 4065        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009278709 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.0157     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.24        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 53.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37          |
# |    ep_rew_mean          | 37          |
# | time/                   |             |
# |    fps                  | 3808        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009409698 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.0622      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 40.6        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 49.1      |
# |    ep_rew_mean          | 49.1      |
# | time/                   |           |
# |    fps                  | 3709      |
# |    iterations           | 4         |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0079565 |
# |    clip_fraction        | 0.0874    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.626    |
# |    explained_variance   | 0.205     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 24.7      |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -0.0198   |
# |    value_loss           | 56.3      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.2        |
# |    ep_rew_mean          | 65.2        |
# | time/                   |             |
# |    fps                  | 3672        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006760597 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.6        |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 66.4        |
# -----------------------------------------

# %%
# Reset environment
observation, info = env.reset(seed=42)
print(f"Total Timesteps:{model.num_timesteps}")
print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Total Timesteps:10240
# Action space: Discrete(2)
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Starting observation: [ 0.0273956  -0.00611216  0.03585979  0.0197368 ]
# maxiumum number of steps per episode: 500

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["cart position", "cart velocity", "pole angle", "pole angular velocity"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(action)

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}")

    for label, observe in zip(labels,observation):
        print(f"{label}: {observe}")

    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 1
# cart position: 0.02727336250245571
# cart velocity: 0.18847766518592834
# pole angle: 0.036254528909921646
# pole angular velocity: -0.26141977310180664
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 0
# cart position: 0.0310429148375988
# cart velocity: -0.007142550311982632
# pole angle: 0.03102613240480423
# pole angular velocity: 0.04247424006462097
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 1
# cart position: 0.03090006485581398
# cart velocity: 0.1875210702419281
# pole angle: 0.0318756178021431
# pole angular velocity: -0.24026045203208923
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 0
# cart position: 0.03465048596262932
# cart velocity: -0.0080413818359375
# pole angle: 0.027070408686995506
# pole angular velocity: 0.062304068356752396
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 1
# cart position: 0.03448965772986412
# cart velocity: 0.18668219447135925
# pole angle: 0.028316490352153778
# pole angular velocity: -0.22171655297279358
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 0
# cart position: 0.038223300129175186
# cart velocity: -0.008832814171910286
# pole angle: 0.02388215810060501
# pole angular velocity: 0.07976232469081879
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 7:
# Action taken: 1
# cart position: 0.03804664686322212
# cart velocity: 0.1859387904405594
# pole angle: 0.02547740563750267
# pole angular velocity: -0.20529106259346008
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 8:
# Action taken: 0
# cart position: 0.041765421628952026
# cart velocity: -0.009538063779473305
# pole angle: 0.02137158438563347
# pole angular velocity: 0.09531859308481216
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 9:
# Action taken: 1
# cart position: 0.04157466068863869
# cart velocity: 0.18527115881443024
# pole angle: 0.023277955129742622
# pole angular velocity: -0.19054575264453888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 10:
# Action taken: 0
# cart position: 0.045280084013938904
# cart velocity: -0.010175937786698341
# pole angle: 0.01946704089641571
# pole angular velocity: 0.1093885749578476
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 11:
# Action taken: 1
# cart position: 0.04507656395435333
# cart velocity: 0.18466173112392426
# pole angle: 0.02165481261909008
# pole angular velocity: -0.17708958685398102
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 12:
# Action taken: 0
# cart position: 0.04876979812979698
# cart velocity: -0.010763324797153473
# pole angle: 0.018113020807504654
# pole angular velocity: 0.12234526872634888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 13:
# Action taken: 1
# cart position: 0.04855453222990036
# cart velocity: 0.18409450352191925
# pole angle: 0.020559925585985184
# pole angular velocity: -0.16456858813762665
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 14:
# Action taken: 0
# cart position: 0.05223642289638519
# cart velocity: -0.011315638199448586
# pole angle: 0.017268553376197815
# pole angular velocity: 0.13452886044979095
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 15:
# Action taken: 1
# cart position: 0.05201010778546333
# cart velocity: 0.1835547536611557
# pole angle: 0.019959131255745888
# pole angular velocity: -0.1526564508676529
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 16:
# Action taken: 0
# cart position: 0.05568120628595352
# cart velocity: -0.011847210116684437
# pole angle: 0.016906002536416054
# pole angular velocity: 0.1462557315826416
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 17:
# Action taken: 1
# cart position: 0.05544425919651985
# cart velocity: 0.18302860856056213
# pole angle: 0.019831117242574692
# pole angular velocity: -0.14104610681533813
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 18:
# Action taken: 0
# cart position: 0.059104833751916885
# cart velocity: -0.01237166952341795
# pole angle: 0.017010195180773735
# pole angular velocity: 0.15782664716243744
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 19:
# Action taken: 1
# cart position: 0.058857399970293045
# cart velocity: 0.18250267207622528
# pole angle: 0.020166728645563126
# pole angular velocity: -0.12944181263446808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 20:
# Action taken: 0
# cart position: 0.06250745058059692
# cart velocity: -0.012902283109724522
# pole angle: 0.017577892169356346
# pole angular velocity: 0.1695346236228943
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 21:
# Action taken: 1
# cart position: 0.062249407172203064
# cart velocity: 0.181963711977005
# pole angle: 0.020968584343791008
# pole angular velocity: -0.11755158007144928
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 22:
# Action taken: 0
# cart position: 0.06588868051767349
# cart velocity: -0.013452299870550632
# pole angle: 0.018617553636431694
# pole angular velocity: 0.18167231976985931
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 23:
# Action taken: 1
# cart position: 0.06561963260173798
# cart velocity: 0.18139836192131042
# pole angle: 0.02225099876523018
# pole angular velocity: -0.10507979243993759
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 24:
# Action taken: 0
# cart position: 0.06924760341644287
# cart velocity: -0.014035270549356937
# pole angle: 0.02014940418303013
# pole angular velocity: 0.19453935325145721
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 25:
# Action taken: 1
# cart position: 0.06896689534187317
# cart velocity: 0.18079274892807007
# pole angle: 0.024040190503001213
# pole angular velocity: -0.09171982109546661
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 26:
# Action taken: 0
# cart position: 0.07258275151252747
# cart velocity: -0.014665385708212852
# pole angle: 0.022205794230103493
# pole angular velocity: 0.20844979584217072
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 27:
# Action taken: 1
# cart position: 0.07228944450616837
# cart velocity: 0.18013212084770203
# pole angle: 0.02637479081749916
# pole angular velocity: -0.07714646309614182
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 28:
# Action taken: 0
# cart position: 0.07589208334684372
# cart velocity: -0.015357806347310543
# pole angle: 0.0248318612575531
# pole angular velocity: 0.22373972833156586
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 29:
# Action taken: 1
# cart position: 0.07558493316173553
# cart velocity: 0.17940059304237366
# pole angle: 0.029306655749678612
# pole angular velocity: -0.06100798398256302
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 30:
# Action taken: 0
# cart position: 0.07917293906211853
# cart velocity: -0.01612902618944645
# pole angle: 0.028086496517062187
# pole angular velocity: 0.24077542126178741
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 31:
# Action taken: 1
# cart position: 0.07885035872459412
# cart velocity: 0.17858068645000458
# pole angle: 0.032902006059885025
# pole angular velocity: -0.04291761294007301
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 32:
# Action taken: 1
# cart position: 0.08242197334766388
# cart velocity: 0.37321576476097107
# pole angle: 0.03204365074634552
# pole angular velocity: -0.3250407576560974
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 33:
# Action taken: 0
# cart position: 0.08988629281520844
# cart velocity: 0.17765256762504578
# pole angle: 0.025542836636304855
# pole angular velocity: -0.022427339106798172
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 34:
# Action taken: 1
# cart position: 0.09343934059143066
# cart velocity: 0.37239906191825867
# pole angle: 0.02509428933262825
# pole angular velocity: -0.30694302916526794
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 35:
# Action taken: 0
# cart position: 0.10088732093572617
# cart velocity: 0.17692869901657104
# pole angle: 0.018955430015921593
# pole angular velocity: -0.00645283330231905
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 36:
# Action taken: 1
# cart position: 0.10442589968442917
# cart velocity: 0.37177374958992004
# pole angle: 0.018826372921466827
# pole angular velocity: -0.29309532046318054
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 37:
# Action taken: 0
# cart position: 0.11186137050390244
# cart velocity: 0.17638850212097168
# pole angle: 0.012964465655386448
# pole angular velocity: 0.005465216469019651
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 38:
# Action taken: 1
# cart position: 0.1153891459107399
# cart velocity: 0.3713221549987793
# pole angle: 0.013073770329356194
# pole angular velocity: -0.2830992341041565
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 39:
# Action taken: 0
# cart position: 0.1228155866265297
# cart velocity: 0.1760161817073822
# pole angle: 0.007411785423755646
# pole angular velocity: 0.013678251765668392
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 40:
# Action taken: 1
# cart position: 0.12633590400218964
# cart velocity: 0.3710310459136963
# pole angle: 0.007685350254178047
# pole angular velocity: -0.27665698528289795
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 41:
# Action taken: 0
# cart position: 0.13375653326511383
# cart velocity: 0.17580030858516693
# pole angle: 0.0021522107999771833
# pole angular velocity: 0.018439961597323418
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 42:
# Action taken: 1
# cart position: 0.13727253675460815
# cart velocity: 0.3708913326263428
# pole angle: 0.0025210101157426834
# pole angular velocity: -0.2735631465911865
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 43:
# Action taken: 0
# cart position: 0.1446903645992279
# cart velocity: 0.17573349177837372
# pole angle: -0.0029502527322620153
# pole angular velocity: 0.019913852214813232
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 44:
# Action taken: 1
# cart position: 0.14820502698421478
# cart velocity: 0.3708976209163666
# pole angle: -0.0025519756600260735
# pole angular velocity: -0.27369844913482666
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 45:
# Action taken: 0
# cart position: 0.15562298893928528
# cart velocity: 0.17581218481063843
# pole angle: -0.008025945164263248
# pole angular velocity: 0.018178483471274376
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 46:
# Action taken: 1
# cart position: 0.1591392308473587
# cart velocity: 0.37104833126068115
# pole angle: -0.007662374991923571
# pole angular velocity: -0.27702587842941284
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 47:
# Action taken: 0
# cart position: 0.16656020283699036
# cart velocity: 0.1760365217924118
# pole angle: -0.013202892616391182
# pole angular velocity: 0.0132305221632123
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 48:
# Action taken: 1
# cart position: 0.17008092999458313
# cart velocity: 0.37134531140327454
# pole angle: -0.012938282452523708
# pole angular velocity: -0.2835886478424072
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 49:
# Action taken: 0
# cart position: 0.17750783264636993
# cart velocity: 0.1764102578163147
# pole angle: -0.01861005462706089
# pole angular velocity: 0.004985686857253313
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 50:
# Action taken: 0
# cart position: 0.18103604018688202
# cart velocity: -0.018439926207065582
# pole angle: -0.01851034164428711
# pole angular velocity: 0.2917393147945404
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 51:
# Action taken: 1
# cart position: 0.1806672364473343
# cart velocity: 0.17694099247455597
# pole angle: -0.012675555422902107
# pole angular velocity: -0.0067235990427434444
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 52:
# Action taken: 0
# cart position: 0.1842060536146164
# cart velocity: -0.01799689792096615
# pole angle: -0.012810027226805687
# pole angular velocity: 0.2819332480430603
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 53:
# Action taken: 1
# cart position: 0.183846116065979
# cart velocity: 0.1773054152727127
# pole angle: -0.007171362638473511
# pole angular velocity: -0.014762232080101967
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 54:
# Action taken: 0
# cart position: 0.1873922348022461
# cart velocity: -0.017712965607643127
# pole angle: -0.007466607261449099
# pole angular velocity: 0.27564945816993713
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 55:
# Action taken: 1
# cart position: 0.18703797459602356
# cart velocity: 0.1775147169828415
# pole angle: -0.001953618600964546
# pole angular velocity: -0.01937907375395298
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 56:
# Action taken: 0
# cart position: 0.19058826565742493
# cart velocity: -0.01757916621863842
# pole angle: -0.0023411998990923166
# pole angular velocity: 0.27268683910369873
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 57:
# Action taken: 1
# cart position: 0.1902366727590561
# cart velocity: 0.17757610976696014
# pole angle: 0.003112536622211337
# pole angular velocity: -0.020733604207634926
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 58:
# Action taken: 0
# cart position: 0.19378820061683655
# cart velocity: -0.017590336501598358
# pole angle: 0.0026978643145412207
# pole angular velocity: 0.27292972803115845
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 59:
# Action taken: 1
# cart position: 0.193436399102211
# cart velocity: 0.17749302089214325
# pole angle: 0.008156458847224712
# pole angular velocity: -0.018901055678725243
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 60:
# Action taken: 0
# cart position: 0.19698625802993774
# cart velocity: -0.01774495281279087
# pole angle: 0.0077784378081560135
# pole angular velocity: 0.2763441205024719
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 61:
# Action taken: 1
# cart position: 0.19663135707378387
# cart velocity: 0.17726516723632812
# pole angle: 0.013305320404469967
# pole angular velocity: -0.01387536246329546
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 62:
# Action taken: 0
# cart position: 0.2001766562461853
# cart velocity: -0.018045049160718918
# pole angle: 0.013027813285589218
# pole angular velocity: 0.2829756736755371
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 63:
# Action taken: 1
# cart position: 0.1998157650232315
# cart velocity: 0.17688868939876556
# pole angle: 0.018687326461076736
# pole angular velocity: -0.00557003915309906
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 64:
# Action taken: 1
# cart position: 0.20335353910923004
# cart velocity: 0.3717377185821533
# pole angle: 0.01857592537999153
# pole angular velocity: -0.2922987937927246
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 65:
# Action taken: 0
# cart position: 0.2107882797718048
# cart velocity: 0.17635589838027954
# pole angle: 0.012729950249195099
# pole angular velocity: 0.006184366066008806
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 66:
# Action taken: 1
# cart position: 0.21431539952754974
# cart velocity: 0.37129300832748413
# pole angle: 0.012853637337684631
# pole angular velocity: -0.28245508670806885
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 67:
# Action taken: 0
# cart position: 0.22174125909805298
# cart velocity: 0.17599008977413177
# pole angle: 0.007204535882920027
# pole angular velocity: 0.014253951609134674
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 68:
# Action taken: 1
# cart position: 0.22526106238365173
# cart velocity: 0.3710079789161682
# pole angle: 0.007489614654332399
# pole angular velocity: -0.27614718675613403
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 69:
# Action taken: 0
# cart position: 0.23268122971057892
# cart velocity: 0.17577996850013733
# pole angle: 0.001966671319678426
# pole angular velocity: 0.018888534978032112
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 70:
# Action taken: 1
# cart position: 0.236196830868721
# cart velocity: 0.37087365984916687
# pole angle: 0.002344441832974553
# pole angular velocity: -0.2731732428073883
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 71:
# Action taken: 0
# cart position: 0.2436143010854721
# cart velocity: 0.17571833729743958
# pole angle: -0.0031190228182822466
# pole angular velocity: 0.020248211920261383
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 72:
# Action taken: 0
# cart position: 0.2471286654472351
# cart velocity: -0.019358741119503975
# pole angle: -0.002714058617129922
# pole angular velocity: 0.3119454085826874
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 73:
# Action taken: 1
# cart position: 0.24674148857593536
# cart velocity: 0.17580176889896393
# pole angle: 0.0035248498897999525
# pole angular velocity: 0.018407799303531647
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 74:
# Action taken: 1
# cart position: 0.2502575218677521
# cart velocity: 0.37087300419807434
# pole angle: 0.0038930056616663933
# pole angular velocity: -0.2731609046459198
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 75:
# Action taken: 0
# cart position: 0.2576749920845032
# cart velocity: 0.17569571733474731
# pole angle: -0.0015702125383540988
# pole angular velocity: 0.02074733003973961
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 76:
# Action taken: 0
# cart position: 0.26118889451026917
# cart velocity: -0.01940368488430977
# pole angle: -0.0011552659561857581
# pole angular velocity: 0.31293442845344543
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 77:
# Action taken: 1
# cart position: 0.260800838470459
# cart velocity: 0.17573469877243042
# pole angle: 0.005103422328829765
# pole angular velocity: 0.01988738588988781
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 78:
# Action taken: 1
# cart position: 0.26431551575660706
# cart velocity: 0.37078309059143066
# pole angle: 0.005501170177012682
# pole angular velocity: -0.27118098735809326
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 79:
# Action taken: 0
# cart position: 0.2717311978340149
# cart velocity: 0.17558307945728302
# pole angle: 7.755035039735958e-05
# pole angular velocity: 0.02323193848133087
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 80:
# Action taken: 0
# cart position: 0.2752428352832794
# cart velocity: -0.019539982080459595
# pole angle: 0.0005421891110017896
# pole angular velocity: 0.315939337015152
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 81:
# Action taken: 1
# cart position: 0.27485203742980957
# cart velocity: 0.17557424306869507
# pole angle: 0.00686097564175725
# pole angular velocity: 0.023427443578839302
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 82:
# Action taken: 1
# cart position: 0.27836352586746216
# cart velocity: 0.37059712409973145
# pole angle: 0.007329524494707584
# pole angular velocity: -0.26708289980888367
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 83:
# Action taken: 0
# cart position: 0.28577548265457153
# cart velocity: 0.17537134885787964
# pole angle: 0.001987866824492812
# pole angular velocity: 0.02790277823805809
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 84:
# Action taken: 1
# cart position: 0.289282888174057
# cart velocity: 0.3704647421836853
# pole angle: 0.0025459222961217165
# pole angular velocity: -0.26415228843688965
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 85:
# Action taken: 0
# cart position: 0.2966921925544739
# cart velocity: 0.1753065288066864
# pole angle: -0.002737123519182205
# pole angular velocity: 0.029332555830478668
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 86:
# Action taken: 0
# cart position: 0.3001983165740967
# cart velocity: -0.019776057451963425
# pole angle: -0.0021504724863916636
# pole angular velocity: 0.32115063071250916
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 87:
# Action taken: 1
# cart position: 0.2998028099536896
# cart velocity: 0.17537644505500793
# pole angle: 0.004272540099918842
# pole angular velocity: 0.027790309861302376
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 88:
# Action taken: 0
# cart position: 0.3033103346824646
# cart velocity: -0.0198065098375082
# pole angle: 0.00482834642753005
# pole angular velocity: 0.32181820273399353
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 89:
# Action taken: 1
# cart position: 0.30291420221328735
# cart velocity: 0.17524635791778564
# pole angle: 0.011264710687100887
# pole angular velocity: 0.030661847442388535
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 90:
# Action taken: 1
# cart position: 0.30641913414001465
# cart velocity: 0.37020495533943176
# pole angle: 0.011877947486937046
# pole angular velocity: -0.25844576954841614
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 91:
# Action taken: 0
# cart position: 0.31382322311401367
# cart velocity: 0.17491547763347626
# pole angle: 0.006709032226353884
# pole angular velocity: 0.03795984759926796
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 92:
# Action taken: 1
# cart position: 0.3173215389251709
# cart velocity: 0.3699405789375305
# pole angle: 0.0074682291597127914
# pole angular velocity: -0.2525987923145294
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 93:
# Action taken: 0
# cart position: 0.3247203528881073
# cart velocity: 0.17471279203891754
# pole angle: 0.002416253322735429
# pole angular velocity: 0.04243037477135658
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 94:
# Action taken: 1
# cart position: 0.3282146155834198
# cart velocity: 0.36980000138282776
# pole angle: 0.0032648607157170773
# pole angular velocity: -0.2494892179965973
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 95:
# Action taken: 0
# cart position: 0.33561059832572937
# cart velocity: 0.17463158071041107
# pole angle: -0.0017249236116185784
# pole angular velocity: 0.04422171786427498
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 96:
# Action taken: 1
# cart position: 0.33910325169563293
# cart velocity: 0.36977821588516235
# pole angle: -0.000840489286929369
# pole angular velocity: -0.24900494515895844
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 97:
# Action taken: 0
# cart position: 0.3464987874031067
# cart velocity: 0.17466828227043152
# pole angle: -0.005820588208734989
# pole angular velocity: 0.04341275990009308
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 98:
# Action taken: 0
# cart position: 0.34999215602874756
# cart velocity: -0.020369715988636017
# pole angle: -0.004952332936227322
# pole angular velocity: 0.33425357937812805
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 99:
# Action taken: 1
# cart position: 0.34958478808403015
# cart velocity: 0.1748223602771759
# pole angle: 0.0017327385721728206
# pole angular velocity: 0.04001305252313614
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 100:
# Action taken: 0
# cart position: 0.35308122634887695
# cart velocity: -0.02032438851892948
# pole angle: 0.0025329994969069958
# pole angular velocity: 0.33324217796325684
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 101:
# Action taken: 1
# cart position: 0.3526747226715088
# cart velocity: 0.17476141452789307
# pole angle: 0.009197843261063099
# pole angular velocity: 0.04135910049080849
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 102:
# Action taken: 1
# cart position: 0.3561699688434601
# cart velocity: 0.3697502613067627
# pole angle: 0.010025025345385075
# pole angular velocity: -0.24840767681598663
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 103:
# Action taken: 0
# cart position: 0.36356496810913086
# cart velocity: 0.17448659241199493
# pole angle: 0.0050568715669214725
# pole angular velocity: 0.04742041975259781
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 104:
# Action taken: 1
# cart position: 0.36705470085144043
# cart velocity: 0.3695356845855713
# pole angle: 0.006005279719829559
# pole angular velocity: -0.2436627447605133
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 105:
# Action taken: 0
# cart position: 0.3744454085826874
# cart velocity: 0.17432846128940582
# pole angle: 0.0011320250341668725
# pole angular velocity: 0.05090833827853203
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 106:
# Action taken: 1
# cart position: 0.37793198227882385
# cart velocity: 0.3694341778755188
# pole angle: 0.0021501919254660606
# pole angular velocity: -0.24141721427440643
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 107:
# Action taken: 0
# cart position: 0.38532066345214844
# cart velocity: 0.17428156733512878
# pole angle: -0.0026781524065881968
# pole angular velocity: 0.05194316804409027
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 108:
# Action taken: 0
# cart position: 0.3888062834739685
# cart velocity: -0.020801881328225136
# pole angle: -0.0016392889665439725
# pole angular velocity: 0.34377992153167725
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 109:
# Action taken: 1
# cart position: 0.38839027285575867
# cart velocity: 0.17434334754943848
# pole angle: 0.005236309487372637
# pole angular velocity: 0.05058050900697708
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 110:
# Action taken: 1
# cart position: 0.39187711477279663
# cart velocity: 0.3693898320198059
# pole angle: 0.0062479195185005665
# pole angular velocity: -0.24044573307037354
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 111:
# Action taken: 0
# cart position: 0.399264931678772
# cart velocity: 0.17417918145656586
# pole angle: 0.0014390049036592245
# pole angular velocity: 0.0542013943195343
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 112:
# Action taken: 0
# cart position: 0.4027484953403473
# cart velocity: -0.02096336893737316
# pole angle: 0.0025230327155441046
# pole angular velocity: 0.3473379909992218
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 113:
# Action taken: 1
# cart position: 0.4023292362689972
# cart velocity: 0.17412260174751282
# pole angle: 0.009469792246818542
# pole angular velocity: 0.055451735854148865
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 114:
# Action taken: 1
# cart position: 0.40581169724464417
# cart velocity: 0.36910751461982727
# pole angle: 0.010578827001154423
# pole angular velocity: -0.23422841727733612
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 115:
# Action taken: 0
# cart position: 0.41319385170936584
# cart velocity: 0.17383600771427155
# pole angle: 0.005894259084016085
# pole angular velocity: 0.06177254393696785
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 116:
# Action taken: 1
# cart position: 0.416670560836792
# cart velocity: 0.3688729703426361
# pole angle: 0.007129709701985121
# pole angular velocity: -0.22904489934444427
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 117:
# Action taken: 0
# cart position: 0.4240480065345764
# cart velocity: 0.1736498475074768
# pole angle: 0.0025488119572401047
# pole angular velocity: 0.06587844341993332
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 118:
# Action taken: 1
# cart position: 0.4275210201740265
# cart velocity: 0.3687351644039154
# pole angle: 0.0038663807790726423
# pole angular velocity: -0.22599923610687256
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 119:
# Action taken: 0
# cart position: 0.43489572405815125
# cart velocity: 0.17355817556381226
# pole angle: -0.0006536039290949702
# pole angular velocity: 0.06790078431367874
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 120:
# Action taken: 1
# cart position: 0.4383668899536133
# cart velocity: 0.36868947744369507
# pole angle: 0.0007044117664918303
# pole angular velocity: -0.22498828172683716
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 121:
# Action taken: 0
# cart position: 0.445740669965744
# cart velocity: 0.17355747520923615
# pole angle: -0.00379535392858088
# pole angular velocity: 0.06791675835847855
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 122:
# Action taken: 0
# cart position: 0.44921183586120605
# cart velocity: -0.02150985412299633
# pole angle: -0.0024370187893509865
# pole angular velocity: 0.35939982533454895
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 123:
# Action taken: 1
# cart position: 0.4487816393375397
# cart velocity: 0.17364665865898132
# pole angle: 0.004750977270305157
# pole angular velocity: 0.0659494400024414
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 124:
# Action taken: 1
# cart position: 0.4522545635700226
# cart velocity: 0.36870017647743225
# pole angle: 0.006069966126233339
# pole angular velocity: -0.22523075342178345
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 125:
# Action taken: 0
# cart position: 0.45962855219841003
# cart velocity: 0.17349199950695038
# pole angle: 0.0015653511509299278
# pole angular velocity: 0.06936067342758179
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 126:
# Action taken: 0
# cart position: 0.463098406791687
# cart velocity: -0.02165236324071884
# pole angle: 0.0029525647405534983
# pole angular velocity: 0.36253705620765686
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 127:
# Action taken: 1
# cart position: 0.4626653492450714
# cart velocity: 0.1734274923801422
# pole angle: 0.010203305631875992
# pole angular velocity: 0.07078660279512405
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 128:
# Action taken: 1
# cart position: 0.46613389253616333
# cart velocity: 0.3684017062187195
# pole angle: 0.011619037948548794
# pole angular velocity: -0.21865974366664886
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 129:
# Action taken: 0
# cart position: 0.47350195050239563
# cart velocity: 0.1731155961751938
# pole angle: 0.007245843298733234
# pole angular velocity: 0.0776655524969101
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 130:
# Action taken: 1
# cart position: 0.4769642651081085
# cart velocity: 0.36813291907310486
# pole angle: 0.008799154311418533
# pole angular velocity: -0.212722510099411
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 131:
# Action taken: 0
# cart position: 0.48432689905166626
# cart velocity: 0.17288628220558167
# pole angle: 0.004544704221189022
# pole angular velocity: 0.08272303640842438
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 132:
# Action taken: 1
# cart position: 0.48778462409973145
# cart velocity: 0.36794278025627136
# pole angle: 0.006199164781719446
# pole angular velocity: -0.20852257311344147
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 133:
# Action taken: 0
# cart position: 0.49514350295066833
# cart velocity: 0.17273275554180145
# pole angle: 0.002028713235631585
# pole angular velocity: 0.08610940724611282
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 134:
# Action taken: 1
# cart position: 0.4985981583595276
# cart velocity: 0.36782556772232056
# pole angle: 0.003750901436433196
# pole angular velocity: -0.20593276619911194
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 135:
# Action taken: 0
# cart position: 0.5059546828269958
# cart velocity: 0.17265017330646515
# pole angle: -0.00036775378976017237
# pole angular velocity: 0.08793102204799652
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 136:
# Action taken: 1
# cart position: 0.509407639503479
# cart velocity: 0.36777740716934204
# pole angle: 0.0013908665860071778
# pole angular velocity: -0.2048679143190384
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 137:
# Action taken: 0
# cart position: 0.5167632102966309
# cart velocity: 0.17263558506965637
# pole angle: -0.002706491621211171
# pole angular velocity: 0.0882534384727478
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 138:
# Action taken: 0
# cart position: 0.5202159285545349
# cart velocity: -0.02244746871292591
# pole angle: -0.0009414228261448443
# pole angular velocity: 0.3800812363624573
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 139:
# Action taken: 1
# cart position: 0.5197669863700867
# cart velocity: 0.1726878434419632
# pole angle: 0.00666020205244422
# pole angular velocity: 0.08710163086652756
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 140:
# Action taken: 1
# cart position: 0.5232207179069519
# cart velocity: 0.36771368980407715
# pole angle: 0.008402234874665737
# pole angular velocity: -0.2034725695848465
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 141:
# Action taken: 0
# cart position: 0.5305749773979187
# cart velocity: 0.17247259616851807
# pole angle: 0.004332783166319132
# pole angular velocity: 0.0918489620089531
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 142:
# Action taken: 1
# cart position: 0.5340244770050049
# cart velocity: 0.3675321638584137
# pole angle: 0.006169762462377548
# pole angular velocity: -0.1994638293981552
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 143:
# Action taken: 0
# cart position: 0.5413751006126404
# cart velocity: 0.17232252657413483
# pole angle: 0.0021804857533425093
# pole angular velocity: 0.09515897184610367
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 144:
# Action taken: 1
# cart position: 0.544821560382843
# cart velocity: 0.36741316318511963
# pole angle: 0.004083665087819099
# pole angular velocity: -0.1968352198600769
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 145:
# Action taken: 0
# cart position: 0.5521697998046875
# cart velocity: 0.17223303020000458
# pole angle: 0.00014696062135044485
# pole angular velocity: 0.09713311493396759
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 146:
# Action taken: 1
# cart position: 0.5556144714355469
# cart velocity: 0.3673528730869293
# pole angle: 0.0020896228961646557
# pole angular velocity: -0.19550344347953796
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 147:
# Action taken: 0
# cart position: 0.5629615187644958
# cart velocity: 0.17220109701156616
# pole angle: -0.0018204457592219114
# pole angular velocity: 0.09783793985843658
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 148:
# Action taken: 0
# cart position: 0.5664055347442627
# cart velocity: -0.022894714027643204
# pole angle: 0.00013631299952976406
# pole angular velocity: 0.38994595408439636
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 149:
# Action taken: 1
# cart position: 0.5659476518630981
# cart velocity: 0.17222529649734497
# pole angle: 0.007935232482850552
# pole angular velocity: 0.0973060205578804
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 150:
# Action taken: 1
# cart position: 0.5693921446800232
# cart velocity: 0.36723262071609497
# pole angle: 0.009881353005766869
# pole angular velocity: -0.1928628385066986
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 151:
# Action taken: 0
# cart position: 0.5767368078231812
# cart velocity: 0.17197072505950928
# pole angle: 0.0060240961611270905
# pole angular velocity: 0.10292079299688339
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 152:
# Action taken: 1
# cart position: 0.5801762342453003
# cart velocity: 0.3670058250427246
# pole angle: 0.008082511834800243
# pole angular velocity: -0.18785548210144043
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 153:
# Action taken: 0
# cart position: 0.5875163674354553
# cart velocity: 0.1717691868543625
# pole angle: 0.004325402434915304
# pole angular velocity: 0.1073661595582962
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 154:
# Action taken: 1
# cart position: 0.5909517407417297
# cart velocity: 0.36682888865470886
# pole angle: 0.006472725421190262
# pole angular velocity: -0.18394899368286133
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 155:
# Action taken: 0
# cart position: 0.5982882976531982
# cart velocity: 0.17161491513252258
# pole angle: 0.0027937456034123898
# pole angular velocity: 0.11076879501342773
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 156:
# Action taken: 1
# cart position: 0.6017206311225891
# cart velocity: 0.36669671535491943
# pole angle: 0.005009121727198362
# pole angular velocity: -0.18103142082691193
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 157:
# Action taken: 0
# cart position: 0.6090545654296875
# cart velocity: 0.1715034544467926
# pole angle: 0.0013884931104257703
# pole angular velocity: 0.1132274866104126
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 158:
# Action taken: 1
# cart position: 0.6124846339225769
# cart velocity: 0.3666054904460907
# pole angle: 0.0036530429497361183
# pole angular velocity: -0.1790170520544052
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 159:
# Action taken: 0
# cart position: 0.6198167204856873
# cart velocity: 0.17143145203590393
# pole angle: 7.270191417774186e-05
# pole angular velocity: 0.11481603980064392
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 160:
# Action taken: 1
# cart position: 0.623245358467102
# cart velocity: 0.36655235290527344
# pole angle: 0.0023690226953476667
# pole angular velocity: -0.17784394323825836
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 161:
# Action taken: 0
# cart position: 0.6305763721466064
# cart velocity: 0.17139658331871033
# pole angle: -0.0011878563091158867
# pole angular velocity: 0.11558537930250168
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 162:
# Action taken: 0
# cart position: 0.6340043544769287
# cart velocity: -0.023708326742053032
# pole angle: 0.0011238513980060816
# pole angular velocity: 0.4078933000564575
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 163:
# Action taken: 1
# cart position: 0.6335301399230957
# cart velocity: 0.17139767110347748
# pole angle: 0.009281717240810394
# pole angular velocity: 0.11556491255760193
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 164:
# Action taken: 1
# cart position: 0.636958122253418
# cart velocity: 0.36638540029525757
# pole angle: 0.011593015864491463
# pole angular velocity: -0.17417530715465546
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 165:
# Action taken: 0
# cart position: 0.6442857980728149
# cart velocity: 0.1710994690656662
# pole angle: 0.008109509944915771
# pole angular velocity: 0.12214217334985733
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 166:
# Action taken: 1
# cart position: 0.6477078199386597
# cart velocity: 0.3661043047904968
# pole angle: 0.010552353225648403
# pole angular velocity: -0.16797128319740295
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 167:
# Action taken: 0
# cart position: 0.6550298929214478
# cart velocity: 0.17083291709423065
# pole angle: 0.007192927412688732
# pole angular velocity: 0.12802183628082275
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 168:
# Action taken: 1
# cart position: 0.6584465503692627
# cart velocity: 0.3658510744571686
# pole angle: 0.009753364138305187
# pole angular velocity: -0.16238315403461456
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 169:
# Action taken: 0
# cart position: 0.6657635569572449
# cart velocity: 0.17059087753295898
# pole angle: 0.006505700759589672
# pole angular velocity: 0.13336066901683807
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 170:
# Action taken: 1
# cart position: 0.669175386428833
# cart velocity: 0.365619033575058
# pole angle: 0.009172914549708366
# pole angular velocity: -0.15726272761821747
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 171:
# Action taken: 0
# cart position: 0.6764878034591675
# cart velocity: 0.17036697268486023
# pole angle: 0.006027659866958857
# pole angular velocity: 0.1382998675107956
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 172:
# Action taken: 1
# cart position: 0.6798951029777527
# cart velocity: 0.36540207266807556
# pole angle: 0.008793656714260578
# pole angular velocity: -0.15247535705566406
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 173:
# Action taken: 0
# cart position: 0.6872031688690186
# cart velocity: 0.17015531659126282
# pole angle: 0.005744149908423424
# pole angular velocity: 0.14296875894069672
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 174:
# Action taken: 1
# cart position: 0.6906062364578247
# cart velocity: 0.36519452929496765
# pole angle: 0.008603525348007679
# pole angular velocity: -0.14789646863937378
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 175:
# Action taken: 0
# cart position: 0.6979101300239563
# cart velocity: 0.1699504405260086
# pole angle: 0.005645595956593752
# pole angular velocity: 0.14748823642730713
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 176:
# Action taken: 1
# cart position: 0.7013091444969177
# cart velocity: 0.36499109864234924
# pole angle: 0.008595360442996025
# pole angular velocity: -0.14340828359127045
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 177:
# Action taken: 0
# cart position: 0.7086089849472046
# cart velocity: 0.16974709928035736
# pole angle: 0.005727194715291262
# pole angular velocity: 0.1519738882780075
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 178:
# Action taken: 1
# cart position: 0.7120039463043213
# cart velocity: 0.3647865951061249
# ...
# pole angular velocity: 0.1800776571035385
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 230:
# Action taken: 1
# cart position: 1.074503779411316
# cart velocity: 0.726213276386261
# pole angle: 0.07622992247343063
# pole angular velocity: -0.08883850276470184
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 231:
# Action taken: 0
# cart position: 1.089028000831604
# cart velocity: 0.5300861597061157
# pole angle: 0.07445315271615982
# pole angular velocity: 0.2268877625465393
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 232:
# Action taken: 1
# cart position: 1.0996297597885132
# cart velocity: 0.7240694761276245
# pole angle: 0.07899090647697449
# pole angular velocity: -0.0414121113717556
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 233:
# Action taken: 0
# cart position: 1.114111065864563
# cart velocity: 0.5279088616371155
# pole angle: 0.07816266268491745
# pole angular velocity: 0.2751104533672333
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 234:
# Action taken: 1
# cart position: 1.1246693134307861
# cart velocity: 0.7218336462974548
# pole angle: 0.08366487175226212
# pole angular velocity: 0.00806781928986311
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 235:
# Action taken: 0
# cart position: 1.1391059160232544
# cart velocity: 0.5256177186965942
# pole angle: 0.0838262289762497
# pole angular velocity: 0.32593104243278503
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 236:
# Action taken: 1
# cart position: 1.1496182680130005
# cart velocity: 0.7194523215293884
# pole angle: 0.09034484624862671
# pole angular velocity: 0.060816094279289246
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 237:
# Action taken: 1
# cart position: 1.164007306098938
# cart velocity: 0.913170576095581
# pole angle: 0.09156116843223572
# pole angular velocity: -0.20205095410346985
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 238:
# Action taken: 0
# cart position: 1.1822707653045654
# cart velocity: 0.7168665528297424
# pole angle: 0.08752015233039856
# pole angular velocity: 0.11805304884910583
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 239:
# Action taken: 1
# cart position: 1.196608066558838
# cart velocity: 0.9106326103210449
# pole angle: 0.08988121151924133
# pole angular velocity: -0.14578549563884735
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 240:
# Action taken: 0
# cart position: 1.2148207426071167
# cart velocity: 0.714346170425415
# pole angle: 0.08696550130844116
# pole angular velocity: 0.17384523153305054
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 241:
# Action taken: 1
# cart position: 1.2291076183319092
# cart velocity: 0.9081227779388428
# pole angle: 0.09044241160154343
# pole angular velocity: -0.09018559008836746
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 242:
# Action taken: 0
# cart position: 1.247270107269287
# cart velocity: 0.7118287086486816
# pole angle: 0.08863869309425354
# pole angular velocity: 0.22960594296455383
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 243:
# Action taken: 1
# cart position: 1.2615066766738892
# cart velocity: 0.9055795073509216
# pole angle: 0.09323081374168396
# pole angular velocity: -0.03385371342301369
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 244:
# Action taken: 0
# cart position: 1.279618263244629
# cart velocity: 0.7092528343200684
# pole angle: 0.09255374222993851
# pole angular velocity: 0.28672754764556885
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 245:
# Action taken: 1
# cart position: 1.293803334236145
# cart velocity: 0.9029414057731628
# pole angle: 0.09828829020261765
# pole angular velocity: 0.024610228836536407
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 246:
# Action taken: 1
# cart position: 1.3118622303009033
# cart velocity: 1.0965265035629272
# pole angle: 0.09878049790859222
# pole angular velocity: -0.23551563918590546
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 247:
# Action taken: 0
# cart position: 1.3337926864624023
# cart velocity: 0.9001421332359314
# pole angle: 0.0940701812505722
# pole angular velocity: 0.08661907911300659
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 248:
# Action taken: 1
# cart position: 1.3517955541610718
# cart velocity: 1.0937986373901367
# pole angle: 0.09580256789922714
# pole angular velocity: -0.17496541142463684
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 249:
# Action taken: 0
# cart position: 1.373671531677246
# cart velocity: 0.8974453806877136
# pole angle: 0.09230325371026993
# pole angular velocity: 0.14633667469024658
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 250:
# Action taken: 1
# cart position: 1.391620397567749
# cart velocity: 1.091132640838623
# pole angle: 0.09522999078035355
# pole angular velocity: -0.11585874110460281
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 251:
# Action taken: 0
# cart position: 1.4134430885314941
# cart velocity: 0.8947843313217163
# pole angle: 0.09291281551122665
# pole angular velocity: 0.20528456568717957
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 252:
# Action taken: 1
# cart position: 1.4313387870788574
# cart velocity: 1.0884631872177124
# pole angle: 0.09701851010322571
# pole angular velocity: -0.05670364573597908
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 253:
# Action taken: 0
# cart position: 1.4531080722808838
# cart velocity: 0.8920937180519104
# pole angle: 0.09588443487882614
# pole angular velocity: 0.2649441361427307
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 254:
# Action taken: 1
# cart position: 1.4709498882293701
# cart velocity: 1.0857256650924683
# pole angle: 0.10118331760168076
# pole angular velocity: 0.003977230750024319
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 255:
# Action taken: 1
# cart position: 1.4926644563674927
# cart velocity: 1.2792619466781616
# pole angle: 0.10126286000013351
# pole angular velocity: -0.2551451325416565
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 256:
# Action taken: 0
# cart position: 1.5182496309280396
# cart velocity: 1.0828509330749512
# pole angle: 0.09615995734930038
# pole angular velocity: 0.06768257170915604
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 257:
# Action taken: 1
# cart position: 1.539906620979309
# cart velocity: 1.2764720916748047
# pole angle: 0.0975136086344719
# pole angular velocity: -0.19317999482154846
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 258:
# Action taken: 0
# cart position: 1.5654361248016357
# cart velocity: 1.080100178718567
# pole angle: 0.09365001320838928
# pole angular velocity: 0.1286020129919052
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 259:
# Action taken: 1
# cart position: 1.5870381593704224
# cart velocity: 1.2737644910812378
# pole angle: 0.09622205048799515
# pole angular velocity: -0.13312862813472748
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 260:
# Action taken: 0
# cart position: 1.6125134229660034
# cart velocity: 1.0774054527282715
# pole angle: 0.09355948120355606
# pole angular velocity: 0.18829326331615448
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 261:
# Action taken: 1
# cart position: 1.634061574935913
# cart velocity: 1.2710729837417603
# pole angle: 0.09732533991336823
# pole angular velocity: -0.07347116619348526
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 262:
# Action taken: 0
# cart position: 1.6594829559326172
# cart velocity: 1.0747002363204956
# pole angle: 0.09585592150688171
# pole angular velocity: 0.24826249480247498
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 263:
# Action taken: 1
# cart position: 1.6809769868850708
# cart velocity: 1.26833176612854
# pole angle: 0.10082116723060608
# pole angular velocity: -0.012713069096207619
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 264:
# Action taken: 1
# cart position: 1.706343650817871
# cart velocity: 1.4618741273880005
# pole angle: 0.10056690871715546
# pole angular velocity: -0.27196112275123596
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 265:
# Action taken: 0
# cart position: 1.7355811595916748
# cart velocity: 1.2654716968536377
# pole angle: 0.09512768685817719
# pole angular velocity: 0.050670865923166275
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 266:
# Action taken: 1
# cart position: 1.7608904838562012
# cart velocity: 1.4591100215911865
# pole angle: 0.09614109992980957
# pole angular velocity: -0.21054798364639282
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 267:
# Action taken: 0
# cart position: 1.7900727987289429
# cart velocity: 1.2627543210983276
# pole angle: 0.09193014353513718
# pole angular velocity: 0.11084741353988647
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 268:
# Action taken: 1
# cart position: 1.8153278827667236
# cart velocity: 1.456446886062622
# pole angle: 0.09414709359407425
# pole angular velocity: -0.15147526562213898
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 269:
# Action taken: 0
# cart position: 1.8444567918777466
# cart velocity: 1.2601118087768555
# pole angle: 0.09111758321523666
# pole angular velocity: 0.16936157643795013
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 270:
# Action taken: 1
# cart position: 1.8696589469909668
# cart velocity: 1.4538193941116333
# pole angle: 0.09450481832027435
# pole angular velocity: -0.09324297308921814
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 271:
# Action taken: 0
# cart position: 1.8987354040145874
# cart velocity: 1.257478952407837
# pole angle: 0.09263996034860611
# pole angular velocity: 0.22769667208194733
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 272:
# Action taken: 1
# cart position: 1.9238849878311157
# cart velocity: 1.4511632919311523
# pole angle: 0.0971938893198967
# pole angular velocity: -0.034386854618787766
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 273:
# Action taken: 0
# cart position: 1.9529082775115967
# cart velocity: 1.2547916173934937
# pole angle: 0.09650615602731705
# pole angular velocity: 0.28731048107147217
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 274:
# Action taken: 1
# cart position: 1.9780040979385376
# cart velocity: 1.4484143257141113
# pole angle: 0.10225236415863037
# pole angular velocity: 0.02655663527548313
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 275:
# Action taken: 1
# cart position: 2.006972312927246
# cart velocity: 1.641932487487793
# pole angle: 0.10278349369764328
# pole angular velocity: -0.2321947067975998
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 276:
# Action taken: 0
# cart position: 2.0398108959198
# cart velocity: 1.44550359249115
# pole angle: 0.09813960641622543
# pole angular velocity: 0.0910588875412941
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 277:
# Action taken: 1
# cart position: 2.068721055984497
# cart velocity: 1.6390918493270874
# pole angle: 0.09996078163385391
# pole angular velocity: -0.16911955177783966
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 278:
# Action taken: 0
# cart position: 2.1015028953552246
# cart velocity: 1.4426918029785156
# pole angle: 0.09657838940620422
# pole angular velocity: 0.15334953367710114
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 279:
# Action taken: 1
# cart position: 2.130356788635254
# cart velocity: 1.636307716369629
# pole angle: 0.09964538365602493
# pole angular velocity: -0.10737106949090958
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 280:
# Action taken: 0
# cart position: 2.1630828380584717
# cart velocity: 1.4399094581604004
# pole angle: 0.09749796241521835
# pole angular velocity: 0.21501222252845764
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 281:
# Action taken: 1
# cart position: 2.1918811798095703
# cart velocity: 1.6335121393203735
# pole angle: 0.10179820656776428
# pole angular velocity: -0.04539363086223602
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 282:
# Action taken: 0
# cart position: 2.2245514392852783
# cart velocity: 1.437088966369629
# pole angle: 0.10089033097028732
# pole angular velocity: 0.27759283781051636
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 283:
# Action taken: 1
# cart position: 2.253293037414551
# cart velocity: 1.630637764930725
# pole angle: 0.10644219070672989
# pole angular velocity: 0.018357526510953903
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 284:
# Action taken: 0
# cart position: 2.2859058380126953
# cart velocity: 1.4341630935668945
# pole angle: 0.1068093404173851
# pole angular velocity: 0.3426365256309509
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 285:
# Action taken: 1
# cart position: 2.314589023590088
# cart velocity: 1.6276161670684814
# pole angle: 0.11366207152605057
# pole angular velocity: 0.08545278757810593
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 286:
# Action taken: 1
# cart position: 2.3471415042877197
# cart velocity: 1.8209408521652222
# pole angle: 0.11537112295627594
# pole angular velocity: -0.16931837797164917
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 287:
# Action taken: 0
# cart position: 2.3835601806640625
# cart velocity: 1.6243728399276733
# pole angle: 0.11198475956916809
# pole angular velocity: 0.15741752088069916
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 288:
# Action taken: 1
# cart position: 2.4160478115081787
# cart velocity: 1.8177281618118286
# pole angle: 0.11513310670852661
# pole angular velocity: -0.09794405102729797
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 288.0

# %% [markdown]
# ## Report Document

# %%
obs_explanation = """\
**Observation vector (4 values):**
1. **Cart Position (m)** — horizontal position on the track (≈ -4.8 to +4.8).
2. **Cart Velocity (m/s)** — how fast the cart moves (unbounded float in practice).
3. **Pole Angle (rad)** — tilt of the pole relative to vertical (≈ -0.4189 to +0.4189 rad ≈ ±24°).
4. **Pole Angular Velocity (rad/s)** — how fast the pole is rotating (unbounded float in practice).
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- **Pole tilt exceeds ±0.4189 rad (~±24°)** → `terminated = True`
- **Cart position leaves track bounds (≈ ±4.8 m)** → `terminated = True`
- **Time limit of 500 steps is reached** → `truncated = True`
"""

with open(report_file, "w",encoding="utf-8")as f:
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Performance Summary:\n")
    f.write(f"- Total Timesteps: {model.num_timesteps}\n")
    f.write(f"- Algorithm: {type(model).__name__}\n")
    f.write(f"- Observation: {observation.tolist()}\n")
    f.write(f"- Total reward: {total_reward}\n")

    f.write("## Graph Interpretation:\n")
    f.write("- Training curve shows how total episode rewards increased during training.\n")
    f.write("- Evaluation curve shows the mean performance of the trained model at fixed intervals.\n")
    f.write("- A smooth upward trend in both curves indicates stable learning.\n")
    f.write("- The final rewards approaching 500 suggest the agent solved the CartPole task.\n\n")

# %% [markdown]
# ## Plotting (Evaluation Curve + Training Curve)

# %%
def generate_evaluation_curve(model, graphs_dir, num_eval_episodes=20, eval_freq=200, total_timesteps=2000):
    """
    Evaluate the model at regular intervals and plot evaluation curve.
    Evaluation curve, not recording rewards during training, evaluating trained model at fixed intervals
    Each point on graph comes from evaluate_policy(), which tests model for several episodes & averages results
    Measures performance after certain amounts of training, NOT the actual learning process

    * TLDR: graphs shows the evaluarion reward at regular timesteps during training *
    """
    rewards = []
    timesteps = []

    env = gym.make("CartPole-v1")

    for step in range(eval_freq, total_timesteps + 1, eval_freq):
        # Evaluate policy
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=num_eval_episodes, deterministic=True) #this uses the model we just trained 
        rewards.append(mean_reward)
        timesteps.append(step)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(timesteps, rewards, marker="o", label="Mean Reward (Evaluation)", color="tab:orange")
    plt.xlabel("Timesteps")
    plt.ylabel("Mean Reward over Episodes")
    plt.title("evaluation Curve (PPO on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

    # Save figure
    graph_file = graphs_dir / "evaluation_curve.png"
    plt.savefig(graph_file, dpi=200, bbox_inches="tight")
    plt.close()
    env.close()

    print(f"evaluation curve saved to {graph_file}")


generate_evaluation_curve(model, graphs_dir)
# Out:
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# evaluation curve saved to ../../documentation/cartpole/ppo-cartpole/run_2025-10-10_14-08-34/graphs/evaluation_curve.png

# %%
def plot_training_curve(monitor_dir, graphs_dir):
    """
    Plot the training learning curve based on rewards logged during training.
    The learning curve visualizes how the agent’s performance evolves over time
    by showing the total episode rewards collected during training.

    Each point on the graph corresponds to the cumulative reward obtained in a
    single training episode, as recorded automatically by the Monitor wrapper.

    This curve reflects the agent’s actual *learning process* — showing how it
    improves, stabilizes, or fluctuates in performance while training.

    * TLDR: graph shows the agent’s reward per episode DURING training (true learning progress) *
  
    """
    monitor_dir = Path(monitor_dir)

    csv_files = list(monitor_dir.glob("*.csv"))
    if not csv_files:
        raise FileNotFoundError(f"No monitor CSV found in {monitor_dir}")
    log_file = csv_files[0]  

    print(f"Found monitor file: {log_file.name}")

    df = pd.read_csv(log_file, skiprows=1)
    plt.figure(figsize=(10, 6))
    plt.plot(df["r"], label="Reward per Episode", color="tab:blue", alpha=0.7)
    plt.xlabel("Episodes")
    plt.ylabel("Total Reward")
    plt.title("Training Learning Curve (PPO on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()
    out = Path(graphs_dir) / "training_learning_curve.png"
    plt.savefig(out, dpi=200, bbox_inches="tight")
    plt.close()
    print(f"Saved training learning curve → {out}")

plot_training_curve(monitor_file, graphs_dir)
# Out:
# Found monitor file: monitor.csv
# Saved training learning curve → ../../documentation/cartpole/ppo-cartpole/run_2025-10-10_14-08-34/graphs/training_learning_curve.png
