# %%
import gymnasium as gym
from pathlib import Path
from gymnasium.wrappers import RecordVideo
from datetime import datetime
from stable_baselines3 import PPO

# %%
docs_path = Path("../../documentation/cartpole/ppo-cartpole") 

run_id = datetime.now().strftime("%Y-%m-%d>%H:%M:%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "ppo_cartpole"

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array") 
env = RecordVideo(
    env,
    video_folder=str(video_dir),
    episode_trigger=lambda e: True,
    name_prefix="cartpole_random_baseline" 
)
# Out:
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/documentation/cartpole/ppo-cartpole/run_2025-10-04>12:14:14/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=1000)

model.save(str(model_file))
# Out:
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:416: UserWarning: WARN: Unable to save last video! Did you call close()?
#   logger.warn("Unable to save last video! Did you call close()?")
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.5     |
# |    ep_rew_mean     | 22.5     |
# | time/              |          |
# |    fps             | 275      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------

# %%
# Reset environment
observation, info = env.reset(seed=42)

print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Action space: Discrete(2)
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Starting observation: [ 0.0273956  -0.00611216  0.03585979  0.0197368 ]
# maxiumum number of steps per episode: 500

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["cart position", "cart velocity", "pole angle", "pole angular velocity"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(action)

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}")

    for label, observe in zip(labels,observation):
        print(f"{label}: {observe}")

    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 1
# cart position: 0.02727336250245571
# cart velocity: 0.18847766518592834
# pole angle: 0.036254528909921646
# pole angular velocity: -0.26141977310180664
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 0
# cart position: 0.0310429148375988
# cart velocity: -0.007142550311982632
# pole angle: 0.03102613240480423
# pole angular velocity: 0.04247424006462097
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 1
# cart position: 0.03090006485581398
# cart velocity: 0.1875210702419281
# pole angle: 0.0318756178021431
# pole angular velocity: -0.24026045203208923
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 0
# cart position: 0.03465048596262932
# cart velocity: -0.0080413818359375
# pole angle: 0.027070408686995506
# pole angular velocity: 0.062304068356752396
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 1
# cart position: 0.03448965772986412
# cart velocity: 0.18668219447135925
# pole angle: 0.028316490352153778
# pole angular velocity: -0.22171655297279358
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 0
# cart position: 0.038223300129175186
# cart velocity: -0.008832814171910286
# pole angle: 0.02388215810060501
# pole angular velocity: 0.07976232469081879
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 7:
# Action taken: 1
# cart position: 0.03804664686322212
# cart velocity: 0.1859387904405594
# pole angle: 0.02547740563750267
# pole angular velocity: -0.20529106259346008
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 8:
# Action taken: 0
# cart position: 0.041765421628952026
# cart velocity: -0.009538063779473305
# pole angle: 0.02137158438563347
# pole angular velocity: 0.09531859308481216
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 9:
# Action taken: 1
# cart position: 0.04157466068863869
# cart velocity: 0.18527115881443024
# pole angle: 0.023277955129742622
# pole angular velocity: -0.19054575264453888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 10:
# Action taken: 0
# cart position: 0.045280084013938904
# cart velocity: -0.010175937786698341
# pole angle: 0.01946704089641571
# pole angular velocity: 0.1093885749578476
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 11:
# Action taken: 1
# cart position: 0.04507656395435333
# cart velocity: 0.18466173112392426
# pole angle: 0.02165481261909008
# pole angular velocity: -0.17708958685398102
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 12:
# Action taken: 0
# cart position: 0.04876979812979698
# cart velocity: -0.010763324797153473
# pole angle: 0.018113020807504654
# pole angular velocity: 0.12234526872634888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 13:
# Action taken: 1
# cart position: 0.04855453222990036
# cart velocity: 0.18409450352191925
# pole angle: 0.020559925585985184
# pole angular velocity: -0.16456858813762665
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 14:
# Action taken: 0
# cart position: 0.05223642289638519
# cart velocity: -0.011315638199448586
# pole angle: 0.017268553376197815
# pole angular velocity: 0.13452886044979095
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 15:
# Action taken: 1
# cart position: 0.05201010778546333
# cart velocity: 0.1835547536611557
# pole angle: 0.019959131255745888
# pole angular velocity: -0.1526564508676529
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 16:
# Action taken: 0
# cart position: 0.05568120628595352
# cart velocity: -0.011847210116684437
# pole angle: 0.016906002536416054
# pole angular velocity: 0.1462557315826416
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 17:
# Action taken: 1
# cart position: 0.05544425919651985
# cart velocity: 0.18302860856056213
# pole angle: 0.019831117242574692
# pole angular velocity: -0.14104610681533813
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 18:
# Action taken: 0
# cart position: 0.059104833751916885
# cart velocity: -0.01237166952341795
# pole angle: 0.017010195180773735
# pole angular velocity: 0.15782664716243744
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 19:
# Action taken: 1
# cart position: 0.058857399970293045
# cart velocity: 0.18250267207622528
# pole angle: 0.020166728645563126
# pole angular velocity: -0.12944181263446808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 20:
# Action taken: 0
# cart position: 0.06250745058059692
# cart velocity: -0.012902283109724522
# pole angle: 0.017577892169356346
# pole angular velocity: 0.1695346236228943
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 21:
# Action taken: 1
# cart position: 0.062249407172203064
# cart velocity: 0.181963711977005
# pole angle: 0.020968584343791008
# pole angular velocity: -0.11755158007144928
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 22:
# Action taken: 0
# cart position: 0.06588868051767349
# cart velocity: -0.013452299870550632
# pole angle: 0.018617553636431694
# pole angular velocity: 0.18167231976985931
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 23:
# Action taken: 1
# cart position: 0.06561963260173798
# cart velocity: 0.18139836192131042
# pole angle: 0.02225099876523018
# pole angular velocity: -0.10507979243993759
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 24:
# Action taken: 0
# cart position: 0.06924760341644287
# cart velocity: -0.014035270549356937
# pole angle: 0.02014940418303013
# pole angular velocity: 0.19453935325145721
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 25:
# Action taken: 1
# cart position: 0.06896689534187317
# cart velocity: 0.18079274892807007
# pole angle: 0.024040190503001213
# pole angular velocity: -0.09171982109546661
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 26:
# Action taken: 1
# cart position: 0.07258275151252747
# cart velocity: 0.37556201219558716
# pole angle: 0.022205794230103493
# pole angular velocity: -0.37672218680381775
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 27:
# Action taken: 0
# cart position: 0.08009399473667145
# cart velocity: 0.18013183772563934
# pole angle: 0.014671350829303265
# pole angular velocity: -0.07712120562791824
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 28:
# Action taken: 1
# cart position: 0.0836966261267662
# cart velocity: 0.3750404119491577
# pole angle: 0.013128926046192646
# pole angular velocity: -0.3651393949985504
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 29:
# Action taken: 0
# cart position: 0.0911974385380745
# cart velocity: 0.17973437905311584
# pole angle: 0.00582613842561841
# pole angular velocity: -0.06834578514099121
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 30:
# Action taken: 1
# cart position: 0.09479212760925293
# cart velocity: 0.374772310256958
# pole angle: 0.00445922277867794
# pole angular velocity: -0.3591848611831665
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 31:
# Action taken: 0
# cart position: 0.10228756815195084
# cart velocity: 0.179587259888649
# pole angle: -0.0027244742959737778
# pole angular velocity: -0.06509917229413986
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 32:
# Action taken: 1
# cart position: 0.10587931424379349
# cart velocity: 0.374748170375824
# pole angle: -0.004026457667350769
# pole angular velocity: -0.3586404323577881
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 33:
# Action taken: 0
# cart position: 0.11337427794933319
# cart velocity: 0.17968368530273438
# pole angle: -0.011199266649782658
# pole angular velocity: -0.06722986698150635
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 34:
# Action taken: 1
# cart position: 0.11696795374155045
# cart velocity: 0.3749643862247467
# pole angle: -0.012543863616883755
# pole angular velocity: -0.363425076007843
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 35:
# Action taken: 0
# cart position: 0.12446723878383636
# cart velocity: 0.1800229549407959
# pole angle: -0.019812365993857384
# pole angular velocity: -0.07472371309995651
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 36:
# Action taken: 1
# cart position: 0.12806770205497742
# cart velocity: 0.37542325258255005
# pole angle: -0.0213068388402462
# pole angular velocity: -0.3735910952091217
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 37:
# Action taken: 0
# cart position: 0.13557615876197815
# cart velocity: 0.18061034381389618
# pole angle: -0.02877866104245186
# pole angular velocity: -0.08770179748535156
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 38:
# Action taken: 1
# cart position: 0.13918837904930115
# cart velocity: 0.3761327266693115
# pole angle: -0.030532697215676308
# pole angular velocity: -0.38932371139526367
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 39:
# Action taken: 0
# cart position: 0.14671102166175842
# cart velocity: 0.18145714700222015
# pole angle: -0.038319170475006104
# pole angular velocity: -0.10642165690660477
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 40:
# Action taken: 0
# cart position: 0.15034016966819763
# cart velocity: -0.013095313683152199
# pole angle: -0.04044760391116142
# pole angular velocity: 0.17392973601818085
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 41:
# Action taken: 1
# cart position: 0.15007826685905457
# cart velocity: 0.18258148431777954
# pole angle: -0.036969009786844254
# pole angular velocity: -0.13123373687267303
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 42:
# Action taken: 0
# cart position: 0.1537298858165741
# cart velocity: -0.011991938576102257
# pole angle: -0.039593685418367386
# pole angular velocity: 0.14956055581569672
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 43:
# Action taken: 1
# cart position: 0.15349005162715912
# cart velocity: 0.1836739480495453
# pole angle: -0.03660247474908829
# pole angular velocity: -0.15534576773643494
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 44:
# Action taken: 0
# cart position: 0.15716353058815002
# cart velocity: -0.010905328206717968
# pole angle: -0.039709389209747314
# pole angular velocity: 0.1255689412355423
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 45:
# Action taken: 1
# cart position: 0.15694542229175568
# cart velocity: 0.18476234376430511
# pole angle: -0.037198010832071304
# pole angular velocity: -0.17937268316745758
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 46:
# Action taken: 0
# cart position: 0.1606406718492508
# cart velocity: -0.009808105416595936
# pole angle: -0.04078546538949013
# pole angular velocity: 0.10134739428758621
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 47:
# Action taken: 1
# cart position: 0.16044451296329498
# cart velocity: 0.18587391078472137
# pole angle: -0.03875851631164551
# pole angular velocity: -0.20391912758350372
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 48:
# Action taken: 0
# cart position: 0.16416199505329132
# cart velocity: -0.008672944270074368
# pole angle: -0.04283689707517624
# pole angular velocity: 0.0762898325920105
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 49:
# Action taken: 1
# cart position: 0.16398853063583374
# cart velocity: 0.18703609704971313
# pole angle: -0.041311100125312805
# pole angular velocity: -0.2295946180820465
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 50:
# Action taken: 0
# cart position: 0.16772925853729248
# cart velocity: -0.007471917662769556
# pole angle: -0.04590299353003502
# pole angular velocity: 0.04977646470069885
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 51:
# Action taken: 1
# cart position: 0.16757981479167938
# cart velocity: 0.18827715516090393
# pole angle: -0.04490746557712555
# pole angular velocity: -0.25702860951423645
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 52:
# Action taken: 0
# cart position: 0.17134535312652588
# cart velocity: -0.0061758412048220634
# pole angle: -0.050048038363456726
# pole angular velocity: 0.021158479154109955
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 53:
# Action taken: 1
# cart position: 0.17122183740139008
# cart velocity: 0.1896267980337143
# pole angle: -0.04962486773729324
# pole angular velocity: -0.28688570857048035
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 54:
# Action taken: 0
# cart position: 0.17501437664031982
# cart velocity: -0.004753615707159042
# pole angle: -0.055362582206726074
# pole angular velocity: -0.010257745161652565
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 55:
# Action taken: 1
# cart position: 0.17491930723190308
# cart velocity: 0.1911168098449707
# pole angle: -0.05556773766875267
# pole angular velocity: -0.31988152861595154
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 56:
# Action taken: 0
# cart position: 0.17874163389205933
# cart velocity: -0.003171555232256651
# pole angle: -0.06196536496281624
# pole angular velocity: -0.045227307826280594
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 57:
# Action taken: 1
# cart position: 0.1786782145500183
# cart velocity: 0.19278168678283691
# pole angle: -0.06286991387605667
# pole angular velocity: -0.3567992150783539
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 58:
# Action taken: 0
# cart position: 0.1825338453054428
# cart velocity: -0.0013927076943218708
# pole angle: -0.07000589370727539
# pole angular velocity: -0.08458463102579117
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 59:
# Action taken: 0
# cart position: 0.1825059950351715
# cart velocity: -0.1954449713230133
# pole angle: -0.07169759273529053
# pole angular velocity: 0.18521584570407867
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 60:
# Action taken: 1
# cart position: 0.178597092628479
# cart velocity: 0.000625694403424859
# pole angle: -0.06799327582120895
# pole angular velocity: -0.12919555604457855
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 61:
# Action taken: 0
# cart position: 0.17860960960388184
# cart velocity: -0.19345968961715698
# pole angle: -0.07057718187570572
# pole angular velocity: 0.14128519594669342
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 62:
# Action taken: 1
# cart position: 0.17474040389060974
# cart velocity: 0.0025983708910644054
# pole angle: -0.06775148212909698
# pole angular velocity: -0.17280222475528717
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 63:
# Action taken: 0
# cart position: 0.17479237914085388
# cart velocity: -0.19149178266525269
# pole angle: -0.07120752334594727
# pole angular velocity: 0.0977613627910614
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 64:
# Action taken: 1
# cart position: 0.17096254229545593
# cart velocity: 0.0045746611431241035
# pole angle: -0.06925229728221893
# pole angular velocity: -0.2165103256702423
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 65:
# Action taken: 0
# cart position: 0.17105403542518616
# cart velocity: -0.18949244916439056
# pole angle: -0.07358250021934509
# pole angular velocity: 0.05354868620634079
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 66:
# Action taken: 1
# cart position: 0.1672641783952713
# cart velocity: 0.006603218149393797
# pole angle: -0.07251153141260147
# pole angular velocity: -0.2614126205444336
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 67:
# Action taken: 0
# cart position: 0.16739624738693237
# cart velocity: -0.18741276860237122
# pole angle: -0.07773978263139725
# pole angular velocity: 0.0075468942523002625
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 68:
# Action taken: 1
# cart position: 0.16364799439907074
# cart velocity: 0.00873302947729826
# pole angle: -0.07758884131908417
# pole angular velocity: -0.30861568450927734
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 69:
# Action taken: 0
# cart position: 0.16382265090942383
# cart velocity: -0.18520259857177734
# pole angle: -0.08376115560531616
# pole angular velocity: -0.04137567803263664
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 70:
# Action taken: 1
# cart position: 0.16011860966682434
# cart velocity: 0.011014372110366821
# pole angle: -0.0845886692404747
# pole angular velocity: -0.3592662513256073
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 71:
# Action taken: 0
# cart position: 0.160338893532753
# cart velocity: -0.18280963599681854
# pole angle: -0.09177399426698685
# pole angular velocity: -0.09440917521715164
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 72:
# Action taken: 0
# cart position: 0.15668269991874695
# cart velocity: -0.3765045404434204
# pole angle: -0.09366218000650406
# pole angular velocity: 0.167966827750206
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 73:
# Action taken: 1
# cart position: 0.14915260672569275
# cart velocity: -0.18017542362213135
# pole angle: -0.09030283987522125
# pole angular velocity: -0.15273252129554749
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 74:
# Action taken: 0
# cart position: 0.14554910361766815
# cart velocity: -0.3738960921764374
# pole angle: -0.09335749596357346
# pole angular velocity: 0.11015155911445618
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 75:
# Action taken: 1
# cart position: 0.1380711793899536
# cart velocity: -0.1775689721107483
# pole angle: -0.09115446358919144
# pole angular velocity: -0.2104639708995819
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 76:
# Action taken: 0
# cart position: 0.1345198005437851
# cart velocity: -0.3712773621082306
# pole angle: -0.09536374360322952
# pole angular velocity: 0.05212995409965515
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 77:
# Action taken: 1
# cart position: 0.12709425389766693
# cart velocity: -0.1749265491962433
# pole angle: -0.09432114660739899
# pole angular velocity: -0.26905250549316406
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 78:
# Action taken: 0
# cart position: 0.1235957220196724
# cart velocity: -0.3685847520828247
# pole angle: -0.09970219433307648
# pole angular velocity: -0.007545692380517721
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 79:
# Action taken: 1
# cart position: 0.1162240207195282
# cart velocity: -0.1721847802400589
# pole angle: -0.09985310584306717
# pole angular velocity: -0.3299465477466583
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 80:
# Action taken: 0
# cart position: 0.11278032511472702
# cart velocity: -0.36575403809547424
# pole angle: -0.10645204037427902
# pole angular velocity: -0.07034703344106674
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 81:
# Action taken: 1
# cart position: 0.10546524822711945
# cart velocity: -0.16927970945835114
# pole angle: -0.10785897821187973
# pole angular velocity: -0.39462804794311523
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 82:
# Action taken: 0
# cart position: 0.10207965224981308
# cart velocity: -0.3627191185951233
# pole angle: -0.11575154215097427
# pole angular velocity: -0.13780421018600464
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 83:
# Action taken: 0
# cart position: 0.09482526779174805
# cart velocity: -0.5560092926025391
# pole angle: -0.11850762367248535
# pole angular velocity: 0.1162358745932579
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 84:
# Action taken: 1
# cart position: 0.08370508253574371
# cart velocity: -0.3594062924385071
# pole angle: -0.11618290841579437
# pole angular velocity: -0.21135997772216797
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 85:
# Action taken: 0
# cart position: 0.07651696354150772
# cart velocity: -0.5526919364929199
# pole angle: -0.12041010707616806
# pole angular velocity: 0.04253295809030533
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 86:
# Action taken: 1
# cart position: 0.0654631182551384
# cart velocity: -0.35606759786605835
# pole angle: -0.11955944448709488
# pole angular velocity: -0.28558316826820374
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 87:
# Action taken: 0
# cart position: 0.05834176763892174
# cart velocity: -0.5492995381355286
# pole angle: -0.12527111172676086
# pole angular velocity: -0.032871220260858536
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 88:
# Action taken: 1
# cart position: 0.0473557785153389
# cart velocity: -0.3526245057582855
# pole angle: -0.12592853605747223
# pole angular velocity: -0.3623054027557373
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 89:
# Action taken: 0
# cart position: 0.04030328989028931
# cart velocity: -0.5457527041435242
# pole angle: -0.13317464292049408
# pole angular velocity: -0.11183232069015503
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 90:
# Action taken: 0
# cart position: 0.02938823401927948
# cart velocity: -0.7387398481369019
# pole angle: -0.13541129231452942
# pole angular velocity: 0.13604749739170074
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 91:
# Action taken: 1
# cart position: 0.014613437466323376
# cart velocity: -0.5419644117355347
# pole angle: -0.13269034028053284
# pole angular velocity: -0.19610309600830078
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 92:
# Action taken: 0
# cart position: 0.0037741493433713913
# cart velocity: -0.7349634170532227
# pole angle: -0.1366124004125595
# pole angular velocity: 0.051954012364149094
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 93:
# Action taken: 1
# cart position: -0.010925118811428547
# cart velocity: -0.5381739735603333
# pole angle: -0.13557332754135132
# pole angular velocity: -0.28051918745040894
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 94:
# Action taken: 0
# cart position: -0.02168859727680683
# cart velocity: -0.7311277985572815
# pole angle: -0.14118370413780212
# pole angular velocity: -0.03348083049058914
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 95:
# Action taken: 1
# cart position: -0.03631115332245827
# cart velocity: -0.5342931747436523
# pole angle: -0.14185331761837006
# pole angular velocity: -0.3671652674674988
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 96:
# Action taken: 0
# cart position: -0.04699701815843582
# cart velocity: -0.7271444797515869
# pole angle: -0.14919662475585938
# pole angular velocity: -0.12235905975103378
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 97:
# Action taken: 0
# cart position: -0.0615399070084095
# cart velocity: -0.9198489785194397
# pole angle: -0.1516438126564026
# pole angular velocity: 0.11978523433208466
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 98:
# Action taken: 1
# cart position: -0.07993688434362411
# cart velocity: -0.7229163646697998
# pole angle: -0.14924810826778412
# pole angular velocity: -0.2166363149881363
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 99:
# Action taken: 0
# cart position: -0.094395212829113
# cart velocity: -0.9156245589256287
# pole angle: -0.15358082950115204
# pole angular velocity: 0.02549630030989647
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 100:
# Action taken: 1
# cart position: -0.1127077043056488
# cart velocity: -0.7186718583106995
# pole angle: -0.15307089686393738
# pole angular velocity: -0.3114309012889862
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 101:
# Action taken: 0
# cart position: -0.12708114087581635
# cart velocity: -0.911319375038147
# pole angle: -0.15929952263832092
# pole angular velocity: -0.07066571712493896
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 102:
# Action taken: 0
# cart position: -0.1453075259923935
# cart velocity: -1.1038415431976318
# pole angle: -0.1607128381729126
# pole angular velocity: 0.1678248643875122
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 103:
# Action taken: 1
# cart position: -0.16738435626029968
# cart velocity: -0.9068277478218079
# pole angle: -0.15735633671283722
# pole angular velocity: -0.1709340214729309
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 104:
# Action taken: 0
# cart position: -0.18552091717720032
# cart velocity: -1.0993884801864624
# pole angle: -0.16077502071857452
# pole angular velocity: 0.06826640665531158
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 105:
# Action taken: 1
# cart position: -0.20750868320465088
# cart velocity: -0.9023705124855042
# pole angle: -0.15940968692302704
# pole angular velocity: -0.2705138325691223
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 106:
# Action taken: 0
# cart position: -0.22555609047412872
# cart velocity: -1.094901204109192
# pole angle: -0.16481997072696686
# pole angular velocity: -0.03204761818051338
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 107:
# Action taken: 0
# cart position: -0.24745412170886993
# cart velocity: -1.2873231172561646
# pole angle: -0.16546091437339783
# pole angular velocity: 0.20443567633628845
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 108:
# Action taken: 1
# cart position: -0.2732005715370178
# cart velocity: -1.0902690887451172
# pole angle: -0.16137219965457916
# pole angular velocity: -0.1355322301387787
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 109:
# Action taken: 0
# cart position: -0.2950059473514557
# cart velocity: -1.282755970954895
# pole angle: -0.1640828549861908
# pole angular velocity: 0.10220906138420105
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 110:
# Action taken: 1
# cart position: -0.3206610679626465
# cart velocity: -1.0857092142105103
# pole angle: -0.1620386689901352
# pole angular velocity: -0.23741532862186432
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 111:
# Action taken: 0
# cart position: -0.3423752784729004
# cart velocity: -1.2781901359558105
# pole angle: -0.16678698360919952
# pole angular velocity: 9.264315303880721e-05
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 112:
# Action taken: 0
# cart position: -0.3679390549659729
# cart velocity: -1.4705761671066284
# pole angle: -0.1667851209640503
# pole angular velocity: 0.2358589470386505
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 113:
# Action taken: 1
# cart position: -0.39735057950019836
# cart velocity: -1.273512840270996
# pole angle: -0.1620679497718811
# pole angular velocity: -0.10444211959838867
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 114:
# Action taken: 0
# cart position: -0.4228208363056183
# cart velocity: -1.4659860134124756
# pole angle: -0.16415679454803467
# pole angular velocity: 0.13304464519023895
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 115:
# Action taken: 1
# cart position: -0.45214056968688965
# cart velocity: -1.268939733505249
# pole angle: -0.1614958941936493
# pole angular velocity: -0.20659689605236053
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 116:
# Action taken: 0
# cart position: -0.47751936316490173
# cart velocity: -1.461428165435791
# pole angle: -0.1656278371810913
# pole angular velocity: 0.031105101108551025
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 117:
# Action taken: 0
# cart position: -0.5067479014396667
# cart velocity: -1.6538355350494385
# pole angle: -0.16500572860240936
# pole angular velocity: 0.26729413866996765
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 118:
# Action taken: 1
# cart position: -0.5398246645927429
# cart velocity: -1.4567903280258179
# pole angle: -0.15965984761714935
# pole angular velocity: -0.0725509449839592
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 119:
# Action taken: 0
# cart position: -0.568960428237915
# cart velocity: -1.6493059396743774
# pole angle: -0.16111086308956146
# pole angular velocity: 0.16580897569656372
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 120:
# Action taken: 0
# cart position: -0.6019465923309326
# cart velocity: -1.841799020767212
# pole angle: -0.15779468417167664
# pole angular velocity: 0.4036473035812378
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 121:
# Action taken: 1
# cart position: -0.6387825608253479
# cart velocity: -1.6448322534561157
# pole angle: -0.14972174167633057
# pole angular velocity: 0.06566845625638962
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 122:
# Action taken: 0
# cart position: -0.6716791987419128
# cart velocity: -1.8375258445739746
# pole angle: -0.14840836822986603
# pole angular velocity: 0.3076213002204895
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 123:
# Action taken: 1
# cart position: -0.7084296941757202
# cart velocity: -1.6406352519989014
# pole angle: -0.14225594699382782
# pole angular velocity: -0.02794022299349308
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 124:
# Action taken: 0
# cart position: -0.7412424087524414
# cart velocity: -1.8334609270095825
# pole angle: -0.1428147554397583
# pole angular velocity: 0.21669432520866394
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 125:
# Action taken: 0
# cart position: -0.7779116034507751
# cart velocity: -2.0262832641601562
# pole angle: -0.13848085701465607
# pole angular velocity: 0.4611380994319916
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 126:
# Action taken: 1
# cart position: -0.8184372782707214
# cart velocity: -1.8295035362243652
# pole angle: -0.12925809621810913
# pole angular velocity: 0.1282109171152115
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 127:
# Action taken: 0
# cart position: -0.8550273776054382
# cart velocity: -2.022559642791748
# pole angle: -0.12669388949871063
# pole angular velocity: 0.37748321890830994
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 128:
# Action taken: 1
# cart position: -0.8954785466194153
# cart velocity: -1.8258874416351318
# pole angle: -0.11914421617984772
# pole angular velocity: 0.04769091308116913
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 129:
# Action taken: 0
# cart position: -0.9319962859153748
# cart velocity: -2.0191173553466797
# pole angle: -0.11819040030241013
# pole angular velocity: 0.3005353510379791
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 130:
# Action taken: 0
# cart position: -0.972378671169281
# cart velocity: -2.212373733520508
# pole angle: -0.112179696559906
# pole angular velocity: 0.5537305474281311
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 131:
# Action taken: 1
# cart position: -1.0166261196136475
# cart velocity: -2.0158700942993164
# pole angle: -0.10110508650541306
# pole angular velocity: 0.22791609168052673
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 132:
# Action taken: 0
# cart position: -1.0569435358047485
# cart velocity: -2.2094128131866455
# pole angle: -0.09654676169157028
# pole angular velocity: 0.48707324266433716
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 133:
# Action taken: 1
# cart position: -1.101131796836853
# cart velocity: -2.013070583343506
# pole angle: -0.0868052989244461
# pole angular velocity: 0.16559085249900818
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 134:
# Action taken: 0
# cart position: -1.1413931846618652
# cart velocity: -2.2068495750427246
# pole angle: -0.08349347859621048
# pole angular velocity: 0.42967626452445984
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 135:
# Action taken: 1
# cart position: -1.185530185699463
# cart velocity: -2.010650634765625
# pole angle: -0.07489995658397675
# pole angular velocity: 0.1118844673037529
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 136:
# Action taken: 0
# cart position: -1.2257431745529175
# cart velocity: -2.2046239376068115
# pole angle: -0.07266226410865784
# pole angular velocity: 0.38002854585647583
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 137:
# Action taken: 0
# cart position: -1.2698357105255127
# cart velocity: -2.3986427783966064
# pole angle: -0.06506169587373734
# pole angular velocity: 0.6489450931549072
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 138:
# Action taken: 1
# cart position: -1.3178085088729858
# cart velocity: -2.2026777267456055
# pole angle: -0.052082791924476624
# pole angular velocity: 0.3365047574043274
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 139:
# Action taken: 0
# cart position: -1.361862063407898
# cart velocity: -2.3970212936401367
# pole angle: -0.04535269737243652
# pole angular velocity: 0.6123194098472595
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 140:
# Action taken: 1
# cart position: -1.4098025560379028
# cart velocity: -2.201295852661133
# pole angle: -0.03310630843043327
# pole angular velocity: 0.3057039678096771
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 141:
# Action taken: 0
# cart position: -1.4538284540176392
# cart velocity: -2.395930767059326
# pole angle: -0.026992229744791985
# pole angular velocity: 0.5877648591995239
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 142:
# Action taken: 1
# cart position: -1.5017470121383667
# cart velocity: -2.200441360473633
# pole angle: -0.015236932784318924
# pole angular velocity: 0.2867029011249542
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 143:
# Action taken: 0
# cart position: -1.5457558631896973
# cart velocity: -2.3953428268432617
# pole angle: -0.009502874687314034
# pole angular velocity: 0.5745415687561035
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 144:
# Action taken: 1
# cart position: -1.5936627388000488
# cart velocity: -2.2000889778137207
# pole angle: 0.0019879566971212626
# pole angular velocity: 0.27888014912605286
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 145:
# Action taken: 0
# cart position: -1.637664556503296
# cart velocity: -2.3952391147613525
# pole angle: 0.007565559819340706
# pole angular velocity: 0.572189450263977
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 146:
# Action taken: 1
# cart position: -1.6855692863464355
# cart velocity: -2.2002241611480713
# pole angle: 0.01900934800505638
# pole angular velocity: 0.28189948201179504
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 147:
# Action taken: 0
# cart position: -1.7295738458633423
# cart velocity: -2.3956120014190674
# pole angle: 0.024647338315844536
# pole angular velocity: 0.5805167555809021
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 148:
# Action taken: 1
# cart position: -1.7774860858917236
# cart velocity: -2.2008440494537354
# pole angle: 0.03625767305493355
# pole angular velocity: 0.29569897055625916
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 149:
# Action taken: 0
# cart position: -1.821502923965454
# cart velocity: -2.396463632583618
# pole angle: 0.0421716533601284
# pole angular velocity: 0.599592924118042
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 150:
# Action taken: 1
# cart position: -1.8694322109222412
# cart velocity: -2.201956272125244
# pole angle: 0.054163508117198944
# pole angular velocity: 0.32048606872558594
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 151:
# Action taken: 0
# cart position: -1.9134713411331177
# cart velocity: -2.39780592918396
# pole angle: 0.06057323142886162
# pole angular velocity: 0.6297461986541748
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 152:
# Action taken: 1
# cart position: -1.9614274501800537
# cart velocity: -2.2035791873931885
# pole angle: 0.07316815853118896
# pole angular velocity: 0.3567381203174591
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 153:
# Action taken: 0
# cart position: -2.0054991245269775
# cart velocity: -2.399661064147949
# pole angle: 0.08030291646718979
# pole angular velocity: 0.6715661287307739
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 154:
# Action taken: 1
# cart position: -2.053492307662964
# cart velocity: -2.2057418823242188
# pole angle: 0.0937342420220375
# pole angular velocity: 0.4052083194255829
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 155:
# Action taken: 0
# cart position: -2.097607135772705
# cart velocity: -2.402059316635132
# pole angle: 0.10183840245008469
# pole angular velocity: 0.7259094715118408
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 156:
# Action taken: 1
# cart position: -2.145648241043091
# cart velocity: -2.208482027053833
# pole angle: 0.11635659635066986
# pole angular velocity: 0.46693655848503113
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 157:
# Action taken: 0
# cart position: -2.1898179054260254
# cart velocity: -2.405039072036743
# pole angle: 0.1256953328847885
# pole angular velocity: 0.7939103245735168
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 158:
# Action taken: 1
# cart position: -2.2379186153411865
# cart velocity: -2.211845874786377
# pole angle: 0.14157353341579437
# pole angular velocity: 0.5432640314102173
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 159:
# Action taken: 1
# cart position: -2.2821555137634277
# cart velocity: -2.018967628479004
# pole angle: 0.15243881940841675
# pole angular velocity: 0.29832491278648376
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 160:
# Action taken: 0
# cart position: -2.3225350379943848
# cart velocity: -2.2158966064453125
# pole angle: 0.15840531885623932
# pole angular velocity: 0.6349365711212158
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 161:
# Action taken: 1
# cart position: -2.3668529987335205
# cart velocity: -2.0232973098754883
# pole angle: 0.1711040437221527
# pole angular velocity: 0.3960311710834503
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 162:
# Action taken: 1
# cart position: -2.4073188304901123
# cart velocity: -1.8309636116027832
# pole angle: 0.17902466654777527
# pole angular velocity: 0.16180291771888733
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 162.0

# %%
obs_explanation = """\
**Observation vector (4 values):**
1. **Cart Position (m)** — horizontal position on the track (≈ -4.8 to +4.8).
2. **Cart Velocity (m/s)** — how fast the cart moves (unbounded float in practice).
3. **Pole Angle (rad)** — tilt of the pole relative to vertical (≈ -0.4189 to +0.4189 rad ≈ ±24°).
4. **Pole Angular Velocity (rad/s)** — how fast the pole is rotating (unbounded float in practice).
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- **Pole tilt exceeds ±0.4189 rad (~±24°)** → `terminated = True`
- **Cart position leaves track bounds (≈ ±4.8 m)** → `terminated = True`
- **Time limit of 500 steps is reached** → `truncated = True`
"""

with open(report_file, "w")as f:
    f.write("# SCRUM-15: Researching Cartpole test write\n\n")
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Example Run\n")
    f.write(f"- Starting observation: {observation.tolist()}\n")
    f.write(f"- Total reward: {total_reward}\n")

# %%
import matplotlib.pyplot as plt
import numpy as np
from stable_baselines3.common.evaluation import evaluate_policy

def generate_learning_curve(model, env, graphs_dir, num_eval_episodes=20, eval_freq=200, total_timesteps=2000):
    """
    Evaluate the model at regular intervals and plot learning curve.
    """
    rewards = []
    timesteps = []

    for step in range(eval_freq, total_timesteps + 1, eval_freq):
        # Evaluate policy
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=num_eval_episodes, deterministic=True)
        rewards.append(mean_reward)
        timesteps.append(step)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(timesteps, rewards, marker="o", label="Mean Reward")
    plt.xlabel("Timesteps")
    plt.ylabel("Mean Reward over Episodes")
    plt.title("Learning Curve (PPO on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

    # Save figure
    graph_file = graphs_dir / "learning_curve.png"
    plt.savefig(graph_file, dpi=200, bbox_inches="tight")
    plt.close()

    print(f"Learning curve saved to {graph_file}")


generate_learning_curve(model, env, graphs_dir, num_eval_episodes=10, eval_freq=200, total_timesteps=1000)
# Out:
# Learning curve saved to ../../documentation/cartpole/ppo-cartpole/run_2025-10-04>12:14:14/graphs/learning_curve.png
