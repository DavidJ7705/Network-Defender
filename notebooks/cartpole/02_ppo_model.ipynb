# %%
import gymnasium as gym
from pathlib import Path
from gymnasium.wrappers import RecordVideo
from datetime import datetime
from stable_baselines3 import PPO

# %%
docs_path = Path("../../documentation/cartpole/ppo-cartpole") 

run_id = datetime.now().strftime("%Y-%m-%d>%H:%M:%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "ppo_cartpole"

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array") 
env = RecordVideo(
    env,
    video_folder=str(video_dir),
    episode_trigger=lambda e: True,
    name_prefix="cartpole_random_baseline" 
)
# Out:
# /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/.venv_mac/lib/python3.9/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/davidjayakumar/Library/CloudStorage/OneDrive-AtlanticTU/YEAR 4/Project Engineering/Network-Defender/documentation/cartpole/ppo-cartpole/run_2025-10-02>16:15:07/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=1000)

model.save(str(model_file))
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | 21.2     |
# | time/              |          |
# |    fps             | 134      |
# |    iterations      | 1        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2048     |
# ---------------------------------

# %%
# Reset environment
observation, info = env.reset(seed=42)

print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Action space: Discrete(2)
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Starting observation: [ 0.0273956  -0.00611216  0.03585979  0.0197368 ]
# maxiumum number of steps per episode: 500

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["cart position", "cart velocity", "pole angle", "pole angular velocity"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(action)

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}")

    for label, observe in zip(labels,observation):
        print(f"{label}: {observe}")

    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 1
# cart position: 0.02727336250245571
# cart velocity: 0.18847766518592834
# pole angle: 0.036254528909921646
# pole angular velocity: -0.26141977310180664
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 0
# cart position: 0.0310429148375988
# cart velocity: -0.007142550311982632
# pole angle: 0.03102613240480423
# pole angular velocity: 0.04247424006462097
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 1
# cart position: 0.03090006485581398
# cart velocity: 0.1875210702419281
# pole angle: 0.0318756178021431
# pole angular velocity: -0.24026045203208923
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 0
# cart position: 0.03465048596262932
# cart velocity: -0.0080413818359375
# pole angle: 0.027070408686995506
# pole angular velocity: 0.062304068356752396
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 1
# cart position: 0.03448965772986412
# cart velocity: 0.18668219447135925
# pole angle: 0.028316490352153778
# pole angular velocity: -0.22171655297279358
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 0
# cart position: 0.038223300129175186
# cart velocity: -0.008832814171910286
# pole angle: 0.02388215810060501
# pole angular velocity: 0.07976232469081879
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 7:
# Action taken: 1
# cart position: 0.03804664686322212
# cart velocity: 0.1859387904405594
# pole angle: 0.02547740563750267
# pole angular velocity: -0.20529106259346008
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 8:
# Action taken: 0
# cart position: 0.041765421628952026
# cart velocity: -0.009538063779473305
# pole angle: 0.02137158438563347
# pole angular velocity: 0.09531859308481216
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 9:
# Action taken: 1
# cart position: 0.04157466068863869
# cart velocity: 0.18527115881443024
# pole angle: 0.023277955129742622
# pole angular velocity: -0.19054575264453888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 10:
# Action taken: 0
# cart position: 0.045280084013938904
# cart velocity: -0.010175937786698341
# pole angle: 0.01946704089641571
# pole angular velocity: 0.1093885749578476
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 11:
# Action taken: 1
# cart position: 0.04507656395435333
# cart velocity: 0.18466173112392426
# pole angle: 0.02165481261909008
# pole angular velocity: -0.17708958685398102
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 12:
# Action taken: 0
# cart position: 0.04876979812979698
# cart velocity: -0.010763324797153473
# pole angle: 0.018113020807504654
# pole angular velocity: 0.12234526872634888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 13:
# Action taken: 1
# cart position: 0.04855453222990036
# cart velocity: 0.18409450352191925
# pole angle: 0.020559925585985184
# pole angular velocity: -0.16456858813762665
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 14:
# Action taken: 0
# cart position: 0.05223642289638519
# cart velocity: -0.011315638199448586
# pole angle: 0.017268553376197815
# pole angular velocity: 0.13452886044979095
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 15:
# Action taken: 1
# cart position: 0.05201010778546333
# cart velocity: 0.1835547536611557
# pole angle: 0.019959131255745888
# pole angular velocity: -0.1526564508676529
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 16:
# Action taken: 0
# cart position: 0.05568120628595352
# cart velocity: -0.011847210116684437
# pole angle: 0.016906002536416054
# pole angular velocity: 0.1462557315826416
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 17:
# Action taken: 1
# cart position: 0.05544425919651985
# cart velocity: 0.18302860856056213
# pole angle: 0.019831117242574692
# pole angular velocity: -0.14104610681533813
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 18:
# Action taken: 0
# cart position: 0.059104833751916885
# cart velocity: -0.01237166952341795
# pole angle: 0.017010195180773735
# pole angular velocity: 0.15782664716243744
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 19:
# Action taken: 1
# cart position: 0.058857399970293045
# cart velocity: 0.18250267207622528
# pole angle: 0.020166728645563126
# pole angular velocity: -0.12944181263446808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 20:
# Action taken: 0
# cart position: 0.06250745058059692
# cart velocity: -0.012902283109724522
# pole angle: 0.017577892169356346
# pole angular velocity: 0.1695346236228943
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 21:
# Action taken: 1
# cart position: 0.062249407172203064
# cart velocity: 0.181963711977005
# pole angle: 0.020968584343791008
# pole angular velocity: -0.11755158007144928
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 22:
# Action taken: 0
# cart position: 0.06588868051767349
# cart velocity: -0.013452299870550632
# pole angle: 0.018617553636431694
# pole angular velocity: 0.18167231976985931
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 23:
# Action taken: 1
# cart position: 0.06561963260173798
# cart velocity: 0.18139836192131042
# pole angle: 0.02225099876523018
# pole angular velocity: -0.10507979243993759
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 24:
# Action taken: 0
# cart position: 0.06924760341644287
# cart velocity: -0.014035270549356937
# pole angle: 0.02014940418303013
# pole angular velocity: 0.19453935325145721
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 25:
# Action taken: 1
# cart position: 0.06896689534187317
# cart velocity: 0.18079274892807007
# pole angle: 0.024040190503001213
# pole angular velocity: -0.09171982109546661
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 26:
# Action taken: 0
# cart position: 0.07258275151252747
# cart velocity: -0.014665385708212852
# pole angle: 0.022205794230103493
# pole angular velocity: 0.20844979584217072
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 27:
# Action taken: 1
# cart position: 0.07228944450616837
# cart velocity: 0.18013212084770203
# pole angle: 0.02637479081749916
# pole angular velocity: -0.07714646309614182
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 28:
# Action taken: 0
# cart position: 0.07589208334684372
# cart velocity: -0.015357806347310543
# pole angle: 0.0248318612575531
# pole angular velocity: 0.22373972833156586
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 29:
# Action taken: 1
# cart position: 0.07558493316173553
# cart velocity: 0.17940059304237366
# pole angle: 0.029306655749678612
# pole angular velocity: -0.06100798398256302
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 30:
# Action taken: 0
# cart position: 0.07917293906211853
# cart velocity: -0.01612902618944645
# pole angle: 0.028086496517062187
# pole angular velocity: 0.24077542126178741
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 31:
# Action taken: 1
# cart position: 0.07885035872459412
# cart velocity: 0.17858068645000458
# pole angle: 0.032902006059885025
# pole angular velocity: -0.04291761294007301
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 32:
# Action taken: 1
# cart position: 0.08242197334766388
# cart velocity: 0.37321576476097107
# pole angle: 0.03204365074634552
# pole angular velocity: -0.3250407576560974
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 33:
# Action taken: 0
# cart position: 0.08988629281520844
# cart velocity: 0.17765256762504578
# pole angle: 0.025542836636304855
# pole angular velocity: -0.022427339106798172
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 34:
# Action taken: 1
# cart position: 0.09343934059143066
# cart velocity: 0.37239906191825867
# pole angle: 0.02509428933262825
# pole angular velocity: -0.30694302916526794
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 35:
# Action taken: 0
# cart position: 0.10088732093572617
# cart velocity: 0.17692869901657104
# pole angle: 0.018955430015921593
# pole angular velocity: -0.00645283330231905
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 36:
# Action taken: 1
# cart position: 0.10442589968442917
# cart velocity: 0.37177374958992004
# pole angle: 0.018826372921466827
# pole angular velocity: -0.29309532046318054
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 37:
# Action taken: 0
# cart position: 0.11186137050390244
# cart velocity: 0.17638850212097168
# pole angle: 0.012964465655386448
# pole angular velocity: 0.005465216469019651
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 38:
# Action taken: 1
# cart position: 0.1153891459107399
# cart velocity: 0.3713221549987793
# pole angle: 0.013073770329356194
# pole angular velocity: -0.2830992341041565
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 39:
# Action taken: 0
# cart position: 0.1228155866265297
# cart velocity: 0.1760161817073822
# pole angle: 0.007411785423755646
# pole angular velocity: 0.013678251765668392
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 40:
# Action taken: 1
# cart position: 0.12633590400218964
# cart velocity: 0.3710310459136963
# pole angle: 0.007685350254178047
# pole angular velocity: -0.27665698528289795
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 41:
# Action taken: 0
# cart position: 0.13375653326511383
# cart velocity: 0.17580030858516693
# pole angle: 0.0021522107999771833
# pole angular velocity: 0.018439961597323418
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 42:
# Action taken: 1
# cart position: 0.13727253675460815
# cart velocity: 0.3708913326263428
# pole angle: 0.0025210101157426834
# pole angular velocity: -0.2735631465911865
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 43:
# Action taken: 0
# cart position: 0.1446903645992279
# cart velocity: 0.17573349177837372
# pole angle: -0.0029502527322620153
# pole angular velocity: 0.019913852214813232
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 44:
# Action taken: 1
# cart position: 0.14820502698421478
# cart velocity: 0.3708976209163666
# pole angle: -0.0025519756600260735
# pole angular velocity: -0.27369844913482666
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 45:
# Action taken: 0
# cart position: 0.15562298893928528
# cart velocity: 0.17581218481063843
# pole angle: -0.008025945164263248
# pole angular velocity: 0.018178483471274376
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 46:
# Action taken: 1
# cart position: 0.1591392308473587
# cart velocity: 0.37104833126068115
# pole angle: -0.007662374991923571
# pole angular velocity: -0.27702587842941284
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 47:
# Action taken: 0
# cart position: 0.16656020283699036
# cart velocity: 0.1760365217924118
# pole angle: -0.013202892616391182
# pole angular velocity: 0.0132305221632123
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 48:
# Action taken: 1
# cart position: 0.17008092999458313
# cart velocity: 0.37134531140327454
# pole angle: -0.012938282452523708
# pole angular velocity: -0.2835886478424072
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 49:
# Action taken: 0
# cart position: 0.17750783264636993
# cart velocity: 0.1764102578163147
# pole angle: -0.01861005462706089
# pole angular velocity: 0.004985686857253313
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 50:
# Action taken: 1
# cart position: 0.18103604018688202
# cart velocity: 0.37179407477378845
# pole angle: -0.01851034164428711
# pole angular velocity: -0.2935103476047516
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 51:
# Action taken: 0
# cart position: 0.18847191333770752
# cart velocity: 0.17694087326526642
# pole angle: -0.024380547925829887
# pole angular velocity: -0.006722329184412956
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 52:
# Action taken: 1
# cart position: 0.19201073050498962
# cart velocity: 0.3724038302898407
# pole angle: -0.024514995515346527
# pole angular velocity: -0.30699682235717773
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 53:
# Action taken: 0
# cart position: 0.19945880770683289
# cart velocity: 0.17763963341712952
# pole angle: -0.03065493144094944
# pole angular velocity: -0.022144978865981102
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 54:
# Action taken: 1
# cart position: 0.20301160216331482
# cart velocity: 0.37318748235702515
# pole angle: -0.031097831204533577
# pole angular velocity: -0.3243401050567627
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 55:
# Action taken: 0
# cart position: 0.210475355386734
# cart velocity: 0.17852181196212769
# pole angle: -0.03758463263511658
# pole angular velocity: -0.041624054312705994
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 56:
# Action taken: 0
# cart position: 0.21404579281806946
# cart velocity: -0.016041584312915802
# pole angle: -0.038417115807533264
# pole angular velocity: 0.2389676570892334
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 57:
# Action taken: 1
# cart position: 0.21372495591640472
# cart velocity: 0.17960752546787262
# pole angle: -0.03363776206970215
# pole angular velocity: -0.065581314265728
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 58:
# Action taken: 0
# cart position: 0.2173171043395996
# cart velocity: -0.015016409568488598
# pole angle: -0.03494938835501671
# pole angular velocity: 0.2163017988204956
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 59:
# Action taken: 1
# cart position: 0.2170167863368988
# cart velocity: 0.1805872917175293
# pole angle: -0.03062335215508938
# pole angular velocity: -0.08719760179519653
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 60:
# Action taken: 0
# cart position: 0.2206285297870636
# cart velocity: -0.014082626439630985
# pole angle: -0.03236730396747589
# pole angular velocity: 0.19566850364208221
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 61:
# Action taken: 1
# cart position: 0.22034688293933868
# cart velocity: 0.18148699402809143
# pole angle: -0.02845393307507038
# pole angular velocity: -0.10704661160707474
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 62:
# Action taken: 0
# cart position: 0.22397661209106445
# cart velocity: -0.013215887360274792
# pole angle: -0.03059486486017704
# pole angular velocity: 0.17652517557144165
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 63:
# Action taken: 1
# cart position: 0.22371229529380798
# cart velocity: 0.18233025074005127
# pole angle: -0.027064362540841103
# pole angular velocity: -0.12565024197101593
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 64:
# Action taken: 0
# cart position: 0.22735890746116638
# cart velocity: -0.01239373441785574
# pole angle: -0.02957736700773239
# pole angular velocity: 0.15837280452251434
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 65:
# Action taken: 1
# cart position: 0.22711102664470673
# cart velocity: 0.1831389218568802
# pole angle: -0.02640991099178791
# pole angular velocity: -0.14349235594272614
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 66:
# Action taken: 0
# cart position: 0.23077380657196045
# cart velocity: -0.011595048941671848
# pole angle: -0.029279757291078568
# pole angular velocity: 0.14074310660362244
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 67:
# Action taken: 1
# cart position: 0.2305418998003006
# cart velocity: 0.18393374979496002
# pole angle: -0.02646489627659321
# pole angular velocity: -0.16103139519691467
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 68:
# Action taken: 0
# cart position: 0.23422057926654816
# cart velocity: -0.010799526236951351
# pole angle: -0.029685523360967636
# pole angular velocity: 0.12318646162748337
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 69:
# Action taken: 1
# cart position: 0.23400458693504333
# cart velocity: 0.18473486602306366
# pole angle: -0.027221793308854103
# pole angular velocity: -0.1787121593952179
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 70:
# Action taken: 0
# cart position: 0.23769928514957428
# cart velocity: -0.009987171739339828
# pole angle: -0.03079603798687458
# pole angular velocity: 0.1052604615688324
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 71:
# Action taken: 1
# cart position: 0.23749954998493195
# cart velocity: 0.18556226789951324
# pole angle: -0.028690828010439873
# pole angular velocity: -0.19697721302509308
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 72:
# Action taken: 0
# cart position: 0.24121078848838806
# cart velocity: -0.009137808345258236
# pole angle: -0.032630372792482376
# pole angular velocity: 0.08651875704526901
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 73:
# Action taken: 1
# cart position: 0.24102802574634552
# cart velocity: 0.18643631041049957
# pole angle: -0.030899997800588608
# pole angular velocity: -0.21627788245677948
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 74:
# Action taken: 0
# cart position: 0.2447567582130432
# cart velocity: -0.008230587467551231
# pole angle: -0.035225555300712585
# pole angular velocity: 0.06649991124868393
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 75:
# Action taken: 1
# cart position: 0.24459214508533478
# cart velocity: 0.18737822771072388
# pole angle: -0.03389555588364601
# pole angular velocity: -0.2370854616165161
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 76:
# Action taken: 0
# cart position: 0.2483397126197815
# cart velocity: -0.007243487983942032
# pole angle: -0.03863726556301117
# pole angular velocity: 0.044716041535139084
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 77:
# Action taken: 1
# cart position: 0.2481948435306549
# cart velocity: 0.18841059505939484
# pole angle: -0.03774294629693031
# pole angular velocity: -0.25990256667137146
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 78:
# Action taken: 0
# cart position: 0.2519630491733551
# cart velocity: -0.006152801681309938
# pole angle: -0.04294099658727646
# pole angular velocity: 0.02064087614417076
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 79:
# Action taken: 1
# cart position: 0.2518399953842163
# cart velocity: 0.18955782055854797
# pole angle: -0.0425281785428524
# pole angular velocity: -0.2852752208709717
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 80:
# Action taken: 0
# cart position: 0.25563114881515503
# cart velocity: -0.004932600073516369
# pole angle: -0.04823368415236473
# pole angular velocity: -0.006302882917225361
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 81:
# Action taken: 1
# cart position: 0.25553250312805176
# cart velocity: 0.19084671139717102
# pole angle: -0.048359740525484085
# pole angular velocity: -0.3138055205345154
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 82:
# Action taken: 0
# cart position: 0.25934943556785583
# cart velocity: -0.003554169787093997
# pole angle: -0.054635852575302124
# pole angular velocity: -0.03675732761621475
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 83:
# Action taken: 0
# cart position: 0.2592783570289612
# cart velocity: -0.19785179197788239
# pole angle: -0.0553709976375103
# pole angular velocity: 0.23819927871227264
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 84:
# Action taken: 1
# cart position: 0.25532132387161255
# cart velocity: -0.001984325936064124
# pole angle: -0.05060701072216034
# pole angular velocity: -0.07142241299152374
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 85:
# Action taken: 0
# cart position: 0.25528162717819214
# cart velocity: -0.19634559750556946
# pole angle: -0.052035462111234665
# pole angular velocity: 0.20487412810325623
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 86:
# Action taken: 1
# cart position: 0.25135472416877747
# cart velocity: -0.0005196205456741154
# pole angle: -0.04793797805905342
# pole angular velocity: -0.10375876724720001
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 87:
# Action taken: 0
# cart position: 0.25134432315826416
# cart velocity: -0.19492296874523163
# pole angle: -0.05001315474510193
# pole angular velocity: 0.1734228879213333
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 88:
# Action taken: 1
# cart position: 0.24744586646556854
# cart velocity: 0.000877781247254461
# pole angle: -0.046544697135686874
# pole angular velocity: -0.13460873067378998
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 89:
# Action taken: 0
# cart position: 0.2474634200334549
# cart velocity: -0.19354763627052307
# pole angle: -0.04923687130212784
# pole angular velocity: 0.14303435385227203
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 90:
# Action taken: 1
# cart position: 0.24359247088432312
# cart velocity: 0.002243614988401532
# pole angle: -0.04637618362903595
# pole angular velocity: -0.16476640105247498
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 91:
# Action taken: 0
# cart position: 0.2436373382806778
# cart velocity: -0.19218483567237854
# pole angle: -0.049671512097120285
# pole angular velocity: 0.11293300241231918
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 92:
# Action taken: 1
# cart position: 0.23979364335536957
# cart velocity: 0.0036123667377978563
# pole angle: -0.047412849962711334
# pole angular velocity: -0.19499799609184265
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 93:
# Action taken: 0
# cart position: 0.23986589908599854
# cart velocity: -0.19080044329166412
# pole angle: -0.05131281167268753
# pole angular velocity: 0.08235934376716614
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 94:
# Action taken: 1
# cart position: 0.23604989051818848
# cart velocity: 0.005018091294914484
# pole angle: -0.04966562241315842
# pole angular velocity: -0.22606119513511658
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 95:
# Action taken: 0
# cart position: 0.23615024983882904
# cart velocity: -0.18936017155647278
# pole angle: -0.05418684706091881
# pole angular velocity: 0.05055098980665207
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 96:
# Action taken: 1
# cart position: 0.2323630452156067
# cart velocity: 0.006495202891528606
# pole angle: -0.053175829350948334
# pole angular velocity: -0.25872400403022766
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 97:
# Action taken: 0
# cart position: 0.23249295353889465
# cart velocity: -0.18782886862754822
# pole angle: -0.05835030972957611
# pole angular velocity: 0.0167237501591444
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 98:
# Action taken: 1
# cart position: 0.22873637080192566
# cart velocity: 0.008079246617853642
# pole angle: -0.05801583454012871
# pole angular velocity: -0.2937835454940796
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 99:
# Action taken: 0
# cart position: 0.22889795899391174
# cart velocity: -0.18616963922977448
# pole angle: -0.06389150768518448
# pole angular velocity: -0.019947541877627373
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 100:
# Action taken: 0
# cart position: 0.22517456114292145
# cart velocity: -0.38031989336013794
# pole angle: -0.06429045647382736
# pole angular velocity: 0.25191232562065125
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 101:
# Action taken: 1
# cart position: 0.21756815910339355
# cart velocity: -0.18434162437915802
# pole angle: -0.05925220996141434
# pole angular velocity: -0.0603361502289772
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 102:
# Action taken: 0
# cart position: 0.21388132870197296
# cart velocity: -0.378566175699234
# pole angle: -0.06045893207192421
# pole angular velocity: 0.21307945251464844
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 103:
# Action taken: 1
# cart position: 0.20631000399589539
# cart velocity: -0.18263427913188934
# pole angle: -0.05619734153151512
# pole angular velocity: -0.09804551303386688
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 104:
# Action taken: 0
# cart position: 0.2026573270559311
# cart velocity: -0.3769076466560364
# pole angle: -0.05815825238823891
# pole angular velocity: 0.17639119923114777
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 105:
# Action taken: 1
# cart position: 0.19511917233467102
# cart velocity: -0.18100370466709137
# pole angle: -0.054630428552627563
# pole angular velocity: -0.13405679166316986
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 106:
# Action taken: 0
# cart position: 0.19149909913539886
# cart velocity: -0.3753023147583008
# pole angle: -0.057311564683914185
# pole angular velocity: 0.14090293645858765
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 107:
# Action taken: 1
# cart position: 0.18399304151535034
# cart velocity: -0.17940835654735565
# pole angle: -0.054493505507707596
# pole angular velocity: -0.16929590702056885
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 108:
# Action taken: 0
# cart position: 0.1804048866033554
# cart velocity: -0.37370967864990234
# pole angle: -0.05787942558526993
# pole angular velocity: 0.10571028292179108
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 109:
# Action taken: 1
# cart position: 0.17293068766593933
# cart velocity: -0.17780810594558716
# pole angle: -0.055765219032764435
# pole angular velocity: -0.20465706288814545
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 110:
# Action taken: 0
# cart position: 0.1693745255470276
# cart velocity: -0.37209007143974304
# pole angle: -0.05985835939645767
# pole angular velocity: 0.06992639601230621
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 111:
# Action taken: 1
# cart position: 0.16193272173404694
# cart velocity: -0.17616331577301025
# pole angle: -0.05845983326435089
# pole angular velocity: -0.24102525413036346
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 112:
# Action taken: 0
# cart position: 0.1584094613790512
# cart velocity: -0.37040355801582336
# pole angle: -0.06328033655881882
# pole angular velocity: 0.032660000026226044
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 113:
# Action taken: 1
# cart position: 0.15100137889385223
# cart velocity: -0.17443391680717468
# pole angle: -0.06262713670730591
# pole angular velocity: -0.2792981266975403
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 114:
# Action taken: 0
# cart position: 0.14751270413398743
# cart velocity: -0.36860916018486023
# pole angle: -0.0682130977511406
# pole angular velocity: -0.007006610278040171
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 115:
# Action taken: 1
# cart position: 0.14014051854610443
# cart velocity: -0.1725786030292511
# pole angle: -0.06835323572158813
# pole angular velocity: -0.3204077184200287
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 116:
# Action taken: 0
# cart position: 0.1366889476776123
# cart velocity: -0.3666639029979706
# pole angle: -0.07476138323545456
# pole angular velocity: -0.050039783120155334
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 117:
# Action taken: 0
# cart position: 0.12935566902160645
# cart velocity: -0.5606386661529541
# pole angle: -0.07576218247413635
# pole angular velocity: 0.21815021336078644
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 118:
# Action taken: 1
# cart position: 0.11814290285110474
# cart velocity: -0.36452004313468933
# pole angle: -0.07139917463064194
# pole angular velocity: -0.09743660688400269
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 119:
# Action taken: 0
# cart position: 0.11085250228643417
# cart velocity: -0.5585499405860901
# pole angle: -0.07334791123867035
# pole angular velocity: 0.1718931347131729
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 120:
# Action taken: 1
# cart position: 0.09968150407075882
# cart velocity: -0.3624589741230011
# pole angle: -0.06991004943847656
# pole angular velocity: -0.1429973691701889
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 121:
# Action taken: 0
# cart position: 0.09243232011795044
# cart velocity: -0.5565137267112732
# pole angle: -0.07276999205350876
# pole angular velocity: 0.1268368512392044
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 122:
# Action taken: 1
# cart position: 0.08130204677581787
# cart velocity: -0.3604287803173065
# pole angle: -0.07023325562477112
# pole angular velocity: -0.18788759410381317
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 123:
# Action taken: 0
# cart position: 0.07409347593784332
# cart velocity: -0.5544793009757996
# pole angle: -0.07399100810289383
# pole angular velocity: 0.08183896541595459
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 124:
# Action taken: 1
# cart position: 0.06300388276576996
# cart velocity: -0.35837897658348083
# pole angle: -0.07235422730445862
# pole angular velocity: -0.23324021697044373
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 125:
# Action taken: 0
# cart position: 0.055836308747529984
# cart velocity: -0.5523965358734131
# pole angle: -0.07701903581619263
# pole angular velocity: 0.035771068185567856
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 126:
# Action taken: 1
# cart position: 0.04478837549686432
# cart velocity: -0.35625940561294556
# pole angle: -0.07630361616611481
# pole angular velocity: -0.2801836133003235
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 127:
# Action taken: 0
# cart position: 0.037663187831640244
# cart velocity: -0.5502146482467651
# pole angle: -0.08190728724002838
# pole angular velocity: -0.012508758343756199
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 128:
# Action taken: 0
# cart position: 0.02665889449417591
# cart velocity: -0.7440722584724426
# pole angle: -0.08215746283531189
# pole angular velocity: 0.253248929977417
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 129:
# Action taken: 1
# cart position: 0.011777449399232864
# cart velocity: -0.547879159450531
# pole angle: -0.0770924836397171
# pole angular velocity: -0.06417520344257355
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 130:
# Action taken: 0
# cart position: 0.0008198663708753884
# cart velocity: -0.741815984249115
# pole angle: -0.07837598770856857
# pole angular velocity: 0.20322328805923462
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 131:
# Action taken: 1
# cart position: -0.014016454108059406
# cart velocity: -0.5456658005714417
# pole angle: -0.0743115171790123
# pole angular velocity: -0.11311780661344528
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 132:
# Action taken: 0
# cart position: -0.024929769337177277
# cart velocity: -0.7396485805511475
# pole angle: -0.07657387852668762
# pole angular velocity: 0.15522590279579163
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 133:
# Action taken: 1
# cart position: -0.039722740650177
# cart velocity: -0.5435185432434082
# pole angle: -0.07346935570240021
# pole angular velocity: -0.1605978161096573
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 134:
# Action taken: 0
# cart position: -0.05059311166405678
# cart velocity: -0.7375159859657288
# pole angle: -0.07668131589889526
# pole angular velocity: 0.10803277045488358
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 135:
# Action taken: 1
# cart position: -0.06534343212842941
# cart velocity: -0.541383683681488
# pole angle: -0.07452066242694855
# pole angular velocity: -0.20782333612442017
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 136:
# Action taken: 0
# cart position: -0.07617110759019852
# cart velocity: -0.7353653311729431
# pole angle: -0.07867712527513504
# pole angular velocity: 0.060452744364738464
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 137:
# Action taken: 1
# cart position: -0.09087841212749481
# cart velocity: -0.5392086505889893
# pole angle: -0.07746806740760803
# pole angular velocity: -0.2559793293476105
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 138:
# Action taken: 0
# cart position: -0.10166258364915848
# cart velocity: -0.7331439852714539
# pole angle: -0.08258765935897827
# pole angular velocity: 0.011298385448753834
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 139:
# Action taken: 1
# cart position: -0.11632546037435532
# cart velocity: -0.5369406938552856
# pole angle: -0.08236169070005417
# pole angular velocity: -0.30625662207603455
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 140:
# Action taken: 0
# cart position: -0.1270642727613449
# cart velocity: -0.7307983040809631
# pole angle: -0.08848682045936584
# pole angular velocity: -0.040642861276865005
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 141:
# Action taken: 0
# cart position: -0.14168024063110352
# cart velocity: -0.9245472550392151
# pole angle: -0.08929967880249023
# pole angular velocity: 0.2228623628616333
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 142:
# Action taken: 1
# cart position: -0.16017119586467743
# cart velocity: -0.7282699942588806
# pole angle: -0.08484243601560593
# pole angular velocity: -0.09659969806671143
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 143:
# Action taken: 0
# cart position: -0.17473658919334412
# cart velocity: -0.9220799207687378
# pole angle: -0.08677442371845245
# pole angular velocity: 0.16815578937530518
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 144:
# Action taken: 1
# cart position: -0.193178191781044
# cart velocity: -0.7258299589157104
# pole angle: -0.0834113135933876
# pole angular velocity: -0.15059120953083038
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 145:
# Action taken: 0
# cart position: -0.20769478380680084
# cart velocity: -0.9196646213531494
# pole angle: -0.08642313629388809
# pole angular velocity: 0.11465540528297424
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 146:
# Action taken: 1
# cart position: -0.22608807682991028
# cart velocity: -0.7234175205230713
# pole angle: -0.08413002640008926
# pole angular velocity: -0.20399343967437744
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 147:
# Action taken: 0
# cart position: -0.24055643379688263
# cart velocity: -0.9172418713569641
# pole angle: -0.08820989727973938
# pole angular velocity: 0.06100974604487419
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 148:
# Action taken: 1
# cart position: -0.2589012682437897
# cart velocity: -0.7209731936454773
# pole angle: -0.08698970079421997
# pole angular velocity: -0.258148729801178
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 149:
# Action taken: 0
# cart position: -0.273320734500885
# cart velocity: -0.9147524833679199
# pole angle: -0.0921526774764061
# pole angular velocity: 0.005878395400941372
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 150:
# Action taken: 0
# cart position: -0.2916157841682434
# cart velocity: -1.1084402799606323
# pole angle: -0.09203510731458664
# pole angular velocity: 0.2681228220462799
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 151:
# Action taken: 1
# cart position: -0.31378456950187683
# cart velocity: -0.9121336340904236
# pole angle: -0.08667264878749847
# pole angular velocity: -0.05211108922958374
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 152:
# Action taken: 0
# cart position: -0.33202725648880005
# cart velocity: -1.1059128046035767
# pole angle: -0.08771487325429916
# pole angular velocity: 0.21201665699481964
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 153:
# Action taken: 1
# cart position: -0.35414549708366394
# cart velocity: -0.9096533060073853
# pole angle: -0.0834745392203331
# pole angular velocity: -0.10699582099914551
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 154:
# Action taken: 0
# cart position: -0.37233856320381165
# cart velocity: -1.1034860610961914
# pole angle: -0.08561445772647858
# pole angular velocity: 0.1582278162240982
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 155:
# Action taken: 1
# cart position: -0.39440828561782837
# cart velocity: -0.9072493314743042
# pole angle: -0.08244989812374115
# pole angular velocity: -0.16018904745578766
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 156:
# Action taken: 0
# cart position: -0.4125532805919647
# cart velocity: -1.101099967956543
# pole angle: -0.08565367758274078
# pole angular velocity: 0.1053864136338234
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 157:
# Action taken: 1
# cart position: -0.43457528948783875
# cart velocity: -0.9048616886138916
# pole angle: -0.08354595303535461
# pole angular velocity: -0.21304337680339813
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 158:
# Action taken: 0
# cart position: -0.4526725113391876
# cart velocity: -1.098695993423462
# pole angle: -0.0878068208694458
# pole angular velocity: 0.052159976214170456
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 159:
# Action taken: 1
# cart position: -0.4746464490890503
# cart velocity: -0.902431845664978
# pole angle: -0.08676362037658691
# pole angular velocity: -0.2668840289115906
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 160:
# Action taken: 0
# cart position: -0.49269506335258484
# cart velocity: -1.0962152481079102
# pole angle: -0.09210129827260971
# pole angular velocity: -0.00277882837690413
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 161:
# Action taken: 0
# cart position: -0.5146193504333496
# cart velocity: -1.2899038791656494
# pole angle: -0.09215687960386276
# pole angular velocity: 0.259483277797699
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 162:
# Action taken: 1
# cart position: -0.5404174327850342
# cart velocity: -1.0935955047607422
# pole angle: -0.08696721494197845
# pole angular velocity: -0.06078565865755081
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 163:
# Action taken: 0
# cart position: -0.5622893571853638
# cart velocity: -1.2873698472976685
# pole angle: -0.08818292617797852
# pole angular velocity: 0.203241229057312
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 164:
# Action taken: 1
# cart position: -0.5880367755889893
# cart velocity: -1.0911046266555786
# pole angle: -0.08411809802055359
# pole angular velocity: -0.1159047782421112
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 165:
# Action taken: 0
# cart position: -0.6098588705062866
# cart velocity: -1.2849268913269043
# pole angle: -0.0864361971616745
# pole angular velocity: 0.14909903705120087
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 166:
# Action taken: 1
# cart position: -0.6355574131011963
# cart velocity: -1.088680386543274
# pole angle: -0.08345421403646469
# pole angular velocity: -0.16955238580703735
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 167:
# Action taken: 0
# cart position: -0.6573309898376465
# cart velocity: -1.2825148105621338
# pole angle: -0.086845263838768
# pole angular velocity: 0.09568029642105103
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 168:
# Action taken: 1
# cart position: -0.6829813122749329
# cart velocity: -1.0862624645233154
# pole angle: -0.08493165671825409
# pole angular velocity: -0.2230892777442932
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 169:
# Action taken: 0
# cart position: -0.7047065496444702
# cart velocity: -1.2800742387771606
# pole angle: -0.08939344435930252
# pole angular velocity: 0.04164065793156624
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 170:
# Action taken: 1
# cart position: -0.7303080558776855
# cart velocity: -1.083791732788086
# pole angle: -0.08856063336133957
# pole angular velocity: -0.27785423398017883
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 171:
# Action taken: 0
# cart position: -0.7519838809967041
# cart velocity: -1.2775459289550781
# pole angle: -0.09411771595478058
# pole angular velocity: -0.014364620670676231
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 172:
# Action taken: 0
# cart position: -0.7775347828865051
# cart velocity: -1.471200942993164
# pole angle: -0.09440501034259796
# pole angular velocity: 0.24720247089862823
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 173:
# Action taken: 1
# cart position: -0.806958794593811
# cart velocity: -1.2748664617538452
# pole angle: -0.08946096152067184
# pole angular velocity: -0.07370185106992722
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 174:
# Action taken: 0
# cart position: -0.832456111907959
# cart velocity: -1.468599557876587
# pole angle: -0.09093499183654785
# pole angular velocity: 0.18946926295757294
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 175:
# Action taken: 1
# cart position: -0.8618281483650208
# cart velocity: -1.272302269935608
# pole angle: -0.0871456116437912
# pole angular velocity: -0.13045814633369446
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 176:
# Action taken: 0
# cart position: -0.8872741460800171
# cart velocity: -1.4660747051239014
# pole angle: -0.08975477516651154
# pole angular velocity: 0.13350924849510193
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 177:
# Action taken: 1
# cart position: -0.9165956974029541
# cart velocity: -1.269789457321167
# pole angle: -0.08708459138870239
# pole angular velocity: -0.18608607351779938
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 178:
# Action taken: 0
# cart position: -0.9419914484024048
# cart velocity: -1.4635645151138306
# pole angle: -0.09080631285905838
# pole angular velocity: 0.07790448516607285
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 179:
# Action taken: 1
# cart position: -0.9712627530097961
# cart velocity: -1.267266035079956
# pole angle: -0.08924821764230728
# pole angular velocity: -0.24199043214321136
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 180:
# Action taken: 0
# cart position: -0.9966080784797668
# cart velocity: -1.4610072374343872
# pole angle: -0.09408802539110184
# pole angular velocity: 0.02126067504286766
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 181:
# Action taken: 0
# cart position: -1.025828242301941
# cart velocity: -1.6546627283096313
# pole angle: -0.0936628133058548
# pole angular velocity: 0.28283804655075073
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 182:
# Action taken: 1
# cart position: -1.058921456336975
# cart velocity: -1.4583383798599243
# pole angle: -0.08800605684518814
# pole angular velocity: -0.03785442188382149
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 183:
# Action taken: 0
# cart position: -1.0880882740020752
# cart velocity: -1.6520953178405762
# pole angle: -0.08876314014196396
# pole angular velocity: 0.2258158028125763
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 184:
# Action taken: 1
# cart position: -1.121130108833313
# cart velocity: -1.4558242559432983
# pole angle: -0.08424682915210724
# pole angular velocity: -0.09349377453327179
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 185:
# Action taken: 0
# cart position: -1.1502466201782227
# cart velocity: -1.6496440172195435
# pole angle: -0.08611670136451721
# pole angular velocity: 0.1714654266834259
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 186:
# Action taken: 1
# cart position: -1.183239459991455
# cart velocity: -1.453401803970337
# pole angle: -0.0826873928308487
# pole angular velocity: -0.14709405601024628
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 187:
# Action taken: 0
# cart position: -1.2123075723648071
# cart velocity: -1.6472482681274414
# pole angle: -0.08562927693128586
# pole angular velocity: 0.11839979141950607
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 188:
# Action taken: 1
# cart position: -1.2452524900436401
# cart velocity: -1.4510104656219482
# pole angle: -0.08326128125190735
# pole angular velocity: -0.20002266764640808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 189:
# Action taken: 0
# cart position: -1.2742726802825928
# cart velocity: -1.6448490619659424
# pole angle: -0.08726172894239426
# pole angular velocity: 0.06527732312679291
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 190:
# Action taken: 1
# cart position: -1.3071696758270264
# cart velocity: -1.4485913515090942
# pole angle: -0.08595618605613708
# pole angular velocity: -0.25361141562461853
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 191:
# Action taken: 0
# cart position: -1.336141586303711
# cart velocity: -1.6423875093460083
# pole angle: -0.09102841466665268
# pole angular velocity: 0.010769562795758247
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 192:
# Action taken: 0
# cart position: -1.3689892292022705
# cart velocity: -1.8360941410064697
# pole angle: -0.09081302583217621
# pole angular velocity: 0.27340102195739746
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 193:
# Action taken: 1
# cart position: -1.4057111740112305
# cart velocity: -1.6398016214370728
# pole angle: -0.08534500002861023
# pole angular velocity: -0.046486735343933105
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 194:
# Action taken: 0
# cart position: -1.4385071992874146
# cart velocity: -1.8336026668548584
# pole angle: -0.08627473562955856
# pole angular velocity: 0.2180958092212677
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 195:
# Action taken: 1
# cart position: -1.4751791954040527
# cart velocity: -1.6373602151870728
# pole angle: -0.0819128230214119
# pole angular velocity: -0.10050643235445023
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 196:
# Action taken: 0
# cart position: -1.5079264640808105
# cart velocity: -1.8312184810638428
# pole angle: -0.08392295241355896
# pole angular velocity: 0.16525055468082428
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 197:
# Action taken: 1
# cart position: -1.5445507764816284
# cart velocity: -1.6350016593933105
# pole angle: -0.08061794191598892
# pole angular velocity: -0.15268312394618988
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 198:
# Action taken: 0
# cart position: -1.5772508382797241
# cart velocity: -1.8288823366165161
# pole angle: -0.08367159962654114
# pole angular velocity: 0.11351721733808517
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 199:
# Action taken: 1
# cart position: -1.6138285398483276
# cart velocity: -1.6326673030853271
# pole angle: -0.08140125870704651
# pole angular velocity: -0.20434637367725372
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 200:
# Action taken: 0
# cart position: -1.6464818716049194
# cart velocity: -1.8265365362167358
# pole angle: -0.08548818528652191
# pole angular velocity: 0.06158897280693054
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 201:
# Action taken: 1
# cart position: -1.68301260471344
# cart velocity: -1.63029944896698
# pole angle: -0.08425640314817429
# pole angular velocity: -0.2567945122718811
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 202:
# Action taken: 0
# cart position: -1.71561861038208
# cart velocity: -1.824123740196228
# pole angle: -0.0893922969698906
# pole angular velocity: 0.008168425410985947
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 203:
# Action taken: 0
# cart position: -1.7521010637283325
# cart velocity: -2.017857551574707
# pole angle: -0.08922892808914185
# pole angular velocity: 0.27136242389678955
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 204:
# Action taken: 1
# cart position: -1.792458176612854
# cart velocity: -1.8215831518173218
# pole angle: -0.08380167931318283
# pole angular velocity: -0.04807642847299576
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 205:
# Action taken: 0
# cart position: -1.8288898468017578
# cart velocity: -2.0154097080230713
# pole angle: -0.08476320654153824
# pole angular velocity: 0.2170342355966568
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 206:
# Action taken: 1
# cart position: -1.8691980838775635
# cart velocity: -1.8191847801208496
# pole angle: -0.08042252063751221
# pole angular velocity: -0.10113701224327087
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 207:
# Action taken: 0
# cart position: -1.9055817127227783
# cart velocity: -2.0130674839019775
# pole angle: -0.08244526386260986
# pole angular velocity: 0.1651284396648407
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 208:
# Action taken: 1
# cart position: -1.9458431005477905
# cart velocity: -1.8168680667877197
# pole angle: -0.07914268970489502
# pole angular velocity: -0.1523825228214264
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 209:
# Action taken: 0
# cart position: -1.9821804761886597
# cart velocity: -2.010772943496704
# pole angle: -0.08219034224748611
# pole angular velocity: 0.1143205314874649
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 210:
# Action taken: 1
# cart position: -2.0223958492279053
# cart velocity: -1.8145753145217896
# pole angle: -0.07990393042564392
# pole angular velocity: -0.20311912894248962
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 211:
# Action taken: 0
# cart position: -2.058687448501587
# cart velocity: -2.0084691047668457
# pole angle: -0.08396631479263306
# pole angular velocity: 0.06332670152187347
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 212:
# Action taken: 1
# cart position: -2.0988566875457764
# cart velocity: -1.812249779701233
# pole angle: -0.08269978314638138
# pole angular velocity: -0.254622220993042
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 213:
# Action taken: 0
# cart position: -2.135101795196533
# cart velocity: -2.0060994625091553
# pole angle: -0.08779222518205643
# pole angular velocity: 0.010872604325413704
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 214:
# Action taken: 0
# cart position: -2.1752238273620605
# cart velocity: -2.199859857559204
# pole angle: -0.08757477253675461
# pole angular velocity: 0.2746160328388214
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 215:
# Action taken: 1
# cart position: -2.2192208766937256
# cart velocity: -2.0036046504974365
# pole angle: -0.08208245038986206
# pole angular velocity: -0.044352710247039795
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 216:
# Action taken: 0
# cart position: -2.2592930793762207
# cart velocity: -2.1974596977233887
# pole angle: -0.08296950906515121
# pole angular velocity: 0.22134539484977722
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 217:
# Action taken: 1
# cart position: -2.3032422065734863
# cart velocity: -2.001255750656128
# pole angle: -0.07854259759187698
# pole angular velocity: -0.09631301462650299
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 218:
# Action taken: 0
# cart position: -2.3432674407958984
# cart velocity: -2.19516921043396
# pole angle: -0.08046886324882507
# pole angular velocity: 0.1705927550792694
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 219:
# Action taken: 1
# cart position: -2.3871707916259766
# cart velocity: -1.9989932775497437
# pole angle: -0.07705700397491455
# pole angular velocity: -0.14635135233402252
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 220:
# Action taken: 0
# cart position: -2.4271507263183594
# cart velocity: -2.192931890487671
# pole angle: -0.07998403161764145
# pole angular velocity: 0.12106114625930786
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 220.0

# %%
obs_explanation = """\
**Observation vector (4 values):**
1. **Cart Position (m)** — horizontal position on the track (≈ -4.8 to +4.8).
2. **Cart Velocity (m/s)** — how fast the cart moves (unbounded float in practice).
3. **Pole Angle (rad)** — tilt of the pole relative to vertical (≈ -0.4189 to +0.4189 rad ≈ ±24°).
4. **Pole Angular Velocity (rad/s)** — how fast the pole is rotating (unbounded float in practice).
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- **Pole tilt exceeds ±0.4189 rad (~±24°)** → `terminated = True`
- **Cart position leaves track bounds (≈ ±4.8 m)** → `terminated = True`
- **Time limit of 500 steps is reached** → `truncated = True`
"""

with open(report_file, "w")as f:
    f.write("# SCRUM-15: Researching Cartpole test write\n\n")
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Example Run\n")
    f.write(f"- Starting observation: {observation.tolist()}\n")
    f.write(f"- Total reward: {total_reward}\n")
