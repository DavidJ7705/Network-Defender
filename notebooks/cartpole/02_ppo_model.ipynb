# %%
import gymnasium as gym
from pathlib import Path
from gymnasium.wrappers import RecordVideo
from datetime import datetime
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy
import matplotlib.pyplot as plt
import numpy as np

# %%
docs_path = Path("../../documentation/cartpole/ppo-cartpole") 

run_id = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
run_path = docs_path / f"run_{run_id}"

video_dir = run_path / "videos"
graphs_dir  = run_path / "graphs"
report_file = run_path / "run_log.md"
model_dir = run_path / "model"
monitor_dir = run_path / "monitor"

docs_path.mkdir(parents=True, exist_ok=True)
graphs_dir.mkdir(parents=True, exist_ok=True)
video_dir.mkdir(parents=True, exist_ok=True)
model_dir.mkdir(parents=True, exist_ok=True)
monitor_dir.mkdir(parents=True, exist_ok=True)

model_file = model_dir / "ppo_cartpole"
monitor_file = str(monitor_dir) #/ "monitor_log.csv"

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array") 
# env = RecordVideo(
#     env,
#     video_folder=str(video_dir),
#     episode_trigger=lambda e: True,
#     name_prefix="cartpole_random_baseline" 
# )
env = Monitor(env, monitor_file)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)
model.save(str(model_file))
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | 23.5     |
# | time/              |          |
# |    fps             | 6182     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.9        |
# |    ep_rew_mean          | 26.9        |
# | time/                   |             |
# |    fps                  | 4212        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009112985 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00041     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.58        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 58.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.2        |
# |    ep_rew_mean          | 35.2        |
# | time/                   |             |
# |    fps                  | 3524        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012182838 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0896      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 34.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 46.1         |
# |    ep_rew_mean          | 46.1         |
# | time/                   |              |
# |    fps                  | 3458         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0069824154 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.64        |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0154      |
# |    value_loss           | 54           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61           |
# |    ep_rew_mean          | 61           |
# | time/                   |              |
# |    fps                  | 3439         |
# |    iterations           | 5            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0070704576 |
# |    clip_fraction        | 0.061        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.621       |
# |    explained_variance   | 0.275        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.7         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0162      |
# |    value_loss           | 57.9         |
# ------------------------------------------

# %%
# Reset environment
observation, info = env.reset(seed=42)

print(f"Action space: {env.action_space}") 
print(f"Observation space: {env.observation_space}") 
print(f"Starting observation: {observation}")
print(f"maxiumum number of steps per episode: {env.spec.max_episode_steps}")
# Out:
# Action space: Discrete(2)
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Starting observation: [ 0.0273956  -0.00611216  0.03585979  0.0197368 ]
# maxiumum number of steps per episode: 500

# %%
step = 0
total_reward = 0
episode_over = False

# %%
labels = ["cart position", "cart velocity", "pole angle", "pole angular velocity"]

while not episode_over:
    step += 1
    action, state = model.predict(observation,deterministic=True)  
    observation, reward, terminated, truncated, info = env.step(action)

    total_reward += reward
    episode_over = terminated or truncated

    print(f"Step {step}:")
    print(f"Action taken: {action}")

    for label, observe in zip(labels,observation):
        print(f"{label}: {observe}")

    print(f"Reward: {reward}")
    print(f"Terminated: {terminated}, Truncated: {truncated}")
    print("-" * 50)

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Step 1:
# Action taken: 1
# cart position: 0.02727336250245571
# cart velocity: 0.18847766518592834
# pole angle: 0.036254528909921646
# pole angular velocity: -0.26141977310180664
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 2:
# Action taken: 0
# cart position: 0.0310429148375988
# cart velocity: -0.007142550311982632
# pole angle: 0.03102613240480423
# pole angular velocity: 0.04247424006462097
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 3:
# Action taken: 1
# cart position: 0.03090006485581398
# cart velocity: 0.1875210702419281
# pole angle: 0.0318756178021431
# pole angular velocity: -0.24026045203208923
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 4:
# Action taken: 0
# cart position: 0.03465048596262932
# cart velocity: -0.0080413818359375
# pole angle: 0.027070408686995506
# pole angular velocity: 0.062304068356752396
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 5:
# Action taken: 1
# cart position: 0.03448965772986412
# cart velocity: 0.18668219447135925
# pole angle: 0.028316490352153778
# pole angular velocity: -0.22171655297279358
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 6:
# Action taken: 0
# cart position: 0.038223300129175186
# cart velocity: -0.008832814171910286
# pole angle: 0.02388215810060501
# pole angular velocity: 0.07976232469081879
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 7:
# Action taken: 1
# cart position: 0.03804664686322212
# cart velocity: 0.1859387904405594
# pole angle: 0.02547740563750267
# pole angular velocity: -0.20529106259346008
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 8:
# Action taken: 0
# cart position: 0.041765421628952026
# cart velocity: -0.009538063779473305
# pole angle: 0.02137158438563347
# pole angular velocity: 0.09531859308481216
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 9:
# Action taken: 1
# cart position: 0.04157466068863869
# cart velocity: 0.18527115881443024
# pole angle: 0.023277955129742622
# pole angular velocity: -0.19054575264453888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 10:
# Action taken: 0
# cart position: 0.045280084013938904
# cart velocity: -0.010175937786698341
# pole angle: 0.01946704089641571
# pole angular velocity: 0.1093885749578476
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 11:
# Action taken: 1
# cart position: 0.04507656395435333
# cart velocity: 0.18466173112392426
# pole angle: 0.02165481261909008
# pole angular velocity: -0.17708958685398102
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 12:
# Action taken: 0
# cart position: 0.04876979812979698
# cart velocity: -0.010763324797153473
# pole angle: 0.018113020807504654
# pole angular velocity: 0.12234526872634888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 13:
# Action taken: 1
# cart position: 0.04855453222990036
# cart velocity: 0.18409450352191925
# pole angle: 0.020559925585985184
# pole angular velocity: -0.16456858813762665
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 14:
# Action taken: 0
# cart position: 0.05223642289638519
# cart velocity: -0.011315638199448586
# pole angle: 0.017268553376197815
# pole angular velocity: 0.13452886044979095
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 15:
# Action taken: 1
# cart position: 0.05201010778546333
# cart velocity: 0.1835547536611557
# pole angle: 0.019959131255745888
# pole angular velocity: -0.1526564508676529
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 16:
# Action taken: 0
# cart position: 0.05568120628595352
# cart velocity: -0.011847210116684437
# pole angle: 0.016906002536416054
# pole angular velocity: 0.1462557315826416
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 17:
# Action taken: 1
# cart position: 0.05544425919651985
# cart velocity: 0.18302860856056213
# pole angle: 0.019831117242574692
# pole angular velocity: -0.14104610681533813
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 18:
# Action taken: 0
# cart position: 0.059104833751916885
# cart velocity: -0.01237166952341795
# pole angle: 0.017010195180773735
# pole angular velocity: 0.15782664716243744
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 19:
# Action taken: 1
# cart position: 0.058857399970293045
# cart velocity: 0.18250267207622528
# pole angle: 0.020166728645563126
# pole angular velocity: -0.12944181263446808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 20:
# Action taken: 0
# cart position: 0.06250745058059692
# cart velocity: -0.012902283109724522
# pole angle: 0.017577892169356346
# pole angular velocity: 0.1695346236228943
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 21:
# Action taken: 1
# cart position: 0.062249407172203064
# cart velocity: 0.181963711977005
# pole angle: 0.020968584343791008
# pole angular velocity: -0.11755158007144928
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 22:
# Action taken: 0
# cart position: 0.06588868051767349
# cart velocity: -0.013452299870550632
# pole angle: 0.018617553636431694
# pole angular velocity: 0.18167231976985931
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 23:
# Action taken: 1
# cart position: 0.06561963260173798
# cart velocity: 0.18139836192131042
# pole angle: 0.02225099876523018
# pole angular velocity: -0.10507979243993759
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 24:
# Action taken: 0
# cart position: 0.06924760341644287
# cart velocity: -0.014035270549356937
# pole angle: 0.02014940418303013
# pole angular velocity: 0.19453935325145721
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 25:
# Action taken: 1
# cart position: 0.06896689534187317
# cart velocity: 0.18079274892807007
# pole angle: 0.024040190503001213
# pole angular velocity: -0.09171982109546661
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 26:
# Action taken: 0
# cart position: 0.07258275151252747
# cart velocity: -0.014665385708212852
# pole angle: 0.022205794230103493
# pole angular velocity: 0.20844979584217072
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 27:
# Action taken: 1
# cart position: 0.07228944450616837
# cart velocity: 0.18013212084770203
# pole angle: 0.02637479081749916
# pole angular velocity: -0.07714646309614182
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 28:
# Action taken: 1
# cart position: 0.07589208334684372
# cart velocity: 0.374866247177124
# pole angle: 0.0248318612575531
# pole angular velocity: -0.3613927662372589
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 29:
# Action taken: 0
# cart position: 0.08338940888643265
# cart velocity: 0.17940029501914978
# pole angle: 0.017604006454348564
# pole angular velocity: -0.06098440662026405
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 30:
# Action taken: 1
# cart position: 0.08697741478681564
# cart velocity: 0.3742654621601105
# pole angle: 0.016384316608309746
# pole angular velocity: -0.34806159138679504
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 31:
# Action taken: 0
# cart position: 0.09446272999048233
# cart velocity: 0.17891435325145721
# pole angle: 0.009423085488379002
# pole angular velocity: -0.050257470458745956
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 32:
# Action taken: 1
# cart position: 0.09804101288318634
# cart velocity: 0.3738999366760254
# pole angle: 0.00841793604195118
# pole angular velocity: -0.3399524986743927
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 33:
# Action taken: 0
# cart position: 0.10551901161670685
# cart velocity: 0.17865923047065735
# pole angle: 0.0016188863664865494
# pole angular velocity: -0.04462696984410286
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 34:
# Action taken: 1
# cart position: 0.10909219831228256
# cart velocity: 0.373757928609848
# pole angle: 0.000726347032468766
# pole angular velocity: -0.33679866790771484
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 35:
# Action taken: 0
# cart position: 0.11656735837459564
# cart velocity: 0.17862564325332642
# pole angle: -0.006009626667946577
# pole angular velocity: -0.04388679191470146
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 36:
# Action taken: 1
# cart position: 0.12013986706733704
# cart velocity: 0.37383323907852173
# pole angle: -0.006887362338602543
# pole angular velocity: -0.33845973014831543
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 37:
# Action taken: 0
# cart position: 0.1276165395975113
# cart velocity: 0.1788099855184555
# pole angle: -0.0136565575376153
# pole angular velocity: -0.04795663803815842
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 38:
# Action taken: 0
# cart position: 0.13119272887706757
# cart velocity: -0.016113510355353355
# pole angle: -0.01461569033563137
# pole angular velocity: 0.24038642644882202
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 39:
# Action taken: 1
# cart position: 0.13087046146392822
# cart velocity: 0.17921414971351624
# pole angle: -0.00980796106159687
# pole angular velocity: -0.05687061697244644
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 40:
# Action taken: 0
# cart position: 0.13445474207401276
# cart velocity: -0.01576581411063671
# pole angle: -0.010945373214781284
# pole angular velocity: 0.23270176351070404
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 41:
# Action taken: 1
# cart position: 0.13413943350315094
# cart velocity: 0.17951080203056335
# pole angle: -0.006291338708251715
# pole angular velocity: -0.06341350078582764
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 42:
# Action taken: 0
# cart position: 0.13772964477539062
# cart velocity: -0.015520378947257996
# pole angle: -0.007559608668088913
# pole angular velocity: 0.22727784514427185
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 43:
# Action taken: 1
# cart position: 0.13741923868656158
# cart velocity: 0.179708793759346
# pole angle: -0.0030140515882521868
# pole angular velocity: -0.067780040204525
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 44:
# Action taken: 0
# cart position: 0.14101341366767883
# cart velocity: -0.015369822271168232
# pole angle: -0.004369652364403009
# pole angular velocity: 0.22395041584968567
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 45:
# Action taken: 1
# cart position: 0.14070601761341095
# cart velocity: 0.17981430888175964
# pole angle: 0.00010935596947092563
# pole angular velocity: -0.07010766118764877
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 46:
# Action taken: 0
# cart position: 0.14430230855941772
# cart velocity: -0.015309209935367107
# pole angle: -0.0012927971547469497
# pole angular velocity: 0.2226097732782364
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 47:
# Action taken: 1
# cart position: 0.14399611949920654
# cart velocity: 0.17983119189739227
# pole angle: 0.0031593982130289078
# pole angular velocity: -0.07048067450523376
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 48:
# Action taken: 0
# cart position: 0.14759273827075958
# cart velocity: -0.01533590815961361
# pole angle: 0.0017497846856713295
# pole angular velocity: 0.22319738566875458
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 49:
# Action taken: 1
# cart position: 0.14728602766990662
# cart velocity: 0.17976099252700806
# pole angle: 0.006213732063770294
# pole angular velocity: -0.06893308460712433
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 50:
# Action taken: 0
# cart position: 0.15088124573230743
# cart velocity: -0.015449492260813713
# pole angle: 0.004835070576518774
# pole angular velocity: 0.22570380568504333
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 51:
# Action taken: 1
# cart position: 0.1505722552537918
# cart velocity: 0.17960302531719208
# pole angle: 0.009349146857857704
# pole angular velocity: -0.0654500350356102
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 52:
# Action taken: 0
# cart position: 0.15416431427001953
# cart velocity: -0.01565171219408512
# pole angle: 0.008040145970880985
# pole angular velocity: 0.23016788065433502
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 53:
# Action taken: 1
# cart position: 0.15385128557682037
# cart velocity: 0.17935442924499512
# pole angle: 0.012643503956496716
# pole angular velocity: -0.05996810644865036
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 54:
# Action taken: 0
# cart position: 0.15743836760520935
# cart velocity: -0.01594650000333786
# pole angle: 0.011444141156971455
# pole angular velocity: 0.23667696118354797
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 55:
# Action taken: 1
# cart position: 0.15711943805217743
# cart velocity: 0.17901009321212769
# pole angle: 0.01617768034338951
# pole angular velocity: -0.052374277263879776
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 56:
# Action taken: 0
# cart position: 0.16069963574409485
# cart velocity: -0.016340041533112526
# pole angle: 0.015130194835364819
# pole angular velocity: 0.2453686147928238
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 57:
# Action taken: 1
# cart position: 0.16037283837795258
# cart velocity: 0.17856258153915405
# pole angle: 0.020037567242980003
# pole angular velocity: -0.04250374063849449
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 58:
# Action taken: 1
# cart position: 0.1639440953731537
# cart velocity: 0.3733915388584137
# pole angle: 0.01918749324977398
# pole angular velocity: -0.3287978768348694
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 59:
# Action taken: 0
# cart position: 0.1714119166135788
# cart velocity: 0.1780017763376236
# pole angle: 0.012611535377800465
# pole angular velocity: -0.03012639470398426
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 60:
# Action taken: 1
# cart position: 0.17497195303440094
# cart velocity: 0.37294062972068787
# pole angle: 0.012009006924927235
# pole angular velocity: -0.31880372762680054
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 61:
# Action taken: 0
# cart position: 0.18243077397346497
# cart velocity: 0.17764970660209656
# pole angle: 0.005632932763546705
# pole angular velocity: -0.022357910871505737
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 62:
# Action taken: 1
# cart position: 0.18598376214504242
# cart velocity: 0.37269043922424316
# pole angle: 0.005185774527490139
# pole angular velocity: -0.31325826048851013
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 63:
# Action taken: 0
# cart position: 0.1934375762939453
# cart velocity: 0.17749498784542084
# pole angle: -0.0010793908732011914
# pole angular velocity: -0.01894443854689598
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 64:
# Action taken: 1
# cart position: 0.19698747992515564
# cart velocity: 0.3726324141025543
# pole angle: -0.0014582796720787883
# pole angular velocity: -0.31196773052215576
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 65:
# Action taken: 0
# cart position: 0.20444011688232422
# cart velocity: 0.17753125727176666
# pole angle: -0.007697634398937225
# pole angular velocity: -0.019745057448744774
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 66:
# Action taken: 0
# cart position: 0.20799075067043304
# cart velocity: -0.017479458823800087
# pole angle: -0.00809253565967083
# pole angular velocity: 0.27049925923347473
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 67:
# Action taken: 1
# cart position: 0.20764115452766418
# cart velocity: 0.17775703966617584
# pole angle: -0.0026825498789548874
# pole angular velocity: -0.02472505532205105
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 68:
# Action taken: 0
# cart position: 0.21119630336761475
# cart velocity: -0.017326345667243004
# pole angle: -0.003177050966769457
# pole angular velocity: 0.26711028814315796
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 69:
# Action taken: 1
# cart position: 0.21084977686405182
# cart velocity: 0.17784079909324646
# pole angle: 0.0021651547867804766
# pole angular velocity: -0.02657300792634487
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 70:
# Action taken: 0
# cart position: 0.2144065946340561
# cart velocity: -0.017312131822109222
# pole angle: 0.0016336946282535791
# pole angular velocity: 0.26679226756095886
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 71:
# Action taken: 1
# cart position: 0.21406035125255585
# cart velocity: 0.1777864694595337
# pole angle: 0.006969539914280176
# pole angular velocity: -0.025374935939908028
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 72:
# Action taken: 0
# cart position: 0.21761608123779297
# cart velocity: -0.01743473671376705
# pole angle: 0.006462041288614273
# pole angular velocity: 0.2694987952709198
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 73:
# Action taken: 1
# cart position: 0.21726737916469574
# cart velocity: 0.1775944083929062
# pole angle: 0.011852016672492027
# pole angular velocity: -0.0211389921605587
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 74:
# Action taken: 1
# cart position: 0.22081926465034485
# cart velocity: 0.37254440784454346
# pole angle: 0.011429237201809883
# pole angular velocity: -0.3100590407848358
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 75:
# Action taken: 0
# cart position: 0.22827015817165375
# cart velocity: 0.17726148664951324
# pole angle: 0.005228056106716394
# pole angular velocity: -0.013793676160275936
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 76:
# Action taken: 1
# cart position: 0.2318153828382492
# cart velocity: 0.37230807542800903
# pole angle: 0.0049521829932928085
# pole angular velocity: -0.30482250452041626
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 77:
# Action taken: 0
# cart position: 0.23926155269145966
# cart velocity: 0.17711590230464935
# pole angle: -0.0011442675022408366
# pole angular velocity: -0.0105819096788764
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 78:
# Action taken: 0
# cart position: 0.24280387163162231
# cart velocity: -0.017989622429013252
# pole angle: -0.0013559056678786874
# pole angular velocity: 0.2817397713661194
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 79:
# Action taken: 1
# cart position: 0.24244406819343567
# cart velocity: 0.1771516501903534
# pole angle: 0.004278889857232571
# pole angular velocity: -0.011370498687028885
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 80:
# Action taken: 0
# cart position: 0.24598710238933563
# cart velocity: -0.01803141087293625
# pole angle: 0.004051479510962963
# pole angular velocity: 0.2826593816280365
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 81:
# Action taken: 1
# cart position: 0.24562647938728333
# cart velocity: 0.17703251540660858
# pole angle: 0.009704667143523693
# pole angular velocity: -0.008742968551814556
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 82:
# Action taken: 1
# cart position: 0.24916712939739227
# cart velocity: 0.37201395630836487
# pole angle: 0.009529808536171913
# pole angular velocity: -0.29834821820259094
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 83:
# Action taken: 0
# cart position: 0.25660741329193115
# cart velocity: 0.17675746977329254
# pole angle: 0.0035628436598926783
# pole angular velocity: -0.0026750697288662195
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 84:
# Action taken: 1
# cart position: 0.26014256477355957
# cart velocity: 0.3718281388282776
# pole angle: 0.0035093422047793865
# pole angular velocity: -0.29423174262046814
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 85:
# Action taken: 0
# cart position: 0.2675791084766388
# cart velocity: 0.1766563355922699
# pole angle: -0.0023752928245812654
# pole angular velocity: -0.00044409657130017877
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 86:
# Action taken: 0
# cart position: 0.27111223340034485
# cart velocity: -0.018431471660733223
# pole angle: -0.0023841746151447296
# pole angular velocity: 0.2914884388446808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 87:
# Action taken: 1
# cart position: 0.27074360847473145
# cart velocity: 0.1767243891954422
# pole angle: 0.0034455943387001753
# pole angular velocity: -0.0019454610301181674
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 88:
# Action taken: 0
# cart position: 0.27427810430526733
# cart velocity: -0.018446803092956543
# pole angle: 0.0034066850785166025
# pole angular velocity: 0.291822612285614
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 89:
# Action taken: 1
# cart position: 0.27390918135643005
# cart velocity: 0.17662641406059265
# pole angle: 0.009243137203156948
# pole angular velocity: 0.00021604134235531092
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 90:
# Action taken: 1
# cart position: 0.27744171023368835
# cart velocity: 0.37161457538604736
# pole angle: 0.00924745760858059
# pole angular velocity: -0.2895362973213196
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 91:
# Action taken: 0
# cart position: 0.28487399220466614
# cart velocity: 0.17636199295520782
# pole angle: 0.003456732025370002
# pole angular velocity: 0.006048782262951136
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 92:
# Action taken: 1
# cart position: 0.28840121626853943
# cart velocity: 0.37143421173095703
# pole angle: 0.003577707801014185
# pole angular velocity: -0.28554150462150574
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 93:
# Action taken: 0
# cart position: 0.2958299219608307
# cart velocity: 0.17626141011714935
# pole angle: -0.0021331224124878645
# pole angular velocity: 0.008267656899988651
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 94:
# Action taken: 0
# cart position: 0.299355149269104
# cart velocity: -0.01882988028228283
# pole angle: -0.001967769116163254
# pole angular velocity: 0.3002767860889435
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 95:
# Action taken: 1
# cart position: 0.2989785373210907
# cart velocity: 0.17632006108760834
# pole angle: 0.004037766717374325
# pole angular velocity: 0.006973923649638891
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 96:
# Action taken: 0
# cart position: 0.3025049567222595
# cart velocity: -0.018859561532735825
# pole angle: 0.004177245311439037
# pole angular velocity: 0.3009280860424042
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 97:
# Action taken: 1
# cart position: 0.30212774872779846
# cart velocity: 0.17620259523391724
# pole angle: 0.010195806622505188
# pole angular velocity: 0.009565487504005432
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 98:
# Action taken: 1
# cart position: 0.30565181374549866
# cart velocity: 0.3711768686771393
# pole angle: 0.010387116111814976
# pole angular velocity: -0.27988317608833313
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 99:
# Action taken: 0
# cart position: 0.31307533383369446
# cart velocity: 0.17590828239917755
# pole angle: 0.004789452999830246
# pole angular velocity: 0.016057632863521576
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 100:
# Action taken: 1
# cart position: 0.3165934979915619
# cart velocity: 0.3709612190723419
# pole angle: 0.0051106056198477745
# pole angular velocity: -0.2751103341579437
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 101:
# Action taken: 0
# cart position: 0.32401272654533386
# cart velocity: 0.1757667362689972
# pole angle: -0.00039160094456747174
# pole angular velocity: 0.01918010227382183
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 102:
# Action taken: 0
# cart position: 0.32752805948257446
# cart velocity: -0.0193496011197567
# pole angle: -7.998894943739288e-06
# pole angular velocity: 0.311739444732666
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 103:
# Action taken: 1
# cart position: 0.32714107632637024
# cart velocity: 0.17577245831489563
# pole angle: 0.006226790137588978
# pole angular velocity: 0.019053999334573746
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 104:
# Action taken: 1
# cart position: 0.3306565284729004
# cart velocity: 0.3708045780658722
# pole angle: 0.006607870105654001
# pole angular velocity: -0.2716578245162964
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 105:
# Action taken: 0
# cart position: 0.33807262778282166
# cart velocity: 0.1755889505147934
# pole angle: 0.0011747138341888785
# pole angular velocity: 0.023101914674043655
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 106:
# Action taken: 0
# cart position: 0.34158438444137573
# cart velocity: -0.01954982802271843
# pole angle: 0.00163675204385072
# pole angular velocity: 0.31615525484085083
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 107:
# Action taken: 1
# cart position: 0.34119340777397156
# cart velocity: 0.17554877698421478
# pole angle: 0.007959856651723385
# pole angular velocity: 0.023988943547010422
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 108:
# Action taken: 1
# cart position: 0.34470435976982117
# cart velocity: 0.37055566906929016
# pole angle: 0.00843963585793972
# pole angular velocity: -0.26617196202278137
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 109:
# Action taken: 0
# cart position: 0.3521154820919037
# cart velocity: 0.1753142923116684
# pole angle: 0.0031161964870989323
# pole angular velocity: 0.02916089817881584
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 110:
# Action taken: 1
# cart position: 0.3556217849254608
# cart velocity: 0.3703914284706116
# pole angle: 0.0036994144320487976
# pole angular velocity: -0.2625372111797333
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 111:
# Action taken: 0
# cart position: 0.3630295991897583
# cart velocity: 0.17521685361862183
# pole angle: -0.0015513297403231263
# pole angular velocity: 0.03131025657057762
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 112:
# Action taken: 0
# cart position: 0.36653393507003784
# cart velocity: -0.019882816821336746
# pole angle: -0.0009251246228814125
# pole angular velocity: 0.323503315448761
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 113:
# Action taken: 1
# cart position: 0.3661362826824188
# cart velocity: 0.1752522885799408
# pole angle: 0.005544941872358322
# pole angular velocity: 0.03052878938615322
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 114:
# Action taken: 0
# cart position: 0.36964133381843567
# cart velocity: -0.01994873210787773
# pole angle: 0.006155517417937517
# pole angular velocity: 0.3249560296535492
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 115:
# Action taken: 1
# cart position: 0.3692423403263092
# cart velocity: 0.17508503794670105
# pole angle: 0.012654637917876244
# pole angular velocity: 0.03422063589096069
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 116:
# Action taken: 1
# cart position: 0.37274405360221863
# cart velocity: 0.370023250579834
# pole angle: 0.01333905104547739
# pole angular velocity: -0.25444290041923523
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 117:
# Action taken: 0
# cart position: 0.38014450669288635
# cart velocity: 0.1747134029865265
# pole angle: 0.008250192739069462
# pole angular velocity: 0.04241735860705376
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 118:
# Action taken: 1
# cart position: 0.38363879919052124
# cart velocity: 0.369716078042984
# pole angle: 0.009098540060222149
# pole angular velocity: -0.24765117466449738
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 119:
# Action taken: 0
# cart position: 0.3910331130027771
# cart velocity: 0.1744653880596161
# pole angle: 0.00414551654830575
# pole angular velocity: 0.047887690365314484
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 120:
# Action taken: 1
# cart position: 0.39452242851257324
# cart velocity: 0.3695276379585266
# pole angle: 0.005103270057588816
# pole angular velocity: -0.24348440766334534
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 121:
# Action taken: 0
# cart position: 0.40191295742988586
# cart velocity: 0.17433317005634308
# pole angle: 0.00023358191538136452
# pole angular velocity: 0.050803836435079575
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 122:
# Action taken: 1
# cart position: 0.4053996205329895
# cart velocity: 0.36945176124572754
# pole angle: 0.0012496586423367262
# pole angular velocity: -0.24180538952350616
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 123:
# Action taken: 0
# cart position: 0.41278865933418274
# cart velocity: 0.17431199550628662
# pole angle: -0.003586448961868882
# pole angular velocity: 0.051271457225084305
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 124:
# Action taken: 0
# cart position: 0.41627490520477295
# cart velocity: -0.02075834758579731
# pole angle: -0.002561019966378808
# pole angular velocity: 0.3428206741809845
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 125:
# Action taken: 1
# cart position: 0.41585972905158997
# cart velocity: 0.1743999421596527
# pole angle: 0.004295393358916044
# pole angular velocity: 0.04933125525712967
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 126:
# Action taken: 0
# cart position: 0.41934773325920105
# cart velocity: -0.020783333107829094
# pole angle: 0.0052820187993347645
# pole angular velocity: 0.3433663249015808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 127:
# Action taken: 1
# cart position: 0.41893208026885986
# cart velocity: 0.17426307499408722
# pole angle: 0.012149345129728317
# pole angular velocity: 0.05235368758440018
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 128:
# Action taken: 1
# cart position: 0.4224173426628113
# cart velocity: 0.3692087233066559
# pole angle: 0.01319641899317503
# pole angular velocity: -0.23647139966487885
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 129:
# Action taken: 0
# cart position: 0.4298015236854553
# cart velocity: 0.1739007532596588
# pole angle: 0.008466990664601326
# pole angular velocity: 0.060344696044921875
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 130:
# Action taken: 1
# cart position: 0.43327951431274414
# cart velocity: 0.3689002990722656
# pole angle: 0.009673885069787502
# pole angular velocity: -0.22965486347675323
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 131:
# Action taken: 0
# cart position: 0.44065752625465393
# cart velocity: 0.17364144325256348
# pole angle: 0.005080787464976311
# pole angular velocity: 0.0660637840628624
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 132:
# Action taken: 1
# cart position: 0.4441303610801697
# cart velocity: 0.3686901926994324
# pole angle: 0.006402063183486462
# pole angular velocity: -0.22501181066036224
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 133:
# Action taken: 0
# cart position: 0.4515041708946228
# cart velocity: 0.17347732186317444
# pole angle: 0.0019018270540982485
# pole angular velocity: 0.06968367844820023
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 134:
# Action taken: 1
# cart position: 0.4549736976623535
# cart velocity: 0.3685719668865204
# pole angle: 0.003295500762760639
# pole angular velocity: -0.22239860892295837
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 135:
# Action taken: 0
# cart position: 0.462345153093338
# cart velocity: 0.1734030544757843
# pole angle: -0.0011524712899699807
# pole angular velocity: 0.07132203131914139
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 136:
# Action taken: 0
# cart position: 0.46581321954727173
# cart velocity: -0.021702351048588753
# pole angle: 0.00027396928635425866
# pole angular velocity: 0.3636411130428314
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 137:
# Action taken: 1
# cart position: 0.46537914872169495
# cart velocity: 0.17341570556163788
# pole angle: 0.007546791806817055
# pole angular velocity: 0.07104460150003433
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 138:
# Action taken: 1
# cart position: 0.46884748339653015
# cart velocity: 0.36842864751815796
# pole angle: 0.008967683650553226
# pole angular velocity: -0.2192477583885193
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 139:
# Action taken: 0
# cart position: 0.47621604800224304
# cart velocity: 0.17317967116832733
# pole angle: 0.00458272872492671
# pole angular velocity: 0.07625040411949158
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 140:
# Action taken: 1
# cart position: 0.4796796441078186
# cart velocity: 0.36823561787605286
# pole angle: 0.006107736844569445
# pole angular velocity: -0.21498313546180725
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 141:
# Action taken: 0
# cart position: 0.4870443642139435
# cart velocity: 0.1730268895626068
# pole angle: 0.0018080740701407194
# pole angular velocity: 0.07962016761302948
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 142:
# Action taken: 1
# cart position: 0.4905048906803131
# cart velocity: 0.3681228756904602
# pole angle: 0.003400477347895503
# pole angular velocity: -0.21249176561832428
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 143:
# Action taken: 0
# cart position: 0.4978673458099365
# cart velocity: 0.17295247316360474
# pole angle: -0.0008493578061461449
# pole angular velocity: 0.08126189559698105
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 144:
# Action taken: 0
# cart position: 0.5013263821601868
# cart velocity: -0.022157294675707817
# pole angle: 0.0007758800638839602
# pole angular velocity: 0.37367671728134155
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 145:
# Action taken: 1
# cart position: 0.5008832812309265
# cart velocity: 0.17295362055301666
# pole angle: 0.008249414153397083
# pole angular velocity: 0.08123853802680969
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 146:
# Action taken: 1
# cart position: 0.5043423175811768
# cart velocity: 0.36795637011528015
# pole angle: 0.009874185547232628
# pole angular velocity: -0.20883029699325562
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 147:
# Action taken: 0
# cart position: 0.5117014646530151
# cart velocity: 0.1726946234703064
# pole angle: 0.005697579123079777
# pole angular velocity: 0.08695098757743835
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 148:
# Action taken: 1
# cart position: 0.5151553750038147
# cart velocity: 0.367734432220459
# pole angle: 0.007436599116772413
# pole angular velocity: -0.20392891764640808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 149:
# Action taken: 0
# cart position: 0.5225100517272949
# cart velocity: 0.1725069284439087
# pole angle: 0.0033580209128558636
# pole angular velocity: 0.09109058976173401
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 150:
# Action taken: 1
# cart position: 0.5259601473808289
# cart velocity: 0.3675805926322937
# pole angle: 0.005179832689464092
# pole angular velocity: -0.2005309909582138
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 151:
# Action taken: 0
# cart position: 0.5333117842674255
# cart velocity: 0.17238493263721466
# pole angle: 0.0011692129774019122
# pole angular velocity: 0.09378141909837723
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 152:
# Action taken: 0
# cart position: 0.5367594957351685
# cart velocity: -0.022753750905394554
# pole angle: 0.003044841345399618
# pole angular velocity: 0.3868330121040344
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 153:
# Action taken: 1
# cart position: 0.5363044142723083
# cart velocity: 0.17232485115528107
# pole angle: 0.010781501419842243
# pole angular velocity: 0.09511164575815201
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 154:
# Action taken: 1
# cart position: 0.5397509336471558
# cart velocity: 0.3672906160354614
# pole angle: 0.01268373429775238
# pole angular velocity: -0.19415031373500824
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 155:
# Action taken: 0
# cart position: 0.5470967292785645
# cart velocity: 0.1719895601272583
# pole angle: 0.008800728246569633
# pole angular velocity: 0.10250663757324219
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 156:
# Action taken: 1
# cart position: 0.5505365133285522
# cart velocity: 0.3669842779636383
# pole angle: 0.010850860737264156
# pole angular velocity: -0.18738675117492676
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 157:
# Action taken: 0
# cart position: 0.5578761696815491
# cart velocity: 0.17170877754688263
# pole angle: 0.007103125564754009
# pole angular velocity: 0.10869935154914856
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 158:
# Action taken: 1
# cart position: 0.561310350894928
# cart velocity: 0.3667282164096832
# pole angle: 0.009277112782001495
# pole angular velocity: -0.1817341297864914
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 159:
# Action taken: 0
# cart position: 0.5686449408531189
# cart velocity: 0.17147476971149445
# pole angle: 0.005642429925501347
# pole angular velocity: 0.11386088281869888
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 160:
# Action taken: 1
# cart position: 0.5720744132995605
# cart velocity: 0.3665153980255127
# pole angle: 0.007919647730886936
# pole angular velocity: -0.1770365685224533
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 161:
# Action taken: 0
# cart position: 0.5794047117233276
# cart velocity: 0.17128102481365204
# pole angle: 0.004378916695713997
# pole angular velocity: 0.11813418567180634
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 162:
# Action taken: 1
# cart position: 0.5828303694725037
# cart velocity: 0.36633995175361633
# pole angle: 0.0067416001111269
# pole angular velocity: -0.1731640249490738
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 163:
# Action taken: 0
# cart position: 0.590157151222229
# cart velocity: 0.17112217843532562
# pole angle: 0.0032783199567347765
# pole angular velocity: 0.12163802236318588
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 164:
# Action taken: 1
# cart position: 0.5935795903205872
# cart velocity: 0.36619701981544495
# pole angle: 0.005711080506443977
# pole angular velocity: -0.1700088232755661
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 165:
# Action taken: 0
# cart position: 0.6009035706520081
# cart velocity: 0.17099377512931824
# pole angle: 0.0023109037429094315
# pole angular velocity: 0.1244702860713005
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 166:
# Action taken: 1
# cart position: 0.6043234467506409
# cart velocity: 0.3660825490951538
# pole angle: 0.004800309427082539
# pole angular velocity: -0.1674826741218567
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 167:
# Action taken: 0
# cart position: 0.6116450428962708
# cart velocity: 0.17089220881462097
# pole angle: 0.0014506559818983078
# pole angular velocity: 0.12671072781085968
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 168:
# Action taken: 1
# cart position: 0.6150628924369812
# cart velocity: 0.36599335074424744
# pole angle: 0.003984870854765177
# pole angular velocity: -0.16551417112350464
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 169:
# Action taken: 0
# cart position: 0.6223827600479126
# cart velocity: 0.17081458866596222
# pole angle: 0.0006745871505700052
# pole angular velocity: 0.12842319905757904
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 170:
# Action taken: 1
# cart position: 0.6257990598678589
# cart velocity: 0.3659268617630005
# pole angle: 0.0032430512364953756
# pole angular velocity: -0.16404682397842407
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 171:
# Action taken: 0
# cart position: 0.6331176161766052
# cart velocity: 0.17075863480567932
# pole angle: -3.7885365600232035e-05
# pole angular velocity: 0.12965743243694305
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 172:
# Action taken: 0
# cart position: 0.6365327835083008
# cart velocity: -0.02436276711523533
# pole angle: 0.002555263228714466
# pole angular velocity: 0.4223284125328064
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 173:
# Action taken: 1
# cart position: 0.636045515537262
# cart velocity: 0.17072288691997528
# pole angle: 0.01100183092057705
# pole angular velocity: 0.13045212626457214
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 174:
# Action taken: 1
# cart position: 0.6394599676132202
# cart velocity: 0.36568552255630493
# pole angle: 0.013610873371362686
# pole angular velocity: -0.15873967111110687
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 175:
# Action taken: 0
# cart position: 0.6467736959457397
# cart velocity: 0.1703713834285736
# pole angle: 0.010436080396175385
# pole angular velocity: 0.138205885887146
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 176:
# Action taken: 1
# cart position: 0.6501811146736145
# cart velocity: 0.36534231901168823
# pole angle: 0.01320019830018282
# pole angular velocity: -0.15116643905639648
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 177:
# Action taken: 0
# cart position: 0.6574879884719849
# cart velocity: 0.17003385722637177
# pole angle: 0.010176869109272957
# pole angular velocity: 0.14565147459506989
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 178:
# Action taken: 1
# cart position: 0.660888671875
# ...
# pole angle: 0.08277333527803421
# pole angular velocity: 0.23113998770713806
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 228:
# Action taken: 1
# cart position: 1.0196514129638672
# cart velocity: 0.7237480878829956
# pole angle: 0.08739612996578217
# pole angular velocity: -0.03432833403348923
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 229:
# Action taken: 0
# cart position: 1.0341262817382812
# cart velocity: 0.527488648891449
# pole angle: 0.08670956641435623
# pole angular velocity: 0.28459906578063965
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 230:
# Action taken: 1
# cart position: 1.0446760654449463
# cart velocity: 0.7212737798690796
# pole angle: 0.09240154922008514
# pole angular velocity: 0.020474081858992577
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 231:
# Action taken: 1
# cart position: 1.0591015815734863
# cart velocity: 0.9149574637413025
# pole angle: 0.09281103312969208
# pole angular velocity: -0.2416846603155136
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 232:
# Action taken: 0
# cart position: 1.0774006843566895
# cart velocity: 0.7186407446861267
# pole angle: 0.087977334856987
# pole angular velocity: 0.07877030968666077
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 233:
# Action taken: 1
# cart position: 1.091773509979248
# cart velocity: 0.9123985767364502
# pole angle: 0.08955274522304535
# pole angular velocity: -0.184910386800766
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 234:
# Action taken: 0
# cart position: 1.1100214719772339
# cart velocity: 0.7161170244216919
# pole angle: 0.08585453778505325
# pole angular velocity: 0.13462547957897186
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 235:
# Action taken: 1
# cart position: 1.1243438720703125
# cart velocity: 0.9099109768867493
# pole angle: 0.08854704350233078
# pole angular velocity: -0.12978453934192657
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 236:
# Action taken: 0
# cart position: 1.1425421237945557
# cart velocity: 0.713639497756958
# pole angle: 0.08595135062932968
# pole angular velocity: 0.18946805596351624
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 237:
# Action taken: 1
# cart position: 1.1568148136138916
# cart velocity: 0.9074333906173706
# pole angle: 0.08974071592092514
# pole angular velocity: -0.07491102814674377
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 238:
# Action taken: 0
# cart position: 1.1749634742736816
# cart velocity: 0.711147129535675
# pole angle: 0.08824249356985092
# pole angular velocity: 0.24468189477920532
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 239:
# Action taken: 1
# cart position: 1.189186453819275
# cart velocity: 0.9049052000045776
# pole angle: 0.09313613176345825
# pole angular velocity: -0.018914679065346718
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 240:
# Action taken: 0
# cart position: 1.2072845697402954
# cart velocity: 0.7085795402526855
# pole angle: 0.09275783598423004
# pole angular velocity: 0.30163994431495667
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 241:
# Action taken: 1
# cart position: 1.2214561700820923
# cart velocity: 0.9022654294967651
# pole angle: 0.09879063814878464
# pole angular velocity: 0.039591748267412186
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 242:
# Action taken: 1
# cart position: 1.2395014762878418
# cart velocity: 1.0958421230316162
# pole angle: 0.09958247095346451
# pole angular velocity: -0.22036032378673553
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 243:
# Action taken: 0
# cart position: 1.261418342590332
# cart velocity: 0.8994482159614563
# pole angle: 0.09517526626586914
# pole angular velocity: 0.10199999809265137
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 244:
# Action taken: 1
# cart position: 1.279407262802124
# cart velocity: 1.0930864810943604
# pole angle: 0.09721526503562927
# pole angular velocity: -0.15920351445674896
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 245:
# Action taken: 0
# cart position: 1.3012690544128418
# cart velocity: 0.896716833114624
# pole angle: 0.0940311923623085
# pole angular velocity: 0.162496417760849
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 246:
# Action taken: 1
# cart position: 1.3192033767700195
# cart velocity: 1.0903756618499756
# pole angle: 0.09728112071752548
# pole angular velocity: -0.09910409897565842
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 247:
# Action taken: 0
# cart position: 1.3410108089447021
# cart velocity: 0.8940038084983826
# pole angle: 0.09529904276132584
# pole angular velocity: 0.2226165235042572
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 248:
# Action taken: 1
# cart position: 1.3588908910751343
# cart velocity: 1.0876436233520508
# pole angle: 0.09975137561559677
# pole angular velocity: -0.038549672812223434
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 249:
# Action taken: 0
# cart position: 1.3806438446044922
# cart velocity: 0.8912432193756104
# pole angle: 0.0989803820848465
# pole angular velocity: 0.28386473655700684
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 250:
# Action taken: 1
# cart position: 1.3984687328338623
# cart velocity: 1.0848243236541748
# pole angle: 0.10465767234563828
# pole angular velocity: 0.023967023938894272
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 251:
# Action taken: 1
# cart position: 1.4201651811599731
# cart velocity: 1.2783018350601196
# pole angle: 0.10513701289892197
# pole angular velocity: -0.23394806683063507
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 252:
# Action taken: 0
# cart position: 1.4457311630249023
# cart velocity: 1.081847071647644
# pole angle: 0.1004580557346344
# pole angular velocity: 0.08996027708053589
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 253:
# Action taken: 1
# cart position: 1.4673681259155273
# cart velocity: 1.2753963470458984
# pole angle: 0.10225725919008255
# pole angular velocity: -0.16941487789154053
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 254:
# Action taken: 0
# cart position: 1.4928760528564453
# cart velocity: 1.0789706707000732
# pole angle: 0.0988689586520195
# pole angular velocity: 0.153695747256279
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 255:
# Action taken: 1
# cart position: 1.5144554376602173
# cart velocity: 1.2725481986999512
# pole angle: 0.10194287449121475
# pole angular velocity: -0.10623236000537872
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 256:
# Action taken: 0
# cart position: 1.5399065017700195
# cart velocity: 1.0761243104934692
# pole angle: 0.09981822967529297
# pole angular velocity: 0.21679313480854034
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 257:
# Action taken: 1
# cart position: 1.5614289045333862
# cart velocity: 1.2696881294250488
# pole angle: 0.10415409505367279
# pole angular velocity: -0.04280949383974075
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 258:
# Action taken: 0
# cart position: 1.586822748184204
# cart velocity: 1.0732388496398926
# pole angle: 0.10329790413379669
# pole angular velocity: 0.2808336019515991
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 259:
# Action taken: 1
# cart position: 1.6082874536514282
# cart velocity: 1.266747236251831
# pole angle: 0.1089145764708519
# pole angular velocity: 0.022433830425143242
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 260:
# Action taken: 1
# cart position: 1.633622407913208
# cart velocity: 1.4601523876190186
# pole angle: 0.10936325043439865
# pole angular velocity: -0.23399725556373596
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 261:
# Action taken: 0
# cart position: 1.6628254652023315
# cart velocity: 1.2636516094207764
# pole angle: 0.1046833023428917
# pole angular velocity: 0.09108176827430725
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 262:
# Action taken: 1
# cart position: 1.6880985498428345
# cart velocity: 1.4571293592453003
# pole angle: 0.10650493949651718
# pole angular velocity: -0.1668255776166916
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 263:
# Action taken: 0
# cart position: 1.7172410488128662
# cart velocity: 1.2606568336486816
# pole angle: 0.10316842794418335
# pole angular velocity: 0.1574665904045105
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 264:
# Action taken: 1
# cart position: 1.742454171180725
# cart velocity: 1.4541620016098022
# pole angle: 0.10631775856018066
# pole angular velocity: -0.1009700745344162
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 265:
# Action taken: 0
# cart position: 1.77153742313385
# cart velocity: 1.2576897144317627
# pole angle: 0.10429836064577103
# pole angular velocity: 0.2232728898525238
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 266:
# Action taken: 1
# cart position: 1.7966912984848022
# cart velocity: 1.4511783123016357
# pole angle: 0.10876381397247314
# pole angular velocity: -0.03477467596530914
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 267:
# Action taken: 0
# cart position: 1.8257148265838623
# cart velocity: 1.2546783685684204
# pole angle: 0.1080683246254921
# pole angular velocity: 0.29014715552330017
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 268:
# Action taken: 1
# cart position: 1.8508083820343018
# cart velocity: 1.4481067657470703
# pole angle: 0.113871268928051
# pole angular velocity: 0.0334075391292572
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 269:
# Action taken: 0
# cart position: 1.8797705173492432
# cart velocity: 1.251551628112793
# pole angle: 0.11453941464424133
# pole angular velocity: 0.35973668098449707
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 270:
# Action taken: 1
# cart position: 1.904801607131958
# cart velocity: 1.444874882698059
# pole angle: 0.1217341497540474
# pole angular velocity: 0.10525287687778473
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 271:
# Action taken: 1
# cart position: 1.9336990118026733
# cart velocity: 1.6380610466003418
# pole angle: 0.12383920699357986
# pole angular velocity: -0.14668036997318268
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 272:
# Action taken: 0
# cart position: 1.9664602279663086
# cart velocity: 1.4414032697677612
# pole angle: 0.12090560048818588
# pole angular velocity: 0.1823628842830658
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 273:
# Action taken: 1
# cart position: 1.995288372039795
# cart velocity: 1.6346063613891602
# pole angle: 0.12455286085605621
# pole angular velocity: -0.06986643373966217
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 274:
# Action taken: 0
# cart position: 2.0279805660247803
# cart velocity: 1.4379392862319946
# pole angle: 0.12315553426742554
# pole angular velocity: 0.25937291979789734
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 275:
# Action taken: 1
# cart position: 2.056739330291748
# cart velocity: 1.6311075687408447
# pole angle: 0.12834298610687256
# pole angular velocity: 0.007931341417133808
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 276:
# Action taken: 0
# cart position: 2.0893614292144775
# cart velocity: 1.4344009160995483
# pole angle: 0.12850160896778107
# pole angular velocity: 0.3381938636302948
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 277:
# Action taken: 1
# cart position: 2.118049383163452
# cart velocity: 1.627482533454895
# pole angle: 0.1352654993534088
# pole angular velocity: 0.08863504230976105
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 278:
# Action taken: 1
# cart position: 2.1505990028381348
# cart velocity: 1.820432424545288
# pole angle: 0.1370382010936737
# pole angular velocity: -0.15849919617176056
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 279:
# Action taken: 0
# cart position: 2.1870076656341553
# cart velocity: 1.6236417293548584
# pole angle: 0.13386821746826172
# pole angular velocity: 0.1740827113389969
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 280:
# Action taken: 1
# cart position: 2.219480514526367
# cart velocity: 1.8166190385818481
# pole angle: 0.13734985888004303
# pole angular velocity: -0.0735536590218544
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 281:
# Action taken: 0
# cart position: 2.255812883377075
# cart velocity: 1.61982262134552
# pole angle: 0.135878786444664
# pole angular velocity: 0.25911492109298706
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 282:
# Action taken: 1
# cart position: 2.2882094383239746
# cart velocity: 1.8127696514129639
# pole angle: 0.14106108248233795
# pole angular velocity: 0.012187706306576729
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 283:
# Action taken: 0
# cart position: 2.324464797973633
# cart velocity: 1.615936040878296
# pole angle: 0.1413048505783081
# pole angular velocity: 0.3458399474620819
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 284:
# Action taken: 1
# cart position: 2.356783390045166
# cart velocity: 1.8087948560714722
# pole angle: 0.14822164177894592
# pole angular velocity: 0.10084053128957748
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 285:
# Action taken: 1
# cart position: 2.3929593563079834
# cart velocity: 2.001516103744507
# pole angle: 0.15023845434188843
# pole angular velocity: -0.14165371656417847
# Reward: 1.0
# Terminated: False, Truncated: False
# --------------------------------------------------
# Step 286:
# Action taken: 0
# cart position: 2.4329898357391357
# cart velocity: 1.8045974969863892
# pole angle: 0.14740538597106934
# pole angular velocity: 0.19440099596977234
# Reward: 1.0
# Terminated: True, Truncated: False
# --------------------------------------------------
# Episode finished! Total reward: 286.0

# %%
obs_explanation = """\
**Observation vector (4 values):**
1. **Cart Position (m)** — horizontal position on the track (≈ -4.8 to +4.8).
2. **Cart Velocity (m/s)** — how fast the cart moves (unbounded float in practice).
3. **Pole Angle (rad)** — tilt of the pole relative to vertical (≈ -0.4189 to +0.4189 rad ≈ ±24°).
4. **Pole Angular Velocity (rad/s)** — how fast the pole is rotating (unbounded float in practice).
"""

failure_conditions = """\
**Episode ends when (termination/truncation):**
- **Pole tilt exceeds ±0.4189 rad (~±24°)** → `terminated = True`
- **Cart position leaves track bounds (≈ ±4.8 m)** → `terminated = True`
- **Time limit of 500 steps is reached** → `truncated = True`
"""

with open(report_file, "w",encoding="utf-8")as f:
    f.write("# SCRUM-15: Researching Cartpole test write\n\n")
    f.write("## Environment Details\n")
    f.write(f"- Action space: {env.action_space}\n")
    f.write(f"- Observation space: {env.observation_space}\n")
    f.write(f"- Maximum steps per episode: {env.spec.max_episode_steps}\n\n")

    f.write("## Observation Meaning\n")
    f.write(obs_explanation + "\n")

    f.write("## Failure Conditions\n")
    f.write(failure_conditions + "\n")


    f.write("## Example Run\n")
    f.write(f"- Starting observation: {observation.tolist()}\n")
    f.write(f"- Total reward: {total_reward}\n")

# %%
def generate_evaluation_curve(model, graphs_dir, num_eval_episodes=20, eval_freq=200, total_timesteps=2000):
    """
    Evaluate the model at regular intervals and plot evaluation curve.
    Evaluation curve, not recording rewards during training, evaluating trained model at fixed intervals
    Each point on graph comes from evaluate_policy(), which tests model for several episodes & averages results
    Measures performance after certain amounts of training, NOT the actual learning process

    * TLDR: graphs shows the evaluarion reward at regular timesteps during training *
    """
    rewards = []
    timesteps = []

    env = gym.make("CartPole-v1")

    for step in range(eval_freq, total_timesteps + 1, eval_freq):
        # Evaluate policy
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=num_eval_episodes, deterministic=True) #this uses the model we just trained 
        rewards.append(mean_reward)
        timesteps.append(step)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(timesteps, rewards, marker="o", label="Mean Reward (Evaluation)", color="tab:orange")
    plt.xlabel("Timesteps")
    plt.ylabel("Mean Reward over Episodes")
    plt.title("evaluation Curve (PPO on CartPole)")
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend()

    # Save figure
    graph_file = graphs_dir / "evaluation_curve.png"
    plt.savefig(graph_file, dpi=200, bbox_inches="tight")
    plt.close()
    env.close()

    print(f"evaluation curve saved to {graph_file}")


generate_evaluation_curve(model, graphs_dir)
# Out:
# evaluation curve saved to ../../documentation/cartpole/ppo-cartpole/run_2025-10-09_11-34-50/graphs/evaluation_curve.png
